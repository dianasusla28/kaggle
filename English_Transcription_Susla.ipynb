# %% [markdown]
# Соревнование: https://www.kaggle.com/c/phonetics-en-2021

# %%
import numpy as np
import scipy
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from matplotlib.colors import Colormap, ListedColormap
import pandas as pd
import time
from keras.datasets import mnist
import torch
import torchvision
from time import time
from torchvision import datasets, transforms
from torch import nn, optim
from torch.nn import functional as F
from torch.autograd import Variable
from tqdm import tqdm
from torch.nn.utils.rnn import pad_sequence
from google.colab import files
from zipfile import ZipFile
from functools import partial
from dataclasses import dataclass
from collections import OrderedDict
from zipfile import ZipFile as zip
from torchsummary import summary
from typing import Type, Any, Callable, Union, List, Optional
from torch import Tensor
import random

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
SOS_token = 0
EOS_token = 1


class Transcription:
    def __init__(self, name):
        self.name = name
        self.sym2index = {}
        self.sym2count = {}
        self.index2sym = {0: "SOS", 1: "EOS"}
        self.n_syms = 2  # Count SOS and EOS

    def addWord(self, word):
        for sym in word.split(' '):
            self.addSym(sym)

    def addSym(self, sym):
        if sym not in self.sym2index:
            self.sym2index[sym] = self.n_syms
            self.sym2count[sym] = 1
            self.index2sym[self.n_syms] = sym
            self.n_syms += 1
        else:
            self.sym2count[sym] += 1

# %%
def readPairs(word, trans):
    words = open('/content/gdrive/My Drive/train.txt', encoding='utf-8').read().strip().split('\n')

    pairs = []
    for w in words:
        pair = w.split(' ')
        pairs.append([' '.join(pair[0]), pair[1].replace('_', ' ')])

    input = Transcription(word)
    output = Transcription(trans)

    return input, output, pairs

# %%
def prepareData(word, trans):
    input_lang, output_lang, pairs = readPairs(word, trans)

    for pair in pairs:
        input_lang.addWord(pair[0])
        output_lang.addWord(pair[1])
    print("Counted words:")
    print(input_lang.name, input_lang.n_syms)
    print(output_lang.name, output_lang.n_syms)
    return input_lang, output_lang, pairs

input_lang, output_lang, pairs = prepareData('word', 'transcriprion')
print(random.choice(pairs))
# Out:
# Counted words:
# word 30
# transcriprion 41
# ['A B O', 'AA B OW']

# %%
class EncoderRNN(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(EncoderRNN, self).__init__()
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(input_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)

    def forward(self, input, hidden):
        embedded = self.embedding(input).view(1, 1, -1)
        output = embedded
        output, hidden = self.gru(output, hidden)
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %%
class DecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size):
        super(DecoderRNN, self).__init__()
        self.hidden_size = hidden_size


        self.embedding = nn.Embedding(output_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)
        self.softmax = nn.LogSoftmax(dim=1)

    def forward(self, input, hidden):
        output = self.embedding(input).view(1, 1, -1)
        output = F.relu(output)
        output, hidden = self.gru(output, hidden)
        output = self.softmax(self.out(output[0]))
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %%
class AttnDecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size, dropout_p=0.1, max_length=75):
        super(AttnDecoderRNN, self).__init__()
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.dropout_p = dropout_p
        self.max_length = max_length

        self.embedding = nn.Embedding(self.output_size, self.hidden_size)
        self.attn = nn.Linear(self.hidden_size * 2, self.max_length)
        self.attn_combine = nn.Linear(self.hidden_size * 2, self.hidden_size)
        self.dropout = nn.Dropout(self.dropout_p)
        self.gru = nn.GRU(self.hidden_size, self.hidden_size)
        self.out = nn.Linear(self.hidden_size, self.output_size)

    def forward(self, input, hidden, encoder_outputs):
        embedded = self.embedding(input).view(1, 1, -1)
        embedded = self.dropout(embedded)

        attn_weights = F.softmax(
            self.attn(torch.cat((embedded[0], hidden[0]), 1)), dim=1)
        attn_applied = torch.bmm(attn_weights.unsqueeze(0),
                                 encoder_outputs.unsqueeze(0))

        output = torch.cat((embedded[0], attn_applied[0]), 1)
        output = self.attn_combine(output).unsqueeze(0)

        output = F.relu(output)
        output, hidden = self.gru(output, hidden)

        output = F.log_softmax(self.out(output[0]), dim=1)
        return output, hidden, attn_weights

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %%
def indexesFromWord(trans, word):
    return [trans.sym2index[s] for s in word.split(' ')]

def tensorFromWord(trans, word):
    indexes = indexesFromWord(trans, word)
    indexes.append(EOS_token)
    return torch.tensor(indexes, dtype=torch.long, device=device).view(-1, 1)

def tensorsFromPair(pair):
    input_tensor = tensorFromWord(input_lang, pair[0])
    target_tensor = tensorFromWord(output_lang, pair[1])
    return (input_tensor, target_tensor)

# %%
teacher_forcing_ratio = 0.7


def train(input_tensor, target_tensor, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion, max_length=75):
    encoder_hidden = encoder.initHidden()

    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    input_length = input_tensor.size(0)
    target_length = target_tensor.size(0)

    encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

    loss = 0

    for ei in range(input_length):
        encoder_output, encoder_hidden = encoder(
            input_tensor[ei], encoder_hidden)
        encoder_outputs[ei] = encoder_output[0, 0]

    decoder_input = torch.tensor([[SOS_token]], device=device)

    decoder_hidden = encoder_hidden

    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    if use_teacher_forcing:
        # Teacher forcing: Feed the target as the next input
        for di in range(target_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            loss += criterion(decoder_output, target_tensor[di])
            decoder_input = target_tensor[di]  # Teacher forcing

    else:
        # Without teacher forcing: use its own predictions as the next input
        for di in range(target_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            topv, topi = decoder_output.topk(1)
            decoder_input = topi.squeeze().detach()  # detach from history as input

            loss += criterion(decoder_output, target_tensor[di])
            if decoder_input.item() == EOS_token:
                break

    loss.backward()

    encoder_optimizer.step()
    decoder_optimizer.step()

    return loss.item() / target_length

# %%
import time
import math


def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)


def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (- %s)' % (asMinutes(s), asMinutes(rs))

# %%
def trainIters(encoder, decoder, n_iters, print_every=500, learning_rate=0.01):
    start = time.time()
    plot_losses = []
    print_loss_total = 0  # Reset every print_every
    plot_loss_total = 0  # Reset every plot_every

    encoder_optimizer = optim.SGD(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = optim.SGD(decoder.parameters(), lr=learning_rate)
    training_pairs = [tensorsFromPair(random.choice(pairs))
                      for i in range(n_iters)]
    #training_pairs = [tensorsFromPair(p) for p in pairs]
    criterion = nn.NLLLoss()

    for iter in range(1, n_iters + 1):
        training_pair = training_pairs[iter - 1]
        input_tensor = training_pair[0]
        target_tensor = training_pair[1]

        loss = train(input_tensor, target_tensor, encoder,
                     decoder, encoder_optimizer, decoder_optimizer, criterion)
        print_loss_total += loss
        plot_loss_total += loss

        if iter % print_every == 0:
            print_loss_avg = print_loss_total / print_every
            print_loss_total = 0
            print('%s (%d %d%%) %.4f' % (timeSince(start, iter / n_iters),
                                         iter, iter / n_iters * 100, print_loss_avg))

# %%
def evaluate(encoder, decoder, sentence, max_length=75):
    with torch.no_grad():
        input_tensor = tensorFromWord(input_lang, sentence)
        input_length = input_tensor.size()[0]
        encoder_hidden = encoder.initHidden()

        encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

        for ei in range(input_length):
            encoder_output, encoder_hidden = encoder(input_tensor[ei],
                                                     encoder_hidden)
            encoder_outputs[ei] += encoder_output[0, 0]

        decoder_input = torch.tensor([[SOS_token]], device=device)  # SOS

        decoder_hidden = encoder_hidden

        decoded_words = []
        decoder_attentions = torch.zeros(max_length, max_length)

        for di in range(max_length):
            decoder_output, decoder_hidden, decoder_attention = decoder(
                decoder_input, decoder_hidden, encoder_outputs)
            decoder_attentions[di] = decoder_attention.data
            topv, topi = decoder_output.data.topk(1)
            if topi.item() == EOS_token:
                break
            else:
                decoded_words.append(output_lang.index2sym[topi.item()])

            decoder_input = topi.squeeze().detach()

        return decoded_words, decoder_attentions[:di + 1]

# %%
def evaluateRandomly(encoder, decoder, n=10000):
    count = 0
    for i in range(n):
        pair = random.choice(pairs)
        print(pair[0].replace(' ', ''))
        print(pair[1].replace(' ', "_"))
        output_syms, attentions = evaluate(encoder, decoder, pair[0])
        output_word = '_'.join(output_syms)
        if (pair[1].replace(' ', "_") == output_word ):
            count += 1
        print(output_word)
        print('')
    print('Верно:', count, 'слов из 10000')

# %%
len(pairs)
# Out:
# 83194

# %%
"""hidden_size = 256
encoder1 = EncoderRNN(input_lang.n_syms, hidden_size).to(device)
decoder1 = AttnDecoderRNN(hidden_size, output_lang.n_syms, dropout_p=0.1).to(device)
"""
trainIters(encoder1, decoder1, 5000)
# Out:
# 0m 14s (- 40m 49s) (500 0%) 2.8512
# 0m 25s (- 34m 50s) (1000 1%) 2.7714
# 0m 35s (- 32m 7s) (1500 1%) 2.6945
# 0m 45s (- 30m 54s) (2000 2%) 2.6874
# 0m 55s (- 29m 59s) (2500 3%) 2.6029
# 1m 5s (- 29m 12s) (3000 3%) 2.4654
# 1m 15s (- 28m 41s) (3500 4%) 2.2308
# 1m 25s (- 28m 18s) (4000 4%) 2.1642
# 1m 36s (- 28m 5s) (4500 5%) 2.0194
# 1m 46s (- 27m 45s) (5000 6%) 1.8399
# 1m 56s (- 27m 28s) (5500 6%) 1.7879
# 2m 7s (- 27m 17s) (6000 7%) 1.6792
# 2m 17s (- 27m 6s) (6500 7%) 1.5991
# 2m 28s (- 26m 53s) (7000 8%) 1.5376
# 2m 39s (- 26m 49s) (7500 9%) 1.5382
# 2m 50s (- 26m 39s) (8000 9%) 1.4118
# 3m 0s (- 26m 28s) (8500 10%) 1.3961
# 3m 11s (- 26m 17s) (9000 10%) 1.4098
# 3m 21s (- 26m 4s) (9500 11%) 1.3008
# 3m 32s (- 25m 51s) (10000 12%) 1.3421
# 3m 42s (- 25m 37s) (10500 12%) 1.2330
# 3m 52s (- 25m 24s) (11000 13%) 1.2326
# 4m 2s (- 25m 14s) (11500 13%) 1.2948
# 4m 13s (- 25m 1s) (12000 14%) 1.1969
# 4m 23s (- 24m 50s) (12500 15%) 1.1915
# 4m 34s (- 24m 40s) (13000 15%) 1.1853
# 4m 44s (- 24m 30s) (13500 16%) 1.1401
# 4m 55s (- 24m 18s) (14000 16%) 1.2300
# 5m 5s (- 24m 6s) (14500 17%) 1.1304
# 5m 16s (- 23m 57s) (15000 18%) 1.0712
# 5m 26s (- 23m 45s) (15500 18%) 1.0388
# 5m 37s (- 23m 35s) (16000 19%) 1.0390
# 5m 47s (- 23m 24s) (16500 19%) 1.0395
# 5m 58s (- 23m 14s) (17000 20%) 1.0533
# 6m 8s (- 23m 4s) (17500 21%) 1.0233
# 6m 19s (- 22m 53s) (18000 21%) 1.0336
# 6m 30s (- 22m 44s) (18500 22%) 1.0031
# 6m 40s (- 22m 33s) (19000 22%) 0.9691
# 6m 51s (- 22m 24s) (19500 23%) 1.0178
# 7m 2s (- 22m 13s) (20000 24%) 1.0393
# 7m 12s (- 22m 3s) (20500 24%) 0.9813
# 7m 23s (- 21m 52s) (21000 25%) 1.0500
# 7m 33s (- 21m 41s) (21500 25%) 1.0119
# 7m 43s (- 21m 30s) (22000 26%) 0.9641
# 7m 54s (- 21m 19s) (22500 27%) 0.9542
# 8m 4s (- 21m 9s) (23000 27%) 0.9417
# 8m 15s (- 20m 58s) (23500 28%) 0.9741
# 8m 25s (- 20m 47s) (24000 28%) 0.9441
# 8m 36s (- 20m 37s) (24500 29%) 0.9735
# 8m 46s (- 20m 26s) (25000 30%) 0.8295
# 8m 57s (- 20m 15s) (25500 30%) 0.9245
# 9m 8s (- 20m 5s) (26000 31%) 0.9116
# 9m 19s (- 19m 56s) (26500 31%) 0.8825
# 9m 29s (- 19m 45s) (27000 32%) 0.8981
# 9m 40s (- 19m 36s) (27500 33%) 0.8851
# 9m 51s (- 19m 25s) (28000 33%) 0.9392
# 10m 1s (- 19m 14s) (28500 34%) 0.8954
# 10m 12s (- 19m 4s) (29000 34%) 0.8063
# 10m 22s (- 18m 53s) (29500 35%) 0.8763
# 10m 33s (- 18m 42s) (30000 36%) 0.8651
# 10m 44s (- 18m 33s) (30500 36%) 0.8420
# 10m 54s (- 18m 22s) (31000 37%) 0.8711
# 11m 5s (- 18m 11s) (31500 37%) 0.8620
# 11m 15s (- 18m 1s) (32000 38%) 0.8467
# 11m 26s (- 17m 50s) (32500 39%) 0.7884
# 11m 36s (- 17m 39s) (33000 39%) 0.8663
# 11m 47s (- 17m 29s) (33500 40%) 0.8175
# 11m 57s (- 17m 18s) (34000 40%) 0.8637
# 12m 8s (- 17m 8s) (34500 41%) 0.9173
# 12m 19s (- 16m 58s) (35000 42%) 0.8477
# 12m 30s (- 16m 47s) (35500 42%) 0.8053
# 12m 41s (- 16m 37s) (36000 43%) 0.8209
# 12m 51s (- 16m 27s) (36500 43%) 0.8881
# 13m 2s (- 16m 16s) (37000 44%) 0.7870
# 13m 12s (- 16m 5s) (37500 45%) 0.7734
# 13m 23s (- 15m 55s) (38000 45%) 0.7772
# 13m 34s (- 15m 45s) (38500 46%) 0.7918
# 13m 45s (- 15m 35s) (39000 46%) 0.7644
# 13m 55s (- 15m 24s) (39500 47%) 0.7951
# 14m 6s (- 15m 13s) (40000 48%) 0.7520
# 14m 16s (- 15m 3s) (40500 48%) 0.7676
# 14m 27s (- 14m 52s) (41000 49%) 0.7623
# 14m 38s (- 14m 42s) (41500 49%) 0.7652
# 14m 48s (- 14m 31s) (42000 50%) 0.7984
# 14m 59s (- 14m 21s) (42500 51%) 0.7077
# 15m 9s (- 14m 10s) (43000 51%) 0.7018
# 15m 20s (- 13m 59s) (43500 52%) 0.7619
# 15m 31s (- 13m 49s) (44000 52%) 0.7950
# 15m 41s (- 13m 39s) (44500 53%) 0.8012
# 15m 53s (- 13m 28s) (45000 54%) 0.7154
# 16m 4s (- 13m 18s) (45500 54%) 0.7525
# 16m 15s (- 13m 8s) (46000 55%) 0.7257
# 16m 25s (- 12m 57s) (46500 55%) 0.7226
# 16m 35s (- 12m 46s) (47000 56%) 0.7316
# 16m 46s (- 12m 36s) (47500 57%) 0.7134
# 16m 57s (- 12m 25s) (48000 57%) 0.8046
# 17m 8s (- 12m 15s) (48500 58%) 0.7462
# 17m 18s (- 12m 4s) (49000 58%) 0.7156
# 17m 29s (- 11m 54s) (49500 59%) 0.7087
# 17m 39s (- 11m 43s) (50000 60%) 0.7443
# 17m 50s (- 11m 32s) (50500 60%) 0.6946
# 18m 0s (- 11m 22s) (51000 61%) 0.6871
# 18m 10s (- 11m 11s) (51500 61%) 0.6510
# 18m 21s (- 11m 0s) (52000 62%) 0.7035
# 18m 31s (- 10m 49s) (52500 63%) 0.7039
# 18m 42s (- 10m 39s) (53000 63%) 0.7467
# 18m 53s (- 10m 28s) (53500 64%) 0.8015
# 19m 3s (- 10m 18s) (54000 64%) 0.7541
# 19m 14s (- 10m 7s) (54500 65%) 0.7312
# 19m 25s (- 9m 57s) (55000 66%) 0.7544
# 19m 35s (- 9m 46s) (55500 66%) 0.7134
# 19m 46s (- 9m 36s) (56000 67%) 0.7767
# 19m 56s (- 9m 25s) (56500 67%) 0.7090
# 20m 7s (- 9m 14s) (57000 68%) 0.7038
# 20m 18s (- 9m 4s) (57500 69%) 0.7122
# 20m 29s (- 8m 54s) (58000 69%) 0.7098
# 20m 40s (- 8m 43s) (58500 70%) 0.7297
# 20m 50s (- 8m 32s) (59000 70%) 0.7145
# 21m 1s (- 8m 22s) (59500 71%) 0.6879
# 21m 11s (- 8m 11s) (60000 72%) 0.7313
# 21m 22s (- 8m 1s) (60500 72%) 0.7327
# 21m 33s (- 7m 50s) (61000 73%) 0.6622
# 21m 43s (- 7m 39s) (61500 73%) 0.6758
# 21m 53s (- 7m 29s) (62000 74%) 0.6474
# 22m 4s (- 7m 18s) (62500 75%) 0.6834
# 22m 15s (- 7m 7s) (63000 75%) 0.6838
# 22m 25s (- 6m 57s) (63500 76%) 0.6325
# 22m 36s (- 6m 46s) (64000 76%) 0.7034
# 22m 46s (- 6m 36s) (64500 77%) 0.6110
# 22m 57s (- 6m 25s) (65000 78%) 0.7143
# 23m 7s (- 6m 14s) (65500 78%) 0.6444
# 23m 17s (- 6m 4s) (66000 79%) 0.6631
# 23m 28s (- 5m 53s) (66500 79%) 0.6917
# 23m 39s (- 5m 43s) (67000 80%) 0.6346
# 23m 49s (- 5m 32s) (67500 81%) 0.6571
# 24m 0s (- 5m 21s) (68000 81%) 0.6457
# 24m 11s (- 5m 11s) (68500 82%) 0.6880
# 24m 22s (- 5m 0s) (69000 82%) 0.5931
# 24m 32s (- 4m 50s) (69500 83%) 0.6097
# 24m 43s (- 4m 39s) (70000 84%) 0.6028
# 24m 54s (- 4m 29s) (70500 84%) 0.6532
# 25m 5s (- 4m 18s) (71000 85%) 0.6169
# 25m 15s (- 4m 7s) (71500 85%) 0.6116
# 25m 26s (- 3m 57s) (72000 86%) 0.6837
# 25m 37s (- 3m 46s) (72500 87%) 0.6803
# 25m 47s (- 3m 36s) (73000 87%) 0.6549
# 25m 57s (- 3m 25s) (73500 88%) 0.6560
# 26m 8s (- 3m 14s) (74000 88%) 0.6679
# 26m 19s (- 3m 4s) (74500 89%) 0.6246
# 26m 29s (- 2m 53s) (75000 90%) 0.6902
# 26m 40s (- 2m 43s) (75500 90%) 0.6552
# 26m 50s (- 2m 32s) (76000 91%) 0.6465
# 27m 1s (- 2m 21s) (76500 91%) 0.7182
# 27m 11s (- 2m 11s) (77000 92%) 0.6877
# 27m 22s (- 2m 0s) (77500 93%) 0.6540
# 27m 32s (- 1m 50s) (78000 93%) 0.6417
# 27m 43s (- 1m 39s) (78500 94%) 0.7176
# 27m 53s (- 1m 28s) (79000 94%) 0.6835
# 28m 4s (- 1m 18s) (79500 95%) 0.6449
# 28m 14s (- 1m 7s) (80000 96%) 0.6774
# 28m 24s (- 0m 57s) (80500 96%) 0.6120
# 28m 35s (- 0m 46s) (81000 97%) 0.6794
# 28m 45s (- 0m 35s) (81500 97%) 0.6421
# 28m 56s (- 0m 25s) (82000 98%) 0.6319
# 29m 6s (- 0m 14s) (82500 99%) 0.6634
# 29m 17s (- 0m 4s) (83000 99%) 0.6757

# %%
trainIters(encoder1, decoder1, 20000)
# Out:
# 0m 12s (- 8m 5s) (500 2%) 0.5034
# 0m 23s (- 7m 23s) (1000 5%) 0.5359
# 0m 33s (- 6m 53s) (1500 7%) 0.5226
# 0m 43s (- 6m 33s) (2000 10%) 0.4965
# 0m 54s (- 6m 20s) (2500 12%) 0.4582
# 1m 5s (- 6m 8s) (3000 15%) 0.5443
# 1m 15s (- 5m 56s) (3500 17%) 0.5205
# 1m 26s (- 5m 45s) (4000 20%) 0.5056
# 1m 36s (- 5m 34s) (4500 22%) 0.5522
# 1m 47s (- 5m 22s) (5000 25%) 0.4921
# 1m 58s (- 5m 11s) (5500 27%) 0.4934
# 2m 9s (- 5m 1s) (6000 30%) 0.5428
# 2m 20s (- 4m 51s) (6500 32%) 0.5672
# 2m 30s (- 4m 39s) (7000 35%) 0.5393
# 2m 41s (- 4m 28s) (7500 37%) 0.5131
# 2m 51s (- 4m 17s) (8000 40%) 0.5523
# 3m 2s (- 4m 6s) (8500 42%) 0.4874
# 3m 13s (- 3m 55s) (9000 45%) 0.5388
# 3m 23s (- 3m 45s) (9500 47%) 0.6052
# 3m 34s (- 3m 34s) (10000 50%) 0.4958
# 3m 44s (- 3m 23s) (10500 52%) 0.5242
# 3m 55s (- 3m 13s) (11000 55%) 0.5738
# 4m 6s (- 3m 2s) (11500 57%) 0.4944
# 4m 17s (- 2m 51s) (12000 60%) 0.4466
# 4m 27s (- 2m 40s) (12500 62%) 0.4663
# 4m 38s (- 2m 29s) (13000 65%) 0.4443
# 4m 48s (- 2m 18s) (13500 67%) 0.4901
# 4m 59s (- 2m 8s) (14000 70%) 0.4674
# 5m 9s (- 1m 57s) (14500 72%) 0.5203
# 5m 20s (- 1m 46s) (15000 75%) 0.5162
# 5m 31s (- 1m 36s) (15500 77%) 0.4949
# 5m 42s (- 1m 25s) (16000 80%) 0.5133
# 5m 52s (- 1m 14s) (16500 82%) 0.4563
# 6m 3s (- 1m 4s) (17000 85%) 0.5477
# 6m 13s (- 0m 53s) (17500 87%) 0.5042
# 6m 24s (- 0m 42s) (18000 90%) 0.5506
# 6m 34s (- 0m 32s) (18500 92%) 0.4893
# 6m 45s (- 0m 21s) (19000 95%) 0.4755
# 6m 55s (- 0m 10s) (19500 97%) 0.5017
# 7m 5s (- 0m 0s) (20000 100%) 0.4974

# %%
trainIters(encoder1, decoder1, 20000)
# Out:
# 0m 11s (- 7m 46s) (500 2%) 0.4689
# 0m 22s (- 7m 11s) (1000 5%) 0.5135
# 0m 33s (- 6m 52s) (1500 7%) 0.4851
# 0m 44s (- 6m 36s) (2000 10%) 0.5237
# 0m 54s (- 6m 22s) (2500 12%) 0.5028
# 1m 5s (- 6m 10s) (3000 15%) 0.5062
# 1m 16s (- 5m 59s) (3500 17%) 0.5062
# 1m 26s (- 5m 47s) (4000 20%) 0.4796
# 1m 37s (- 5m 36s) (4500 22%) 0.5140
# 1m 47s (- 5m 23s) (5000 25%) 0.5094
# 1m 58s (- 5m 12s) (5500 27%) 0.5567
# 2m 9s (- 5m 1s) (6000 30%) 0.5628
# 2m 20s (- 4m 51s) (6500 32%) 0.5315
# 2m 30s (- 4m 39s) (7000 35%) 0.4901
# 2m 41s (- 4m 28s) (7500 37%) 0.5137
# 2m 51s (- 4m 17s) (8000 40%) 0.5749
# 3m 1s (- 4m 6s) (8500 42%) 0.5137
# 3m 12s (- 3m 55s) (9000 45%) 0.5089
# 3m 22s (- 3m 43s) (9500 47%) 0.4546
# 3m 33s (- 3m 33s) (10000 50%) 0.5209
# 3m 43s (- 3m 22s) (10500 52%) 0.5277
# 3m 54s (- 3m 11s) (11000 55%) 0.5377
# 4m 5s (- 3m 1s) (11500 57%) 0.5984
# 4m 15s (- 2m 50s) (12000 60%) 0.4937
# 4m 26s (- 2m 39s) (12500 62%) 0.5486
# 4m 36s (- 2m 29s) (13000 65%) 0.5474
# 4m 47s (- 2m 18s) (13500 67%) 0.4934
# 4m 58s (- 2m 7s) (14000 70%) 0.5461
# 5m 8s (- 1m 56s) (14500 72%) 0.5135
# 5m 19s (- 1m 46s) (15000 75%) 0.5330
# 5m 29s (- 1m 35s) (15500 77%) 0.4875
# 5m 40s (- 1m 25s) (16000 80%) 0.5152
# 5m 50s (- 1m 14s) (16500 82%) 0.5710
# 6m 1s (- 1m 3s) (17000 85%) 0.4742
# 6m 11s (- 0m 53s) (17500 87%) 0.5354
# 6m 22s (- 0m 42s) (18000 90%) 0.4167
# 6m 32s (- 0m 31s) (18500 92%) 0.5379
# 6m 43s (- 0m 21s) (19000 95%) 0.5235
# 6m 53s (- 0m 10s) (19500 97%) 0.4743
# 7m 4s (- 0m 0s) (20000 100%) 0.5685

# %%
evaluateRandomly(encoder1, decoder1)
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# G_OW_B_IY
# G_OW_B_IY
#
# WILTSIE
# W_IH_L_T_S_IY
# W_IH_L_S_T_IY
#
# HARGRAVES
# HH_AA_R_G_R_EY_V_Z
# HH_AA_R_G_R_EY_V_Z
#
# LINGERING
# L_IH_NG_G_ER_IH_NG
# L_IH_NG_G_ER_IH_NG
#
# PRESSBURGER
# P_R_EH_S_B_ER_G_ER
# P_R_EH_S_B_AH_G_ER
#
# CONSUMED
# K_AH_N_S_UW_M_D
# K_AA_N_S_AH_M_D
#
# DORAVILLE
# D_AO_R_AH_V_IH_L
# D_AO_R_EY_V_ER_L_L_L
#
# PROCUREMENT
# P_R_OW_K_Y_UH_R_M_AH_N_T
# P_R_OW_K_ER_R_M_AH_N_T
#
# WATTERS
# W_AA_T_ER_Z
# W_AE_T_ER_Z
#
# UNDERSECRETARY
# AH_N_D_ER_S_EH_K_R_IH_T_EH_R_IY
# AH_N_D_ER_S_EH_K_T_R_IY_IY_IY
#
# EX-GIRLFRIEND
# EH_K_Z_G_ER_L_F_R_EH_N_D
# EH_G_S_F_EH_R_AH_AH_N_D
#
# HOLLAR
# HH_AA_L_ER
# HH_AA_L_ER
#
# DECAYING
# D_IH_K_EY_IH_NG
# D_IH_K_EY_IH_NG
#
# CHILDCARE
# CH_AY_L_D_K_EH_R
# K_IH_L_D_K_R
#
# MCINTOSH
# M_AE_K_AH_N_T_AO_SH
# M_IH_K_IH_N_SH_AO
#
# BUTTE
# B_Y_UW_T
# B_AH_T
#
# HICKOK
# HH_IH_K_AH_K
# HH_IH_K_AH_K
#
# NOLA
# N_OW_L_AH
# N_OW_L_AA
#
# OUTS
# AW_T_S
# AW_T_S
#
# UNHOOK
# AH_N_HH_UH_K
# AH_N_HH_UH_K
#
# GIESEKE
# G_IY_S_IH_K
# JH_IY_S_K
#
# ALPA
# AE_L_P_AH
# AA_L_P_AH
#
# SPEECHWRITER
# S_P_IY_CH_R_AY_T_ER
# S_P_IY_K_R_AY_T_ER
#
# DEFRANCISCO
# D_IH_F_R_AA_N_CH_IY_S_K_OW
# D_EH_F_R_EY_N_CH_AA_N_S_K_IY
#
# LUKOWSKI
# L_AH_K_AO_F_S_K_IY
# L_UW_K_AO_F_S_K_IY
#
# MAAM
# M_AH_M
# M_AA_M
#
# BEFORT
# B_EH_F_ER_T
# B_IY_F_ER_T
#
# TERHAAR
# T_ER_HH_AA_R
# T_ER_HH_AA_R
#
# HORGAVITT
# HH_AO_R_G_AH_V_IH_T
# HH_AO_R_G_AH_V_IH_T
#
# RECIPROCANTS
# R_IY_S_IH_P_R_AH_K_AH_N_T_S
# R_IY_S_IH_P_R_AA_P_AH_N_T_S
#
# STOECKLE
# S_T_OW_K_AH_L
# S_T_OW_K_AH_L
#
# CORNFELD
# K_AO_R_N_F_EH_L_D
# K_ER_N_F_EH_L_D
#
# LARGESSE
# L_AA_R_G_EH_S
# L_AA_R_G_IY_S
#
# MADOFF
# M_AE_D_AO_F
# M_AE_D_AO_F
#
# X-RAY
# EH_K_S_R_EY
# EH_EH_S_K_EY_R_EY
#
# YAMASAKI
# Y_AA_M_AA_S_AA_K_IY
# Y_AA_M_AA_S_AA_K_IY
#
# INFATUATING
# IH_N_F_AE_CH_UW_EY_T_IH_NG
# IH_N_F_Y_UW_CH_EY_EY_T_NG
#
# CROSSROADS
# K_R_AO_S_R_OW_D_Z
# K_R_OW_S_R_OW_D_Z
#
# BUCKBEE
# B_AH_K_B_IY
# B_AH_K_B_IY
#
# LINEMEN
# L_AY_N_M_AH_N
# L_IH_N_AH_M_AH_N
#
# EISENBERG
# AY_Z_AH_N_B_ER_G
# AY_S_AH_N_B_ER_G
#
# OPULENCE
# AA_P_Y_AH_L_AH_N_S
# OW_P_Y_AH_L_AH_N_N_S
#
# DIGITI
# D_IH_JH_AH_T_AY
# D_IH_JH_IH_T_IY
#
# FOURTEENTH
# F_AO_R_T_IY_N_TH
# F_AO_R_T_IY_TH
#
# LANDRITH
# L_AE_N_D_R_IH_TH
# L_AE_N_D_R_IH_TH
#
# LAMBERTY
# L_AE_M_B_ER_T_IY
# L_AE_M_B_ER_T_IY
#
# BAWLED
# B_AO_L_D
# B_AO_L_AH
#
# GOWEN
# G_AW_AH_N
# G_AW_AH_N
#
# UNPRINTABLE
# AH_N_P_R_IH_N_T_AH_B_AH_L
# AH_N_P_R_AH_T_T_AH_AH_AH_AH_L
#
# PLUNKERS
# P_L_AH_NG_K_ER_Z
# P_L_AH_NG_K_ER_ER_Z
#
# HUMERUS
# HH_Y_UW_M_ER_AH_S
# HH_UW_M_ER_AH_S
#
# KOMISAR
# K_AH_M_IH_S_ER
# K_OW_M_IY_S_ER
#
# AGRONOMISTS
# AH_G_R_AA_N_AH_M_IH_S_T_S
# AH_G_R_UW_N_OW_M_AH_S_T_S_T_S
#
# NONSTANDARD
# N_AA_N_S_T_AE_N_D_ER_D
# N_AA_N_S_T_AA_N_D_AA_R
#
# STASZAK
# S_T_AA_SH_AH_K
# S_T_AA_CH_AH_K
#
# OUTLIVES
# AW_T_L_IH_V_Z
# AW_T_L_AY_V_Z
#
# REPRINTS
# R_IY_P_R_IH_N_T_S
# R_IH_P_R_IH_N_T_S
#
# SHELLING
# SH_EH_L_IH_NG
# SH_EH_L_IH_NG
#
# MICROVAX
# M_AY_K_R_OW_V_AE_K_S
# M_AY_K_R_UW_V_AE_K_S
#
# SPEKTR'S
# S_P_EH_K_T_ER_Z
# S_P_EH_K_T_ER_Z
#
# FRONTRUNNERS
# F_R_AH_N_T_R_AH_N_ER_Z
# F_R_AA_N_T_N_ER_Z
#
# COUSINS
# K_AH_Z_AH_N_Z
# K_AW_Z_IH_N_Z
#
# KRASNER
# K_R_AE_S_N_ER
# K_R_AE_S_N_ER
#
# OESTERREICH
# OW_S_T_ER_AY_K
# OW_S_T_CH_R_IH
#
# DREIS
# D_R_IY_Z
# D_R_AY_Z
#
# SCHLESWIG
# SH_L_EH_S_W_IH_G
# SH_L_EH_S_W_IH_G
#
# OLEXA
# AH_L_IY_K_S_AH
# OW_L_EH_K_S_AH
#
# MCCOWEN
# M_AH_K_AW_AH_N
# M_AH_K_AW_N
#
# MERNICK
# M_ER_N_IH_K
# M_ER_N_IH_K
#
# PAKULSKI
# P_AH_K_AH_L_S_K_IY
# P_AH_K_AH_L_S_K_IY
#
# RADIOGRAPHY
# R_EY_D_IY_AA_G_R_AH_F_IY
# R_AE_D_IY_G_R_AH_F_IY
#
# ALLAHABAD
# AH_L_AA_HH_AH_B_AA_D
# AH_L_AH_B_HH_AE_B
#
# SHINALL
# SH_IH_N_AH_L
# SH_IH_N_AH_L
#
# ABIAM'S
# EY_B_IY_AH_M_Z
# EY_B_IY_AH_M_Z
#
# CROVITZ'S
# K_R_OW_V_IH_T_S_IH_Z
# K_R_AA_V_IH_T_S
#
# CUNLIFFE
# K_AH_N_L_IH_F
# K_AH_N_L_AY_F
#
# EPROMS
# EH_P_R_AH_M_Z
# EH_P_R_AH_M_Z
#
# SCRAMBLE
# S_K_R_AE_M_B_AH_L
# S_K_R_AE_M_B_AH_L
#
# SCHWERNER
# SH_W_ER_N_ER
# SH_W_ER_N_ER
#
# UPRIGHT
# AH_P_R_AY_T
# AH_P_R_AY_T
#
# SUPERPREMIUM
# S_UW_P_ER_P_R_IY_M_IY_AH_M
# S_UW_P_ER_M_R_R_UW_AH_M_AH
#
# FRUITION
# F_R_UW_IH_SH_AH_N
# F_R_UW_EY_SH_AH_N
#
# KRUK
# K_R_AH_K
# K_R_AH_K
#
# DEHUMANIZED
# D_IH_HH_Y_UW_M_AH_N_AY_Z_D
# D_AY_HH_Y_AH_M_AH_N_AY_Z_D
#
# IGLESIAS
# IH_G_L_EY_S_IY_IH_S
# IH_G_L_IY_SH_IY
#
# CERVICAL
# S_ER_V_AH_K_AH_L
# S_ER_V_IH_K_AH_L
#
# BERKLEE
# B_ER_K_L_IY
# B_ER_K_AH_IY
#
# HENPECK
# HH_EH_N_P_EH_K
# HH_EH_N_P_IH_K
#
# CO
# K_OW
# K_OW
#
# PAINTS
# P_EY_N_T_S
# P_EY_N_T_S
#
# GLOECKNER
# G_L_OW_K_N_ER
# G_L_OW_K_N_ER
#
# NEPHEWS
# N_EH_F_Y_UW_Z
# N_EH_F_OW_Z
#
# ALAMEDA
# AE_L_AH_M_IY_D_AH
# AE_L_AA_M_IY_D_AH
#
# TALLERICO
# T_AA_L_ER_IY_K_OW
# T_AE_L_ER_R_IY_OW
#
# HIGLEY
# HH_IH_G_L_IY
# HH_IH_G_L_IY
#
# HERMIE
# HH_ER_M_IY
# HH_ER_M_IY
#
# DUNKER
# D_AH_NG_K_ER
# D_AH_NG_K_ER
#
# KONOP
# K_OW_N_AH_P
# K_AA_N_AH_P
#
# WITTER
# W_IH_T_ER
# W_IH_T_ER
#
# COTIJA
# K_OW_T_IY_JH_AH
# K_OW_T_AY_Y_AH
#
# CENTERED
# S_EH_N_T_ER_D
# S_EH_N_T_ER_D_D
#
# GEOMAGNETIC
# JH_IY_OW_M_AE_G_N_EH_T_IH_K
# G_UW_UW_M_AE_N_T_T_T_IH
#
# NEGATIVES
# N_EH_G_AH_T_IH_V_Z
# N_EH_G_AH_T_EY_V_Z
#
# LEVINER
# L_EH_V_IH_N_ER
# L_EH_V_AY_N_ER
#
# HAUSA
# HH_AW_S_AH
# HH_AO_S_AH
#
# PROSECUTORS
# P_R_AA_S_IH_K_Y_UW_T_ER_Z
# P_R_OW_S_AH_K_Y_UW_T_ER_Z
#
# DILUTED
# D_AY_L_UW_T_AH_D
# D_IH_L_AH_T_AH_D
#
# DIOXIDE
# D_AY_AA_K_S_AY_D
# D_AY_AH_AH_S_AY_D
#
# ESTABLISHES
# IH_S_T_AE_B_L_IH_SH_IH_Z
# EH_S_T_AE_B_L_IH_SH_IH_Z
#
# ADDED
# AE_D_IH_D
# AE_D_AH
#
# INDISCREET
# IH_N_D_IH_S_K_R_IY_T
# IH_N_D_IH_S_K_R_IH_T
#
# PHILHARMONIA
# F_IH_L_HH_AA_R_M_OW_N_IY_AH
# F_IH_L_HH_OW_M_AA_R_IY_IY_IY_AH
#
# DOFFING
# D_AO_F_IH_NG
# D_AO_F_IH_NG
#
# LINDBECK
# L_AY_N_D_B_EH_K
# L_IH_N_D_B_EH
#
# PROGNOSTICATIVE
# P_R_AA_G_N_AA_S_T_AH_K_EY_T_IH_V
# P_R_AA_G_N_AH_K_T_EY_T_T_V
#
# HOPPA
# HH_AA_P_AH
# HH_AA_P_AH
#
# CLOCKER
# K_L_AA_K_ER
# K_L_AA_K_ER
#
# AITKEN
# AY_T_K_AH_N
# EY_K_AH_AH_N
#
# PLEASES
# P_L_IY_Z_IH_Z
# P_L_IY_Z_AH_Z
#
# YIGAL
# Y_IH_G_AE_L
# AY_G_G_AH_L
#
# ORSBORN
# AO_R_S_B_ER_N
# AO_R_S_B_ER_N
#
# EXTRUDING
# IH_K_S_T_R_UW_D_IH_NG
# EH_K_S_T_R_UW_D_NG
#
# LEGAN
# L_EH_G_AH_N
# L_EH_G_AH_N
#
# HONOURABLE
# AA_N_ER_AH_B_AH_L
# HH_AA_N_R_OW_B_AH_L_AH_L
#
# BUGAI'S
# B_Y_UW_G_AY_Z
# B_UW_G_EY_Z
#
# AMONGST
# AH_M_AH_NG_S_T
# AH_M_AO_NG_S_T
#
# NOLETA
# N_OW_L_EH_T_AH
# N_OW_L_EH_T_AH
#
# BUMBLING
# B_AH_M_B_AH_L_IH_NG
# B_AH_M_B_L_L_IH_NG
#
# DUSTMAN
# D_AH_S_T_M_AH_N
# D_AH_S_M_AH_AH_N
#
# ROMANOSKI
# R_AH_M_AH_N_AW_S_K_IY
# R_OW_M_AE_N_AA_S_K_IY
#
# CROATIANS
# K_R_OW_EY_SH_AH_N_Z
# K_R_OW_SH_AH_N_Z
#
# SINGLE-HANDED
# S_IH_NG_G_AH_L_HH_AE_N_D_IH_D
# S_IH_NG_G_L_AH_HH_AE_N_D_AH_D
#
# GALLING
# G_AO_L_IH_NG
# G_AE_L_IH_NG
#
# ALTERATIONS
# AO_L_T_ER_EY_SH_AH_N_Z
# AE_L_T_ER_EY_SH_AH_N_Z
#
# ROCHAT
# R_AA_CH_AH_T
# R_AA_K_AH_T
#
# COTIJA
# K_OW_T_IY_JH_AH
# K_OW_T_Y_AH
#
# SINGED
# S_IH_N_JH_D
# S_IH_NG_D
#
# MARINATES
# M_EH_R_AH_N_EY_T_S
# M_EH_R_AH_N_EY_T_S
#
# NEWINGHAM
# N_UW_IH_NG_HH_AE_M
# N_UW_HH_IH_NG_HH_AE_M
#
# HARMONIZE
# HH_AA_R_M_AH_N_AY_Z
# HH_AA_R_M_AH_N_AY_Z
#
# DISCOUNTER
# D_IH_S_K_AW_N_T_ER
# D_IH_S_K_AW_ER_ER
#
# RAUT
# R_AW_T
# R_AO_T
#
# BRANDENBURGER
# B_R_AE_N_D_AH_N_B_ER_G_ER
# B_R_AE_N_D_AH_N_B_ER_G_ER
#
# HEBDA
# HH_EH_B_D_AH
# HH_EH_B_D_AH
#
# REDACTED
# R_IH_D_AE_K_T_IH_D
# R_IH_D_AH_K_T_IH_D_D
#
# HORDES
# HH_AO_R_D_Z
# HH_AO_R_D_Z
#
# MCALEESE'S
# M_AH_K_AH_L_IY_S_IY_Z
# M_AH_K_AA_L_IY_Z_IY_Z
#
# MULTIPLYING
# M_AH_L_T_AH_P_L_AY_IH_NG
# M_AH_L_T_AH_P_AH_L_IH_NG
#
# SESSION
# S_EH_SH_AH_N
# S_EH_SH_AH_N
#
# JIGGLING
# JH_IH_G_AH_L_IH_NG
# JH_IH_G_L_L_NG
#
# PROSTHETICS
# P_R_AA_S_TH_EH_T_IH_K_S
# P_R_AA_S_TH_EH_T_IH_K_S
#
# NOVELLA
# N_OW_V_EH_L_AH
# N_OW_V_EH_L_AH
#
# TORTURED
# T_AO_R_CH_ER_D
# T_AO_R_CH_ER
#
# NUT
# N_AH_T
# N_AH_N
#
# MARWICK
# M_AA_R_W_IH_K
# M_AA_R_W_IH_K
#
# LLAMAS
# L_AA_M_AH_Z
# L_AA_M_AA_Z
#
# KANTZ
# K_AE_N_T_S
# K_AE_N_T_S
#
# STILLINGER
# S_T_IH_L_IH_NG_ER
# S_T_IH_L_IH_NG_ER
#
# BONICA
# B_AA_N_IH_K_AH
# B_AA_N_IH_K_AH
#
# BROMIDE
# B_R_OW_M_AY_D
# B_R_AA_M_AY_D
#
# GRANITIC
# G_R_AH_N_IH_T_IH_K
# G_R_AE_N_IH_T_T_K
#
# JAPANESE
# JH_AE_P_AH_N_IY_Z
# JH_AH_P_AA_N_IY_Z
#
# RYBAKOV
# R_AY_B_AH_K_AA_V
# R_AY_B_AH_K_AA_V
#
# RUBBISH
# R_AH_B_IH_SH
# R_AH_B_IH_SH
#
# BAUGH
# B_AO
# B_AO
#
# DONALD
# D_AA_N_AH_L_D
# D_OW_N_AH_L_D
#
# PLATFORMS
# P_L_AE_T_F_AO_R_M_Z
# P_L_AE_T_F_ER_M_Z
#
# NAKHAMKIN
# N_AE_K_AE_M_K_IH_N
# N_AA_K_M_M_S_AH_N
#
# DOMAN
# D_UW_M_AH_N
# D_OW_M_AH_N
#
# VINIK'S
# V_IH_N_IH_K_S
# V_IH_N_IH_K_S
#
# VANDECAR
# V_AE_N_D_AH_K_AA_R
# V_AE_N_D_EH_K_AA_R
#
# DUDECK'S
# D_UW_D_EH_K_S
# D_UW_D_EH_K_S
#
# KLUTZNICK
# K_L_AH_T_S_N_IH_K
# K_L_AH_T_S_IH_IH_K
#
# COBRAS
# K_OW_B_R_AH_Z
# K_AH_B_R_AH_Z
#
# WOULD'VE
# W_UH_D_AH_V
# W_UH_L_D_V
#
# LANE'S
# L_EY_N_Z
# L_EY_N_Z
#
# ARMINIE
# AA_R_M_IH_N_IY
# AA_R_M_IY_N_IY
#
# MARIE'S
# M_ER_IY_Z
# M_AA_R_IY_Z
#
# PHU
# F_UW
# F_UW_UW
#
# VIGILIA
# V_IY_JH_IY_L_IY_AH
# V_IH_G_IY_L_IY_AH
#
# HOVSEPIAN
# HH_AH_V_S_IY_P_IY_AH_N
# HH_OW_V_S_IY_P_IY_AH_N
#
# FLUFFIER
# F_L_AH_F_IY_ER
# F_L_AH_F_ER_ER
#
# VOLITION
# V_OW_L_IH_SH_AH_N
# V_AA_L_IH_SH_AH_N
#
# RENOUNCES
# R_IH_N_AW_N_S_IH_Z
# R_IY_N_AW_N_S_IH_Z
#
# INTERGRAPH'S
# IH_N_T_ER_G_R_AE_F_S
# IH_N_T_ER_G_R_AE_F_S
#
# TAMP
# T_AE_M_P
# T_AE_M_P
#
# TRANSPORT
# T_R_AE_N_S_P_AO_R_T
# T_R_AE_N_S_P_AO_R_T
#
# DELSANTO
# D_EH_L_S_AA_N_T_OW
# D_EH_L_S_AA_N_T_T
#
# GOEDERT
# G_OW_D_ER_T
# G_OW_D_ER_T
#
# GROUPERS
# G_R_UW_P_ER_Z
# G_R_UW_P_ER_Z
#
# LAEVO
# L_EY_V_OW
# L_IY_V_OW
#
# XENOS
# Z_IY_N_OW_Z
# Z_IY_N_OW_Z
#
# DAH
# D_AH
# D_AA
#
# LETHAL
# L_IY_TH_AH_L
# L_EH_TH_AH_L
#
# INLET
# IH_N_L_EH_T
# IH_N_L_AH_T
#
# BIEV
# B_IY_V
# B_IY_V
#
# SOPHISTICATION
# S_AH_F_IH_S_T_AH_K_EY_SH_AH_N
# S_AA_F_IH_S_T_EY_SH_AH_N
#
# ACCESSORIZE
# AE_K_S_EH_S_ER_AY_Z
# AH_K_AH_S_ER_AY_Z_AY
#
# MATTKE
# M_AE_T_K_IY
# M_AE_T_K
#
# MCCREDIE
# M_AH_K_R_IY_D_IY
# M_AH_K_R_IY_D_IY
#
# FARVE
# F_AA_R_V_EY
# F_AA_R_V
#
# TURBEVILLE
# T_ER_B_V_IH_L
# T_ER_B_ER_V_AH_L
#
# OXIDIZING
# AA_K_S_AH_D_AY_Z_IH_NG
# AA_K_Z_AY_D_AY_Z_IH_NG
#
# LEV
# L_EH_V
# L_EH_V
#
# TAGS
# T_AE_G_Z
# T_AE_G_Z
#
# RESEARCHES
# R_IY_S_ER_CH_IH_Z
# R_IY_S_ER_CH_IY_Z
#
# OKRAY
# AA_K_R_EY
# AA_K_R_EY
#
# FEEBACK
# F_IY_B_AE_K
# F_IY_B_AH_K
#
# TURNS
# T_ER_N_Z
# T_ER_N_Z
#
# PURITANISMS
# P_Y_UH_R_AH_T_AH_N_IH_Z_AH_M_Z
# P_UH_R_IH_T_AH_N_IH_Z_AH_M
#
# KILLMAN'S
# K_IH_L_M_AH_N_Z
# K_IH_L_M_AH_N_Z
#
# CONSTANT'S
# K_AA_N_S_T_AH_N_T_S
# K_AA_N_S_T_AA_N_T_S
#
# HOLLYHOCK
# HH_AA_L_IY_HH_AA_K
# HH_OW_L_HH_AA_K
#
# CONCLUSIONS
# K_AH_N_K_L_UW_ZH_AH_N_Z
# K_AH_NG_K_W_Z_SH_AH_N_Z
#
# RANTING
# R_AE_N_T_IH_NG
# R_AE_N_T_IH_NG
#
# DOWNTOWN'S
# D_AW_N_T_AW_N_Z
# D_AW_N_T_AW_N_Z
#
# THIESEN
# TH_IY_S_AH_N
# TH_IY_S_AH_N
#
# ELECTROMAGNETS
# IH_L_EH_K_T_R_OW_M_AE_G_N_AH_T_S
# EY_L_EH_K_R_EY_M_EY_G_T_AH_T_S
#
# SCHMALTZ
# SH_M_AA_L_T_S
# SH_L_AE_M_T_S
#
# PLUMBING
# P_L_AH_M_IH_NG
# P_L_AH_M_B_NG
#
# KATSUHIKO
# K_AA_T_S_UW_HH_IY_K_OW
# K_AE_T_S_UW_CH_IY_K_OW
#
# MCGOVERN'S
# M_AH_G_AH_V_ER_N_Z
# M_AH_G_AH_V_ER_N_Z
#
# BAYNES
# B_EY_N_Z
# B_EY_N_Z
#
# DEMILITARIZED
# D_IY_M_IH_L_AH_T_ER_AY_Z_D
# D_EH_M_AH_L_AH_AY_AY_Z_D
#
# SYNCHRONIZATION
# S_IH_NG_K_R_AH_N_AH_Z_EY_SH_AH_N
# S_IH_NG_K_R_AH_S_AH_N_EY_SH_AH_N
#
# LOUGHRY
# L_AW_R_IY
# L_AO_R_IY
#
# CECALA
# CH_EH_K_AA_L_AH
# CH_EH_K_AA_L_AH
#
# MRAZ
# M_R_AE_Z
# R_AE_Z
#
# WAID
# W_EY_D
# W_EY_D
#
# DARMAN'S
# D_AA_R_M_AH_N_Z
# D_AA_R_M_AH_N_Z
#
# PROLIFERATION
# P_R_OW_L_IH_F_ER_EY_SH_AH_N
# P_R_OW_L_AH_F_ER_EY_SH_AH_N
#
# RAYBURN'S
# R_EY_B_ER_N_Z
# R_EY_B_ER_N_Z
#
# STOCKBROKERS'
# S_T_AA_K_B_R_OW_K_ER_Z
# S_T_AA_K_B_B_B_R_OW_ER_Z
#
# COSLETT
# K_AA_S_L_IH_T
# K_AA_S_L_IH_T
#
# SHEAFFER
# SH_IY_F_ER
# SH_EH_F_ER
#
# FINKEN
# F_IH_NG_K_AH_N
# F_IH_NG_K_AH_N
#
# SARATOGA
# S_EH_R_AH_T_OW_G_AH
# S_AA_R_EY_T_OW_G_AH
#
# MANSKE
# M_AE_N_S_K
# M_AE_NG_S_K_IY
#
# PANEL
# P_AE_N_AH_L
# P_AE_N_AH_L
#
# AFFIXES
# AE_F_IH_K_S_IH_Z
# AE_F_IH_K_S_IH_Z
#
# PROFETA
# P_R_OW_F_EH_T_AH
# P_R_OW_F_EH_T_AH
#
# DAURIA
# D_AO_R_IY_AH
# D_AO_R_IY_AH
#
# DEES
# D_IY_Z
# D_IY_Z
#
# SYNOPTIC
# S_IH_N_AA_P_T_IH_K
# S_IH_N_AA_T_T_T_T
#
# VANDUZER
# V_AE_N_D_UW_Z_ER
# V_AE_N_D_Y_UW_Z_ER
#
# DELETERIOUS
# D_EH_L_AH_T_IH_R_IY_AH_S
# D_IH_L_IH_SH_AH_R_EH_S
#
# ABOHALIMA
# AE_B_AH_HH_AH_L_IY_M_AH
# OW_B_OW_HH_OW_L_IH_M_AH
#
# THEORIZES
# TH_IY_ER_AY_Z_IH_Z
# TH_ER_IY_AY_AY_Z
#
# BONUS
# B_OW_N_AH_S
# B_OW_N_AH_S
#
# KRAHL
# K_R_AA_L
# K_R_AA_L
#
# MCKANE
# M_AH_K_EY_N
# M_AH_K_EY_N
#
# UNTHINKING
# AH_N_TH_IH_NG_K_IH_NG
# AH_N_TH_AH_K_IH_NG
#
# ASHCREEK
# AE_SH_K_R_IY_K
# AE_SH_K_R_IY_K
#
# VERNACULAR
# V_ER_N_AE_K_Y_AH_L_ER
# V_EH_R_N_AE_K_Y_AH_L_ER
#
# SIGURD
# S_IH_G_ER_D
# S_AY_G_ER_D
#
# SONES
# S_OW_N_Z
# S_OW_N_Z
#
# FUMED
# F_Y_UW_M_D
# F_Y_UW_M_D
#
# JUDGEMENT
# JH_AH_JH_M_AH_N_T
# JH_AH_JH_M_AH_N_T_N_T
#
# ASTUTE
# AH_S_T_UW_T
# AH_S_T_UW_T
#
# MERCOSUR
# M_ER_K_OW_S_ER
# M_EH_R_K_OW_S_ER
#
# TECHNOCRATS
# T_EH_K_N_AH_K_R_AE_T_S
# T_EH_K_N_OW_K_AA_R_T_S
#
# GILDA
# G_IH_L_D_AH
# G_IH_L_D_AH
#
# GRONLUND
# G_R_AA_N_L_AH_N_D
# G_R_AA_N_L_AH_N_D
#
# NAPHTHA
# N_AE_F_TH_AH
# N_AA_F_T_AH
#
# ROKA
# R_OW_K_AH
# R_OW_K_AH
#
# BARANY
# B_ER_AO_N_IY
# B_AA_R_AH_N_IY
#
# FISHKIN
# F_IH_SH_K_IH_N
# F_IH_SH_K_IH_N
#
# TELACTION
# T_EH_L_AE_K_SH_AH_N
# T_EH_L_AE_K_SH_AH_N
#
# UNLABELED
# AH_N_L_EY_B_AH_L_D
# AH_N_AH_AH_B_AH_L_AH
#
# TIRADES
# T_AY_R_EY_D_Z
# T_AY_R_EY_D_Z
#
# GROHMAN
# G_R_OW_M_AH_N
# G_R_OW_M_AH_N
#
# EVANESCENT
# EH_V_AH_N_EH_S_AH_N_T
# IH_V_EY_N_S_AH_N_N_N_T
#
# ABDUL
# AE_B_D_UW_L
# AE_B_AH_L
#
# PATENTABLE
# P_AE_T_AH_N_T_AH_B_AH_L
# P_AE_T_EH_N_T_AH_B_AH_L_AH_L
#
# PALOMO
# P_AA_L_OW_M_OW
# P_AA_L_OW_M_OW
#
# REICHLE
# R_AY_K_AH_L
# R_AY_K_AH_L
#
# HAWBAKER
# HH_AO_B_EY_K_ER
# HH_AO_B_EY_K_ER
#
# CONLON
# K_AA_N_L_AH_N
# K_AA_N_L_AH_N
#
# POLITY
# P_AA_L_AH_T_IY
# P_OW_L_AH_T_IY
#
# FREEHOFF'S
# F_R_IY_HH_AO_F_S
# F_R_IY_HH_AO_F_S
#
# MISFORTUNES
# M_IH_S_F_AO_R_CH_AH_N_Z
# M_IH_S_F_ER_AO_T_T_Z
#
# DELAP
# D_EH_L_AH_P
# D_EH_L_AA_P
#
# SWARD
# S_W_AO_R_D
# S_W_AO_R_D
#
# ICEBOX
# AY_S_B_AA_K_S
# AY_K_B_K_S
#
# NONEMERGENCY
# N_AA_N_IH_M_ER_JH_AH_N_S_IY
# N_AA_M_EH_M_ER_AH_N_S_IY
#
# SANT
# S_AE_N_T
# S_AE_N_T
#
# SCHOLARSHIP
# S_K_AA_L_ER_SH_IH_P
# S_K_AA_L_AA_R_SH_IH_P
#
# NOVOSAD
# N_AA_V_AH_S_AE_D
# N_OW_V_OW_S_AH_D
#
# FOEHLICH
# F_OW_L_IH_CH
# F_OW_L_L_K
#
# IANTHE
# IY_AA_N_TH_EY
# AY_N_TH
#
# ACIDIC
# AH_S_IH_D_IH_K
# AH_S_IH_D_IH_K
#
# HISPANICS
# HH_IH_S_P_AE_N_IH_K_S
# HH_IH_S_P_AE_N_IH_K_S
#
# FACELIFT
# F_EY_S_L_IH_F_T
# F_AH_S_EH_L_IH_F_T
#
# PRIMAL
# P_R_AY_M_AH_L
# P_R_AY_M_AH_L
#
# PRECIPITOUS
# P_R_IH_S_IH_P_IH_T_AH_S
# P_R_IH_CH_IH_P_IH_T_AH_S
#
# HARK
# HH_AA_R_K
# HH_AA_R_K
#
# PROSTHETIC
# P_R_AA_S_TH_EH_T_IH_K
# P_R_AA_S_TH_EH_T_IH_K
#
# PALUCH
# P_AE_L_AH_K
# P_AE_L_UW_K
#
# READOUT
# R_IY_D_AW_T
# R_IY_D_OW_T
#
# BOAKE
# B_OW_K
# B_OW_K
#
# JANEANE
# JH_EY_N_AE_N
# JH_EY_N_IY_N_IY
#
# FRIONA
# F_R_IY_OW_N_AH
# F_R_AY_OW_N_AH
#
# SEABERRY
# S_IY_B_EH_R_IY
# S_IY_B_ER_IY
#
# UNDERDEVELOPMENT
# AH_N_D_ER_D_AH_V_EH_L_AH_P_M_AH_N_T
# AH_N_V_ER_M_AH_L_D_AH_M_P_D_N_T_AH_N_T
#
# MANCILLA
# M_AE_N_S_IH_L_AH
# M_AE_N_CH_IH_L_AH
#
# UTHER
# Y_UW_TH_ER
# AH_TH_ER
#
# MATSUSHITA'S
# M_AA_T_S_UW_SH_IY_T_AH_Z
# M_AE_T_T_UW_CH_AH_T_AH_Z
#
# MUSSOLINI'S
# M_UW_S_OW_L_IY_N_IY_Z
# M_UW_S_OW_L_IY_N_IY_Z
#
# PERSECUTION
# P_ER_S_AH_K_Y_UW_SH_AH_N
# P_ER_S_AH_K_SH_AH_N
#
# INAKI
# IH_N_AA_K_IY
# IH_N_AA_K_IY
#
# GUERINO
# G_EH_R_IY_N_OW
# G_ER_IY_N_OW
#
# DETAINING
# D_IH_T_EY_N_IH_NG
# D_IH_T_EY_N_NG
#
# JEANES
# JH_IY_N_Z
# JH_IY_N_Z
#
# TRANSCONTINENTAL
# T_R_AE_N_Z_K_AA_N_T_IH_N_EH_N_T_AH_L
# T_R_AE_N_S_K_K_S_AH_N_T_AH_AH_L
#
# GRAYBEAL
# G_R_EY_B_AH_L
# G_R_EY_B_AH_L
#
# BAILEY
# B_EY_L_IY
# B_EY_L_IY
#
# DEROCHER
# D_EH_R_AH_K_ER
# D_EH_R_AH_K_ER
#
# ENCOR
# EH_N_K_AO_R
# EH_N_K_ER_R
#
# NICKY
# N_IH_K_IY
# N_IH_K_IY
#
# SERRATO
# S_ER_AA_T_OW
# S_EH_R_AA_T_OW
#
# ZEGERS
# Z_IY_G_ER_Z
# Z_IH_G_ER_Z
#
# MOLDABLE
# M_OW_L_D_AH_B_AH_L
# M_OW_L_D_AH_B_AH_L
#
# PATRICIANS
# P_AH_T_R_IH_SH_AH_N_Z
# P_AH_T_R_IH_SH_AH_N_Z
#
# TIJUANA
# T_IH_W_AA_N_AH
# T_IH_Y_UW_N_AH
#
# ELLWOOD
# EH_L_W_UH_D
# EH_L_W_UH_D
#
# RICHENTHAL
# R_IH_K_AH_N_TH_AO_L
# R_IH_K_AH_N_TH_AO_L
#
# TIMMS
# T_IH_M_Z
# T_IH_M_Z
#
# LITTLEFIELD
# L_IH_T_AH_L_F_IY_L_D
# L_IH_T_F_IH_L_EH_L_D
#
# ESTONIAN
# EH_S_T_OW_N_IY_AH_N
# EH_S_T_OW_N_IY_AH_N
#
# MENNAN
# M_EH_N_AH_N
# M_EH_N_AH_N
#
# MODEL'S
# M_AA_D_AH_L_Z
# M_OW_D_AH_L_Z
#
# SMOKEJUMPERS
# S_M_OW_K_JH_AH_M_P_ER_Z
# S_K_OW_K_AH_M_P_ER_Z
#
# GORDON'S
# G_AO_R_D_AH_N_Z
# G_AO_R_D_AH_N_Z
#
# AGING
# EY_JH_IH_NG
# AE_JH_IH_NG
#
# RADDE
# R_AE_D
# R_AE_D
#
# BEHELD
# B_IY_HH_EH_L_D
# B_EH_HH_EH_L_D
#
# KOLINSKI
# K_AH_L_IH_N_S_K_IY
# K_AH_L_IH_N_S_K_IY
#
# ATTABOY
# AE_T_AH_B_OY
# AE_T_AH_B_OY
#
# EDPER
# EH_D_P_ER
# EH_D_P_ER
#
# ATHLETICS
# AE_TH_L_EH_T_IH_K_S
# AE_TH_F_L_T_T_K_S
#
# GUARDIAN
# G_AA_R_D_IY_AH_N
# G_AA_R_D_IY_AH_N
#
# WARREN
# W_AO_R_AH_N
# W_AO_R_AH_N
#
# JACKRABBIT
# JH_AE_K_R_AE_B_AH_T
# JH_AE_K_R_AH_B_IH_T
#
# TROSCLAIR
# T_R_AH_S_K_L_EH_R
# T_R_OW_S_K_L_R_EY
#
# KOMABA
# K_OW_M_AA_B_AH
# K_OW_M_AA_B_AH
#
# PEPPIN
# P_EH_P_IH_N
# P_EH_P_IH_N
#
# VOUCHERS
# V_AW_CH_ER_Z
# V_AW_CH_ER_Z
#
# LEVCHENKO
# L_EH_V_CH_EH_NG_K_OW
# L_EH_V_CH_EH_N_K_OW
#
# KNORR
# N_AO_R
# N_AO_R
#
# BREN
# B_R_EH_N
# B_R_EH_N
#
# PHILOSOPHICAL
# F_IH_L_AH_S_AA_F_IH_K_AH_L
# F_IH_L_OW_S_AH_K_AH_K_AH_L
#
# BOTRYTIS
# B_AH_T_R_IH_T_IH_S
# B_AA_T_R_IH_T_IH_S
#
# GOUGE
# G_AW_JH
# G_OW_JH
#
# UNSATISFACTORY
# AH_N_S_AH_T_IH_S_F_AE_K_T_ER_IY
# AH_N_S_AH_F_AH_K_T_R_R_K
#
# AFFILIATING
# AH_F_IH_L_IY_EY_T_IH_NG
# AH_F_IH_L_EY_EY_EY_NG
#
# MONTREALERS
# M_AH_N_T_R_IY_AO_L_ER_Z
# M_AA_N_T_T_R_IY_ER
#
# AMANDAS
# AH_M_AE_N_D_AH_Z
# AH_M_AE_N_D_AH_Z
#
# SUPPOSITION
# S_AH_P_AH_Z_IH_SH_AH_N
# S_AH_P_OW_Z_IY_SH_AH_N
#
# ZAPATISTA'S
# Z_AA_P_AH_T_IY_S_T_AH_Z
# Z_AH_P_AA_T_IY_T_AH_AH_S
#
# FARVE
# F_AA_R_V_EY
# F_AA_R_V
#
# OCCUPIES
# AA_K_Y_AH_P_AY_Z
# AH_K_UW_P_IY_Z
#
# JACOBEAN
# JH_AE_K_AH_B_IY_AH_N
# JH_AE_K_AH_B_IY_AH_N
#
# HOUSE
# HH_AW_S
# HH_AW_S
#
# CUTTING-EDGE
# K_AH_T_IH_NG_EH_JH
# K_AH_T_IH_N_T_IH_JH
#
# WEBSITE'S
# W_EH_B_S_AY_T_S
# W_EH_B_S_AY_T_S
#
# OVERWORKING
# OW_V_ER_W_ER_K_IH_NG
# OW_V_ER_K_AO_R_IH_NG
#
# ROZANSKI
# R_AH_Z_AE_N_S_K_IY
# R_OW_Z_AE_N_S_K_IY
#
# WHEEZING
# W_IY_Z_IH_NG
# W_IY_Z_IH_NG
#
# ATORINO
# AE_T_ER_IY_N_OW
# AH_T_AO_R_IY_N
#
# SPOERL
# S_P_AO_R_L
# S_P_OW_ER_L
#
# SNAKE'S
# S_N_EY_K_S
# S_N_EY_K_S
#
# HOMEWOOD
# HH_OW_M_W_UH_D
# HH_OW_M_W_UH
#
# DISCLOSING
# D_IH_S_K_L_OW_Z_IH_NG
# D_IH_S_K_L_L_IH_NG
#
# MCCUTCHEN
# M_AH_K_AH_CH_AH_N
# M_AH_K_AH_CH_AH_N
#
# JIRAK
# JH_IH_R_AE_K
# Y_IH_R_AH_K
#
# CANDY
# K_AE_N_D_IY
# K_AE_N_D_IY
#
# SCHAUMBURG
# SH_AW_M_B_ER_G
# SH_AO_M_B_ER_G
#
# MEDCO'S
# M_EH_D_K_OW_Z
# M_EH_D_OW_OW_Z
#
# COMPARISON
# K_AH_M_P_EH_R_AH_S_AH_N
# K_AH_M_P_EH_R_IH_SH_AH_N
#
# KUNA
# K_Y_UW_N_AH
# K_UW_UW_AH
#
# PROMINENTLY
# P_R_AA_M_AH_N_AH_N_T_L_IY
# P_R_AA_M_AH_N_AH_N_T_L_IY
#
# LINE-UP
# L_AY_N_AH_P
# L_AY_N_AH_P
#
# BALBOA
# B_AA_L_B_OW_AH
# B_AE_L_B_OW_AH
#
# HEEKE
# HH_IY_K
# HH_IY_K
#
# PAGE'S
# P_EY_JH_IH_Z
# P_EY_JH_IY_Z
#
# BINDLEY
# B_IH_N_D_L_IY
# B_IH_N_D_L_IY
#
# SUBJECTS'
# S_AH_B_JH_EH_K_T_S
# S_AH_B_B_EH_K_T_S
#
# ANGERT
# EY_NG_G_ER_T
# AE_NG_G_ER_T
#
# MAITI
# M_EY_T_IY
# M_EY_T_IY
#
# BIOPHYSICS
# B_AY_OW_F_IH_S_IH_K_S
# B_AY_F_IH_S_IH_K_S
#
# WELP
# W_EH_L_P
# W_EH_L_P
#
# DELINE
# D_EH_L_IY_N_IY
# D_IH_L_IY_N_IY
#
# WOLBER
# W_OW_L_B_ER
# W_OW_L_B_ER
#
# LEPISTO
# L_EH_P_IY_S_T_OW
# L_EH_P_IY_S_T
#
# NORDELL
# N_AO_R_D_AH_L
# N_AO_R_D_AH_L
#
# KOTZEBUE
# K_AA_T_S_AH_B_Y_UW
# K_AA_T_Z_AH_B_UW
#
# CHAIDEZ
# CH_AA_IY_D_EH_Z
# CH_EY_D_EH_Z
#
# ADAMSTOWN
# AE_D_AH_M_S_T_AW_N
# AE_D_AH_M_S_T_AW_N
#
# DYANA
# D_AY_AE_N_AH
# D_AY_N_N_AH
#
# TICKETING
# T_IH_K_AH_T_IH_NG
# T_IH_K_AH_T_IH_NG
#
# UNIFORM
# Y_UW_N_AH_F_AO_R_M
# Y_UW_N_IH_F_AO_R_M
#
# BIGELOW'S
# B_IH_G_AH_L_OW_Z
# B_IH_JH_IY_L_OW_Z
#
# REGRETFULLY
# R_IH_G_R_EH_T_F_AH_L_IY
# R_EH_G_R_AH_F_AH_L_L_IY
#
# PRUNTY
# P_R_AH_N_T_IY
# P_R_AH_N_T_IY
#
# HADRIA
# HH_AE_D_R_IY_AH
# HH_AE_D_R_IY_AH
#
# NOTED
# N_OW_T_AH_D
# N_OW_T_AH_D
#
# SABUNUMA
# S_AE_B_UW_N_AH_M_AH
# S_AH_B_UW_N_AA_M_AH
#
# PUPPETS
# P_AH_P_AH_T_S
# P_AH_P_AH_T_S
#
# BENNETTS
# B_EH_N_IH_T_S
# B_EH_N_AH_T_S
#
# MIGUEZ
# M_IY_G_EH_Z
# M_IH_G_EH_G_EH_Z
#
# DUMLER
# D_AH_M_L_ER
# D_AH_M_L_ER
#
# AUDITION
# AA_D_IH_SH_AH_N
# AW_D_IH_SH_AH_N
#
# TIPPERS
# T_IH_P_ER_Z
# T_IH_P_ER_Z
#
# GIANNETTO
# JH_AH_N_EH_T_OW
# JH_AA_N_EH_T_OW
#
# SCHWEBEL
# SH_W_EH_B_AH_L
# SH_L_B_B_EH_L
#
# PENOLOGY
# P_IY_N_AA_L_AH_JH_IY
# P_EH_N_AA_L_AA_JH_IY
#
# QUARANTINING
# K_W_AO_R_AH_N_T_IY_N_IH_NG
# K_W_AO_R_EY_N_T_T_IH_NG
#
# VIBRANT
# V_AY_B_R_AH_N_T
# V_AY_B_R_AA_N_T
#
# CENTRAM
# S_EH_N_T_R_AE_M
# S_EH_N_T_R_M_M
#
# RELINQUISHED
# R_IH_L_IH_NG_K_W_IH_SH_T
# R_EH_L_IH_NG_K_W_SH_SH
#
# EDITORIALIST
# EH_D_AH_T_AO_R_IY_AH_L_IH_S_T
# IH_D_IH_SH_AO_L_IH_L_IH_S_T
#
# HANKEY
# HH_AE_NG_K_IY
# HH_AE_NG_K_IY
#
# D'ANDREA
# D_AE_N_D_R_IY_AH
# D_AA_N_D_R_IY_AH
#
# TOMES
# T_OW_M_Z
# T_OW_M_Z
#
# WYK
# W_IH_K
# W_AY_K
#
# DEPICT
# D_IH_P_IH_K_T
# D_IH_P_IH_K_T
#
# VIRTUES
# V_ER_CH_UW_Z
# V_ER_T_UW_Z
#
# REISCH
# R_AY_SH
# R_AY_SH
#
# SONRISE
# S_AH_N_R_AY_Z
# S_AA_N_R_AY_Z
#
# VANDERVLIET
# V_AE_N_D_ER_V_L_IY_T
# V_AE_N_D_ER_V_EH_L_IH_T
#
# WRENCHING
# R_EH_N_CH_IH_NG
# R_EH_N_CH_IH_NG
#
# HYDROGENATED
# HH_AY_D_R_AH_JH_AH_N_EY_T_IH_D
# HH_AY_D_R_AH_JH_AH_N_EY_T_AH_D_D
#
# BIEVER
# B_IY_V_ER
# B_IY_V_ER
#
# COMMEMORATED
# K_AH_M_EH_M_ER_EY_T_IH_D
# K_AH_M_AH_M_ER_EY_T_AH
#
# HOBBYIST
# HH_AA_B_IY_IH_S_T
# HH_OW_B_IY_IH_S_T
#
# TENG
# T_EH_NG
# T_EH_NG
#
# SINISI
# S_IH_N_IY_S_IY
# S_IH_N_IY_S_IY
#
# USONIAM
# Y_UW_S_OW_N_IY_AH_M
# Y_UW_S_OW_N_IY_M
#
# VERONICA
# V_ER_AA_N_IH_K_AH
# V_EH_R_AH_N_IH_K_AH
#
# RANTALA
# R_AA_N_T_AA_L_AH
# R_AA_N_T_AA_L_AH
#
# TRACERS
# T_R_EY_S_ER_Z
# T_R_EY_T_ER_Z
#
# OVERBOOKING
# OW_V_ER_B_UH_K_IH_NG
# OW_V_ER_B_OW_K_NG
#
# GIEGER
# G_IY_G_ER
# JH_IY_G_ER
#
# POSTIPANKKI
# P_AO_S_T_IH_P_AE_NG_K_IY
# P_AO_S_T_IH_P_AE_N_S_K_IY
#
# GUTFREUND
# G_UH_T_F_R_EH_N_D
# G_AH_T_F_R_AH_N_D
#
# DOBKINS
# D_AA_B_K_IH_N_Z
# D_AA_B_K_IH_N_Z
#
# BURROWS
# B_ER_OW_Z
# B_ER_OW_Z
#
# EXPRESS
# IH_K_S_P_R_EH_S
# IH_K_S_P_R_AH_S
#
# SHIU
# SH_UW
# SH_IY_UW
#
# HUFFAKER
# HH_AH_F_AH_K_ER
# HH_AH_F_EY_K_ER
#
# LEHRMANN
# L_EH_R_M_AH_N
# R_EH_L_M_ER_N
#
# OXIDATION
# AA_K_S_AH_D_EY_SH_AH_N
# AA_K_Z_AH_D_AH_D_EY_SH_AH_N
#
# ADA
# EY_D_AH
# AA_D_AH
#
# EUROMISSILE
# Y_UW_R_OW_M_IH_S_AH_L
# Y_OW_R_OW_M_AH_S_AH_L
#
# CLAYPOOL
# K_L_EY_P_UW_L
# K_L_EY_P_UW_L
#
# HELLMER
# HH_EH_L_M_ER
# HH_EH_L_M_ER
#
# ZEALOTS
# Z_EH_L_AH_T_S
# Z_IY_L_AA_T_S
#
# GESKE
# JH_EH_S_K
# JH_EH_S_K
#
# ELCOTEL
# EH_L_K_OW_T_EH_L
# EH_L_K_OW_T_EH_L
#
# TRACED
# T_R_EY_S_T
# T_R_EY_S_T
#
# MOVED
# M_UW_V_D
# M_OW_V_D
#
# TACTICALLY
# T_AE_K_T_IH_K_AH_L_IY
# T_AE_K_T_IH_K_L_L_IY_IY
#
# FRIER
# F_R_AY_ER
# F_R_AY_ER
#
# MOJO
# M_OW_JH_OW
# M_OW_JH_OW
#
# DEBONIS
# D_EH_B_AH_N_IH_S
# D_IH_B_OW_N_IH_Z
#
# PRESIDENCIES
# P_R_EH_Z_IH_D_AH_N_S_IY_Z
# P_R_EH_S_IH_D_D_N_S_IY_Z
#
# HOLLADAY
# HH_AA_L_AH_D_EY
# HH_AA_L_AH_D_EY
#
# COLUMNS
# K_AA_L_AH_M_Z
# K_OW_L_AH_M_Z
#
# AEROSTAR
# EH_R_OW_S_T_AA_R
# EH_R_OW_S_T_AA_R
#
# NON-SEQUITUR
# N_AA_N_S_EH_K_W_IH_T_ER
# N_AA_N_S_AH_K_W_ER
#
# BONENBERGER
# B_OW_N_AH_N_B_ER_G_ER
# B_AA_N_AH_N_B_ER_G_ER
#
# DRILLER
# D_R_IH_L_ER
# D_R_IH_L_ER
#
# SEEHUSEN
# S_IY_HH_UW_S_AH_N
# S_IY_HH_AH_S_AH_N
#
# JANOWITZ
# Y_AE_N_AH_W_IH_T_S
# JH_AE_N_AH_W_IH_T_S
#
# SINGLETARY
# S_IH_NG_G_AH_L_T_EH_R_IY
# S_IH_NG_G_L_L_T_EH_R_IY
#
# LANGERMAN
# L_AE_NG_ER_M_AH_N
# L_AE_NG_ER_M_AH_N
#
# CLEPPER
# K_L_EH_P_ER
# K_L_EH_P_ER
#
# JANII
# JH_AH_N_IY
# JH_AA_N_IY
#
# TAXCUT
# T_AE_K_S_K_AH_T
# T_AE_K_S_T_AH
#
# TYPEFACES
# T_AY_P_F_EY_S_AH_Z
# T_AY_P_T_T_EY_S_IH_Z
#
# PILGRIMS
# P_IH_L_G_R_AH_M_Z
# P_IH_L_G_R_IH_M_Z
#
# EQUILINK
# EH_K_W_AH_L_IH_NG_K
# IH_K_W_IH_L_IH_NG_K
#
# MEDICATING
# M_EH_D_IH_K_EY_T_IH_NG
# M_EH_D_AH_K_EY_EY_IH_NG
#
# GABBERT
# G_AE_B_ER_T
# G_AE_B_ER_T
#
# OKAZAKI
# OW_K_AA_Z_AA_K_IY
# OW_K_AA_Z_AA_K_IY
#
# BLOCKADERS
# B_L_AA_K_EY_D_ER_Z
# B_L_AA_K_EY_D_ER_Z
#
# HALFRIDA
# HH_AE_F_R_IH_D_AH
# HH_AE_L_F_R_IH_D_AH
#
# TOUPEE
# T_UW_P_EY
# T_UW_P_IY
#
# KEROSENE
# K_EH_R_AH_S_IY_N
# K_ER_OW_S_OW_N_IY
#
# RIVER'S
# R_IH_V_ER_Z
# R_AY_V_ER_Z
#
# SACHSE
# S_AE_CH_S
# S_AE_K_S
#
# RIMPOCHET
# R_IH_P_OW_CH_IH_T
# R_IH_M_P_AH_K_IH_T
#
# SPONSORSHIP
# S_P_AA_N_S_ER_SH_IH_P
# S_P_AA_N_S_AO_R_SH_AH_P
#
# MCCULLA
# M_AH_K_AH_L_AH
# M_AH_K_UW_L_AH
#
# REALISTICALLY
# R_IY_AH_L_IH_S_T_IH_K_L_IY
# R_IY_L_L_IH_S_T_T_L_IY_L
#
# PANMURE
# P_AE_N_M_UH_R
# P_AE_N_M_ER
#
# CRAIGIE
# K_R_EY_G_IY
# K_R_EY_JH_IY
#
# BOOTH
# B_UW_TH
# B_UW_TH
#
# BELLINI
# B_EH_L_IY_N_IY
# B_EH_L_IY_N_IY
#
# LAMBSDORFF
# L_AE_M_Z_D_AO_R_F
# L_AE_M_S_B_R_B_B
#
# WEST
# W_EH_S_T
# W_EH_S_T
#
# SPINOFF
# S_P_IH_N_AO_F
# S_P_IH_N_OW_F
#
# CENTERFOLD
# S_EH_N_T_ER_F_OW_L_D
# S_EH_N_T_ER_F_OW_L_D
#
# OMNI
# AA_M_N_IY
# AA_M_N_IY
#
# CREELY
# K_R_IY_L_IY
# K_R_IY_L_IY
#
# BUN
# B_AH_N
# B_AH_N
#
# SHUR
# SH_ER
# SH_ER
#
# THERANI
# T_EH_R_AA_N_IY
# TH_ER_IY_N_IY
#
# SUPERSAVER
# S_UW_P_ER_S_EY_V_ER
# S_UW_P_ER_V_EY_ER_ER
#
# OHARRA
# OW_HH_ER_AH
# OW_HH_AA_R_AH
#
# BIOTECHNOLOGY
# B_AY_OW_T_EH_K_N_AA_L_AH_JH_IY
# B_AY_OW_T_T_K_K_L_L_L_L_IY_IY
#
# WESTBOROUGH
# W_EH_S_T_B_ER_OW
# B_EH_S_T_B_R_AO
#
# PECKMAN
# P_EH_K_M_AH_N
# P_EH_K_M_AH_N
#
# ALT
# AA_L_T
# AA_L_T
#
# CINCHED
# S_IH_N_CH_T
# S_IH_N_CH
#
# UNCONTROVERSIAL
# AH_N_K_AA_N_T_R_AH_V_ER_SH_AH_L
# AH_N_K_R_AH_N_AH_K_S_AH_V_ER_EY_L
#
# CANCOM
# K_AE_NG_K_AH_M
# K_AE_N_K_AH_M
#
# BIOCINE
# B_AY_AH_S_IY_N
# B_AY_OW_S_IY_N
#
# OLDEST
# OW_L_D_AH_S_T
# OW_L_D_EH_S_T
#
# KINLAW
# K_IH_N_L_AO
# K_IH_N_L_AW
#
# MIC
# M_IH_K
# M_IH_K
#
# STIRRUPS
# S_T_ER_AH_P_S
# S_T_IH_R_AH_P_S
#
# AIRLOCK
# EH_R_L_AO_K
# EH_R_L_AA_K
#
# OPTIMIZATION
# AA_P_T_IH_M_IH_Z_EY_SH_AH_N
# AA_M_T_IH_M_AH_SH_AH_N
#
# LEVEES
# L_EH_V_IY_Z
# L_EH_V_IY_Z
#
# DEVELOPMENT
# D_IH_V_EH_L_AH_P_M_AH_N_T
# D_IH_V_EH_L_AH_M_AA_N_T_T_N_T
#
# WIRTHLIN
# W_ER_TH_L_IH_N
# W_ER_TH_L_IH_N
#
# CIMARRON
# S_IH_M_ER_AA_N
# K_IH_M_ER_AA_N
#
# KANNAN
# K_AA_N_AH_N
# K_AE_N_AH_N
#
# SPORTSCASTER
# S_P_AO_R_T_S_K_AE_S_T_ER
# S_P_AO_R_T_S_T_EY_K_ER
#
# NANOGRAM
# N_AA_N_OW_G_R_AE_M
# N_AE_N_AA_G_R_AA_M
#
# BROGAN
# B_R_OW_G_AH_N
# B_R_AA_G_AH_N
#
# SYMES
# S_AY_M_Z
# S_AY_M_Z
#
# VALIANTLY
# V_AE_L_Y_AH_N_T_L_IY
# V_AE_L_AH_N_T_T_L_IY
#
# KOSYAKOV
# K_OW_S_Y_AA_K_AO_V
# K_OW_Z_IY_V_AA_K
#
# MUSLIN
# M_AH_Z_L_AH_N
# M_AH_Z_L_IH_N
#
# SEMINAL
# S_EH_M_AH_N_AH_L
# S_EH_M_AH_N_AH_L
#
# OAT
# OW_T
# OW_T
#
# GARFIELD
# G_AA_R_F_IY_L_D
# G_AA_R_F_IY_L_D
#
# FESTS
# F_EH_S_T_S
# F_EH_S_T_S
#
# NIEMEIER
# N_IY_M_AY_ER
# N_IY_M_AY_ER
#
# SGRO
# S_K_R_OW
# G_R_OW_S
#
# OUTVOTED
# AW_T_V_OW_T_AH_D
# AW_T_T_OW_T_AH_D
#
# BLACKENED
# B_L_AE_K_AH_N_D
# B_L_AE_K_AH_N_D
#
# KOMARIK'S
# K_OW_M_AA_R_IH_K_S
# K_AH_M_AA_R_IH_K_S
#
# VLASIC
# V_L_AE_Z_IH_K
# V_L_AE_S_IH_K
#
# PLOETZ
# P_L_OW_T_S
# P_L_OW_T_S
#
# HALEY
# HH_EY_L_IY
# HH_EY_L_IY
#
# CONSUMES
# K_AH_N_S_UW_M_Z
# K_AA_N_S_AH_M_Z
#
# NIMMER
# N_IH_M_ER
# N_IH_M_ER
#
# NOTE
# N_OW_T
# N_OW_T
#
# TRICIL
# T_R_IH_S_IH_L
# T_R_IH_S_AH_L
#
# FLAGSTAFF
# F_L_AE_G_S_T_AE_F
# F_L_AE_G_S_T_AH_F
#
# ZAWADZKI
# Z_AA_V_AA_JH_K_IY
# Z_AH_V_AE_D_D_S_K_IY
#
# GUANGZHOU
# G_W_AE_NG_Z_UW
# G_AO_NG_Z_OW
#
# WOODWORKERS
# W_UH_D_W_ER_K_ER_Z
# W_UH_D_K_UH_ER_ER_ER_Z
#
# CHUMNEY
# CH_AH_M_N_IY
# CH_AH_M_N_IY
#
# MILFORD
# M_IH_L_F_ER_D
# M_IH_L_F_ER_D
#
# SIDEWISE
# S_AY_D_W_AY_Z
# S_AY_D_AY_W_AY
#
# SPYCATCHER
# S_P_AY_K_AE_CH_ER
# S_P_IY_K_AH_K_ER
#
# LOMBARDI
# L_AA_M_B_AA_R_D_IY
# L_AA_M_B_AA_R_D_IY
#
# REICHENBERG
# R_AY_K_AH_N_B_ER_G
# R_AY_K_AH_N_B_ER_G
#
# BLITZES
# B_L_IH_T_S_IH_Z
# B_L_IH_T_Z_IH_Z
#
# JUDGED
# JH_AH_JH_D
# JH_AH_JH_D
#
# AZZATO
# AH_Z_AA_T_OW
# AA_Z_Z_AA_T
#
# MONTGOMERY
# M_AA_N_T_G_AH_M_R_IY
# M_AA_NG_G_AH_AH_M_R_IY
#
# THUNDERBOLT
# TH_AH_N_D_ER_B_AO_L_T
# TH_AH_N_D_ER_B_OW_L_T
#
# TITLEHOLDER
# T_AY_T_AH_L_HH_OW_L_D_ER
# T_IH_T_HH_AH_L_ER
#
# CORNELLE
# K_ER_N_EH_L
# K_ER_N_EH_L
#
# LETOURNEAU
# L_EH_T_UH_R_N_OW
# L_EH_T_ER_N_OW
#
# CAIRO
# K_AY_R_OW
# K_EH_R_OW
#
# SQUABBLING
# S_K_W_AA_B_AH_L_IH_NG
# S_K_AE_B_AH_L_NG
#
# TERRIFICALLY
# T_ER_IH_F_IH_K_L_IY
# T_EH_R_IH_F_IH_K_IY_IY
#
# MCALEESE
# M_AH_K_AH_L_IY_Z
# M_AH_K_AA_L_IY_Z
#
# AFFILIATIONS
# AH_F_IH_L_IY_EY_SH_AH_N_Z
# AH_F_IH_L_EY_SH_AH_N_Z
#
# GURROLA
# G_UH_R_OW_L_AH
# G_ER_OW_L_AH
#
# SONATAS
# S_AA_N_AA_T_AH_Z
# S_AA_N_AA_T_AH_Z
#
# DURING
# D_UH_R_IH_NG
# D_UH_R_IH_NG
#
# CANADIAN'S
# K_AH_N_EY_D_IY_AH_N_Z
# K_AH_N_EY_D_IY_AH_N_Z
#
# NIKOLAIVICH
# N_IH_K_OW_L_AY_V_IH_CH
# N_IH_K_L_L_IH_V
#
# REINCARNATED
# R_IY_IH_N_K_AA_R_N_EY_T_IH_D
# R_AY_AH_K_K_K_R_EY_EY_EY_T_AH
#
# TRENCH
# T_R_EH_N_CH
# T_R_EH_N_CH
#
# FORE
# F_AO_R
# F_AO_R
#
# ERRONEOUSLY
# EH_R_OW_N_IY_AH_S_L_IY
# IH_R_OW_N_IY_AH_S_L_IY
#
# INCURRING
# IH_N_K_ER_IH_NG
# IH_N_K_ER_IH_NG
#
# BARNACLES
# B_AA_R_N_AH_K_AH_L_Z
# B_AA_R_N_AA_K_AH_L_Z
#
# LANGLAND
# L_AE_NG_L_AH_N_D
# L_AE_NG_L_AH_N_D
#
# NEUTROGENA
# N_UW_T_R_AH_JH_IY_N_AH
# N_UW_T_R_OW_JH_AH_N_AH_AH
#
# DELAUGHTER
# D_EH_L_AO_T_ER
# D_EH_L_AO_T_ER
#
# MCDANNEL
# M_AH_K_D_AE_N_AH_L
# M_AH_K_D_AE_N_AH_AH
#
# HENLINE
# HH_EH_N_L_AY_N
# HH_EH_N_L_AY_N
#
# MINISCRIBE
# M_IH_N_IY_S_K_R_AY_B
# M_IH_N_AH_S_K_R_AY_B
#
# GANEY
# G_EY_N_IY
# G_EY_N_IY
#
# HEIST
# HH_AY_S_T
# HH_AY_S_T
#
# BRUSQUELY
# B_R_AH_S_K_L_IY
# B_R_AH_S_K_IH_IY_IY
#
# TENNANT
# T_EH_N_AH_N_T
# T_EH_N_AH_N_T
#
# WHENEVER
# W_EH_N_EH_V_ER
# W_EH_N_AH_V_ER
#
# LITTLE'S
# L_IH_T_AH_L_Z
# L_IH_T_AH_L_Z
#
# OUTLINES
# AW_T_L_AY_N_Z
# AW_T_L_AY_N_Z
#
# SODEN
# S_OW_D_AH_N
# S_AA_D_AH_N
#
# SUPERPOWER
# S_UW_P_ER_P_AW_ER
# S_UW_P_ER_P_ER
#
# KUNAEV
# K_Y_UW_N_EY_V
# K_UW_N_N_V_EH
#
# BENIGHT
# B_IY_N_AY_T
# B_EH_N_IH_T
#
# FRERKING
# F_R_ER_K_IH_NG
# F_R_EH_K_IH_NG
#
# KERLEY
# K_ER_L_IY
# K_ER_L_IY
#
# LOVETT
# L_AH_V_IH_T
# L_OW_V_IH_T
#
# RALPH
# R_AE_L_F
# R_AE_L_F
#
# MERCURIC
# M_ER_K_Y_UH_R_IH_K
# M_ER_K_UH_R_IH_K
#
# CUTCHER
# K_AH_CH_ER
# K_AH_CH_ER
#
# ZANDY
# Z_AE_N_D_IY
# Z_AE_N_D_IY
#
# PLUME
# P_L_UW_M
# P_L_UW_M
#
# MARVER
# M_AA_R_V_ER
# M_AA_R_V_ER
#
# MENTZER
# M_EH_N_T_Z_ER
# M_EH_N_T_Z_ER
#
# WALNUT
# W_AO_L_N_AH_T
# W_AE_L_N_AW_T
#
# MADIS
# M_AE_D_AH_S
# M_AE_D_IH_S
#
# CARLON
# K_AA_R_L_AH_N
# K_AA_R_L_AH_N
#
# PITCHER'S
# P_IH_CH_ER_Z
# P_IH_CH_ER_Z
#
# BERNSTEIN
# B_ER_N_S_T_AY_N
# B_ER_N_S_T_AY_N
#
# OVERPLAY
# OW_V_ER_P_L_EY
# OW_V_ER_P_L_EY
#
# ACROLEIN
# AE_K_R_OW_L_IY_N
# AE_K_R_UW_L_AY_N
#
# COASTAMERICA
# K_OW_S_T_AH_M_EH_R_IH_K_AH
# K_OW_S_T_M_AE_AE_R_IH_K_AH
#
# DOMINA
# D_OW_M_IY_N_AH
# D_AA_M_IY_N_AH
#
# BASULTO
# B_AH_S_AH_L_T_OW
# B_AH_S_UW_L_T
#
# HEZBULLAH
# HH_EH_Z_B_AA_L_AH
# HH_EH_B_B_AH_SH_AH
#
# ABRIDGEMENT
# AH_B_R_IH_JH_M_AH_N_T
# AH_B_R_IH_G_M_AH_N_T_AH_N_T
#
# AEROSPATIALE'S
# EH_R_OW_S_P_AA_S_IY_AA_L_Z
# EH_R_OW_S_P_P_EY_L_L_Z
#
# CAUDLE
# K_AO_D_AH_L
# K_AO_D_AH_L
#
# RAGONESE
# R_AA_G_OW_N_EY_Z_IY
# R_AE_G_AH_N_IY_Z
#
# MICALLEF
# M_IH_K_AH_L_EH_F
# M_IH_K_AH_L_AH_F
#
# FOXWORTH
# F_AA_K_S_W_ER_TH
# F_OW_K_S_W_ER_TH
#
# LARUSSA
# L_AA_R_UW_S_AH
# L_AA_R_UW_S_AH
#
# SERIES
# S_IH_R_IY_Z
# S_AY_R_IY_Z
#
# AMERICAN
# AH_M_EH_R_IH_K_AH_N
# AH_M_EH_R_IH_K_AH_N
#
# FEDERBUSH
# F_EH_D_ER_B_UH_SH
# F_EY_D_ER_B_F
#
# ISLAMI
# IH_Z_L_AA_M_IY
# IH_S_L_AA_M_IY
#
# RADBURN
# R_AE_D_B_ER_N
# R_AE_D_B_ER_N
#
# PENNY
# P_EH_N_IY
# P_EH_N_IY
#
# HOMEOWNER
# HH_OW_M_OW_N_ER
# HH_OW_M_IY_N_ER
#
# MILLERS
# M_IH_L_ER_Z
# M_IH_L_ER_Z
#
# POWELL'S
# P_AA_W_EH_L_Z
# P_AW_EH_L_L_Z
#
# HODGSON
# HH_AA_JH_S_AH_N
# HH_AA_JH_S_AH_N
#
# STIHL
# S_T_IH_L
# S_T_IH_L
#
# SABOL'S
# S_AA_B_AO_L_Z
# S_AE_B_OW_L_Z
#
# SUPERCONDUCTOR
# S_UW_P_ER_K_AH_N_D_AH_K_T_ER
# S_UW_S_ER_D_AH_K_K_K_K_ER_T
#
# HOLDS
# HH_OW_L_D_Z
# HH_OW_L_D_Z
#
# AYES
# AY_Z
# AY_Z
#
# AMIS
# AE_M_IH_S
# AE_M_IY_Z
#
# DICED
# D_AY_S_T
# D_AY_S_T
#
# HAZELRIGG
# HH_AH_Z_EH_L_R_IH_G
# HH_EY_Z_ER_L_IH
#
# TERRAIN
# T_ER_EY_N
# T_EH_R_EY_N
#
# WOLAK
# W_OW_L_AH_K
# W_OW_L_AH_K
#
# BELVIDERE
# B_EH_L_V_IH_D_IH_R
# B_EH_L_V_IH_D_ER
#
# EISHI
# EY_SH_IY
# IY_SH_IY
#
# ABU
# AE_B_UW
# AE_B_UW
#
# CAMARADERIE
# K_AA_M_ER_AA_D_ER_IY
# K_AH_M_AA_D_EH_R_IY
#
# ONE-LEGGED
# W_AH_N_L_EH_G_AH_D
# AA_N_AH_L_G_JH_D
#
# SELECT
# S_AH_L_EH_K_T
# S_EH_L_IH_K_T
#
# HADNOT
# HH_AE_D_N_AH_T
# HH_AE_D_N_AH_T
#
# REDID
# R_IY_D_IH_D
# R_IY_D_IH_D
#
# STUTZMAN
# S_T_AH_T_S_M_AH_N
# S_T_AH_T_Z_M_AH_N
#
# SEAQ
# S_IY_K
# S_IY_K
#
# TAMPER
# T_AE_M_P_ER
# T_AE_M_P_ER
#
# CHRISTOFFERSEN
# K_R_IH_S_T_AH_F_ER_S_AH_N
# K_R_IH_S_T_AH_F_ER_S_AH_N
#
# TUTWILER
# T_AH_T_W_AY_L_ER
# T_AH_T_W_ER_ER
#
# TRIPLED
# T_R_IH_P_AH_L_D
# T_R_IH_P_AH_L_D
#
# BAPTISTA
# B_AE_P_T_IH_S_T_AH
# B_AA_P_IH_IH_S_T_AH
#
# KRONOR
# K_R_OW_N_ER
# K_R_AA_N_ER
#
# FIN
# F_IH_N
# F_IH_N
#
# DEVIL
# D_EH_V_AH_L
# D_EH_V_IH_L
#
# HOLINESS
# HH_OW_L_IY_N_AH_S
# HH_OW_L_IY_N_AH_S
#
# ADRIATIC
# EY_D_R_IY_AE_T_IH_K
# AA_D_R_IY_AE_T_T_K
#
# ROSENBERGS
# R_OW_Z_AH_N_B_ER_G_Z
# R_OW_Z_AH_N_B_ER_G_Z
#
# NEWARK
# N_UW_ER_K
# N_UW_W_ER_K
#
# INEXTRICABLY
# IH_N_EH_K_S_T_R_IH_K_AH_B_L_IY
# IH_N_EH_K_S_T_R_K_K_AH_B_L_IY
#
# VECTRA
# V_EH_K_T_R_ER
# V_EH_K_T_R_AH
#
# WUTHERING
# W_AH_DH_ER_IH_NG
# W_AH_DH_ER_IH_NG
#
# FINK
# F_IH_NG_K
# F_IH_NG_K
#
# POPULARIZER
# P_AA_P_Y_AH_L_ER_AY_Z_ER
# P_AA_P_Y_AH_L_EY_Z_ER
#
# DECIPHERED
# D_IH_S_AY_F_ER_D
# D_IH_S_HH_AY_ER
#
# OCCHOA
# OW_CH_OW_AA
# OW_CH_OW_OW
#
# SCHROADER
# SH_R_OW_D_ER
# SH_R_OW_D_ER
#
# ARETA
# AA_R_EH_T_AH
# AA_R_EH_T_AH
#
# DECEMBER
# D_IH_S_EH_M_B_ER
# D_IY_S_AH_M_B_ER
#
# GOMBERT
# G_AA_M_B_ER_T
# G_AA_M_B_ER_T
#
# JUGS
# JH_AH_G_Z
# JH_AH_G_Z
#
# CHANCEY
# CH_AE_N_S_IY
# CH_AE_N_S_IY
#
# POZOS
# P_OW_Z_OW_S
# P_OW_Z_OW_Z
#
# AVALLONE
# AE_V_AH_L_OW_N
# AE_V_AH_L_OW_N_IY
#
# VIRULENCE
# V_IH_R_AH_L_AH_N_S
# V_IH_R_AH_L_AH_N_S
#
# INTERPERSONAL
# IH_N_T_ER_P_ER_S_AH_N_AH_L
# IH_N_T_ER_P_AH_S_AH_AH_AH_L
#
# FRANCKLIN
# F_R_AE_NG_K_L_IH_N
# F_R_AE_N_K_L_IH_N
#
# GAINFUL
# G_EY_N_F_AH_L
# G_EY_N_F_AH_L
#
# PAPO
# P_AE_P_OW
# P_AA_P_OW
#
# KOMP
# K_AA_M_P
# K_AA_M_P
#
# SURPRISE
# S_ER_P_R_AY_Z
# S_ER_P_R_AY_Z
#
# DELIBERATES
# D_IH_L_IH_B_ER_EY_T_S
# D_IH_L_IH_B_ER_EY_T_S
#
# FESSEL
# F_EH_S_AH_L
# F_EH_S_AH_L
#
# CRISCI
# K_R_IH_S_IY
# K_R_IH_S_IY
#
# HUNTER
# HH_AH_N_T_ER
# HH_AH_N_ER_ER
#
# WIKIPEDIA
# W_IH_K_IY_P_IY_D_IY_AH
# W_IH_K_IH_D_AY_P_AH
#
# JAMA
# JH_AE_M_AH
# JH_AA_M_AH
#
# KRISTOPHER'S
# K_R_IH_S_T_AH_F_ER_Z
# K_R_IH_S_T_AA_F_ER_Z
#
# CIERA
# S_IY_EH_R_AA
# S_IY_R_AH
#
# MARKETERS
# M_AA_R_K_AH_T_ER_Z
# M_AA_R_K_AH_T_ER_Z
#
# BROMINE
# B_R_OW_M_IY_N
# B_R_AA_M_IY_N_IY
#
# UNCOOL
# AH_N_K_UW_L
# AH_NG_K_UW_L
#
# PHILADELPHIAN
# F_IH_L_AH_D_EH_L_F_IY_AH_N
# F_IH_L_AH_D_L_L_AH_AH_AH_N
#
# BRONCO
# B_R_AA_NG_K_OW
# B_R_AA_NG_K_OW
#
# GAZELLA
# G_AH_Z_EH_L_AH
# G_AA_Z_EH_L_AH
#
# GEURIN
# ZH_ER_AE_N
# JH_ER_IY_N
#
# MORASH
# M_AO_R_AH_SH
# M_AO_R_AH_SH
#
# LORUSSO
# L_AO_R_UW_S_OW
# L_AO_R_UW_S_OW
#
# DURAKON
# D_UH_R_AH_K_IH_N
# D_UH_R_AH_K_AA_N
#
# ROSSMORE
# R_AA_S_M_AO_R
# R_AO_S_M_ER
#
# EXAMINATIONS
# IH_G_Z_AE_M_AH_N_EY_SH_AH_N_Z
# IH_G_Z_AH_M_AH_Z_EY_SH_AH_N_Z
#
# BRANON
# B_R_AE_N_AH_N
# B_R_AE_N_AH_N
#
# NOLANDA
# N_AH_L_AE_N_D_AH
# N_OW_L_AA_N_D_AH
#
# MUMA
# M_Y_UW_M_AH
# Y_UW_M_AH
#
# WAMBOLD
# W_AA_M_B_OW_L_D
# W_AE_M_B_OW_L_D
#
# GRUMBLED
# G_R_AH_M_B_AH_L_D
# G_R_AH_M_B_AH_L_D
#
# POLECATS
# P_OW_L_K_AE_T_S
# P_OW_L_AH_K_AE_T_S
#
# CHURCHILL'S
# CH_ER_CH_IH_L_Z
# CH_ER_CH_IH_L_Z
#
# JUGGLE
# JH_AH_G_AH_L
# JH_AH_G_AH_L
#
# WOLFINBARGER
# W_UH_L_F_IH_N_B_AA_R_G_ER
# W_OW_L_F_AH_B_AA_AA_ER_ER
#
# RUMMY
# R_AH_M_IY
# R_AH_M_IY
#
# TORRIJOS
# T_AO_R_IY_OW_S
# T_AO_R_IY_HH_OW_Z
#
# BLUE
# B_L_UW
# B_L_UW
#
# DELCARLO
# D_EH_L_K_AA_R_L_OW
# D_EH_L_K_AA_R_OW_L
#
# ORENSTEIN
# AO_R_AH_N_S_T_AY_N
# AO_R_AH_N_S_T_AY_N
#
# ALLERGIC
# AH_L_ER_JH_IH_K
# AH_L_ER_JH_IH_IH
#
# ARMELLINO
# AA_R_M_EH_L_IY_N_OW
# AA_R_M_EH_L_IY_N_OW
#
# DINGEE
# D_IH_NG_G_IY
# D_IH_NG_G_IY
#
# BOSTELMAN
# B_AA_S_T_AH_L_M_AH_N
# B_AA_S_T_AH_L_M_AH_N
#
# TERRA
# T_EH_R_AA
# T_EH_R_AH
#
# JARMON
# Y_AA_R_M_AO_N
# JH_AA_R_M_AH_N
#
# LYCURGUS
# L_AY_K_ER_G_AH_S
# L_AY_K_ER_G_AH_S
#
# PETRICK
# P_EH_T_R_IH_K
# P_EH_T_R_IH_K
#
# ELSTON
# IH_L_S_T_AA_N
# EH_L_S_T_AH_N
#
# OUTBURST
# AW_T_B_ER_S_T
# AW_T_B_ER_S_T
#
# GRADIENTS
# G_R_EY_D_IY_AH_N_T_S
# G_R_EY_D_AH_AH_N_T_S_T_S
#
# PODANY
# P_AH_D_AO_N_IY
# P_AH_D_AH_N_IY
#
# ENDUSER
# EH_N_D_Y_UW_Z_ER
# EH_N_D_Y_UW_Z_ER
#
# JACKSDEIT
# JH_AE_K_S_D_IY_AH_T
# JH_AE_K_S_T_IH_S_T
#
# ADDIDAS
# AH_D_IY_D_AH_S
# AH_D_AY_D_AH_Z
#
# FACILITATES
# F_AH_S_IH_L_AH_T_EY_T_S
# F_AE_S_IH_L_IH_T_EY_T_S
#
# DIFFRACT
# D_IH_F_R_AE_K_T
# D_IH_F_R_AE_K_T
#
# EMERANT
# EY_M_EH_R_AH_N_T
# IH_M_ER_AH_N_T
#
# BRAKES
# B_R_EY_K_S
# B_R_EY_K_S
#
# CHAIRMAN
# CH_EH_R_M_AH_N
# CH_EY_R_M_AH_N
#
# HESLOP
# HH_EH_S_L_AH_P
# HH_EH_S_L_OW_P
#
# MEDENDORP
# M_EH_D_EH_N_D_AO_R_P
# M_EH_D_AH_N_D_AO_R_P
#
# TORELLO
# T_AO_R_EH_L_OW
# T_AO_R_EH_L_OW
#
# BURRIS
# B_ER_IH_S
# B_ER_IH_S
#
# GASKILL
# G_AE_S_K_IH_L
# G_AE_S_K_IH_L
#
# RIVARD
# R_IH_V_ER_D
# R_IH_V_ER_D
#
# MEATIER
# M_IY_T_IY_ER
# M_IY_T_ER
#
# KLOSE
# K_L_OW_Z
# K_L_OW_Z
#
# AKKADIAN
# AH_K_EY_D_IY_AH_N
# AH_K_AH_D_IY_AH_N
#
# CONCEAL
# K_AH_N_S_IY_L
# K_AH_N_S_IY_L
#
# HEMING
# HH_EH_M_IH_NG
# HH_EH_M_IH_NG
#
# MANHOOD
# M_AE_N_HH_UH_D
# M_AE_N_HH_UH_D
#
# MISTRY
# M_IH_S_T_R_IY
# M_IH_S_T_R_IY
#
# EJACULATION
# IY_JH_AE_K_Y_UW_L_EY_SH_AH_N
# IH_JH_AH_K_Y_UW_L_EY_SH_AH_N
#
# WESTENDORF
# W_EH_S_T_IH_N_D_AO_R_F
# W_EH_S_T_AH_N_F_ER_D
#
# WOOLLEN
# W_UH_L_AH_N
# W_UH_L_AH_N
#
# STIEFELHAGEN
# S_T_IY_F_AH_L_HH_EY_G_AH_N
# S_T_IY_F_AH_L_AH_AH_AH_N
#
# ORIGINATES
# ER_IH_JH_AH_N_EY_T_S
# AO_R_IH_JH_AH_N_EY_T_S
#
# CLARKIN
# K_L_AA_R_K_IH_N
# K_L_AA_R_K_IH_N
#
# FUCHSIAS
# F_Y_UW_SH_AH_Z
# F_UW_K_SH_AH_Z
#
# TEASTER
# T_IY_S_T_ER
# T_IY_S_T_ER
#
# HEMY
# HH_EH_M_IY
# HH_EH_M_IY
#
# STATTIN
# S_T_AE_T_IH_N
# S_T_AE_T_IH_N
#
# LOCOMOTIVE
# L_OW_K_AH_M_OW_T_IH_V
# L_OW_K_OW_M_OW_T_T_V
#
# AMORTIZE
# AE_M_ER_T_AY_Z
# AH_M_AO_R_T_AY_Z
#
# HURLY
# HH_ER_L_IY
# HH_ER_L_IY
#
# FRENZEL
# F_R_EH_N_Z_AH_L
# F_R_EH_N_Z_AH_L
#
# EISON
# AY_Z_AH_N
# AY_Z_AH_N
#
# ECLIPTIC
# IH_K_L_IH_P_T_IH_K
# IH_K_L_IH_P_T_K
#
# FELONY
# F_EH_L_AH_N_IY
# F_EH_L_OW_N_IY
#
# LAUNIUS
# L_AW_N_IY_IH_S
# L_AO_N_IY_AH_S
#
# NON-SEQUITURS
# N_AA_N_S_EH_K_W_IH_T_ER_Z
# N_AA_N_S_AH_K_W_ER_ER_ER
#
# TAPEIE'S
# T_EY_P_IY_EY_Z
# T_EY_P_IY_Z
#
# HERZFELD
# HH_ER_Z_F_EH_L_D
# HH_ER_Z_F_EH_L_D
#
# IDEA
# AY_D_IY_AH
# AY_D_IY_AH
#
# DUGALD
# D_AH_G_AH_L_D
# D_AH_G_AH_L_D
#
# EAGLES
# IY_G_AH_L_Z
# IY_G_AH_L_Z
#
# YASSIN
# Y_AE_S_IH_N
# Y_AA_S_IH_N
#
# OILMEN
# OY_L_M_EH_N
# OY_L_M_AH_N
#
# REHABILITATED
# R_IY_HH_AH_B_IH_L_AH_T_EY_T_IH_D
# R_IH_HH_AH_B_IH_L_AH_L_EY_T_AH
#
# NEWSDAY
# N_UW_Z_D_EY
# N_UW_S_D_EY
#
# JOISTS
# JH_OY_S_T_S
# JH_OY_S_T_S
#
# WYER
# W_AY_ER
# W_AY_ER
#
# WOLFRAM
# W_UH_L_F_R_AE_M
# W_OW_L_F_R_AH_M
#
# PECO
# P_EY_K_OW
# P_IY_K_OW
#
# BERLING
# B_ER_L_IH_NG
# B_ER_L_IH_NG
#
# YOFFIE
# Y_AO_F_IY
# Y_OW_F_IY
#
# WRUCK
# R_AH_K
# R_AH_K
#
# BANIA
# B_AA_N_IY_AH
# B_AA_N_IY_AH
#
# ATTENDANT'S
# AH_T_EH_N_D_AH_N_T_S
# AE_T_AH_N_D_AH_N_T_S
#
# HETEROGENEOUS
# HH_EH_T_ER_AH_JH_IY_N_Y_AH_S
# HH_EY_T_ER_JH_UW_N_UW_S
#
# SCHWENK
# SH_W_EH_NG_K
# SH_W_EH_NG_K
#
# RADIALS
# R_EY_D_IY_AH_L_Z
# R_EY_D_IY_AH_L_Z
#
# CONSTITUTE
# K_AA_N_S_T_AH_T_UW_T
# K_AA_N_S_T_AH_T_UW_T
#
# PELLEGRIN
# P_EH_L_IH_G_R_IH_N
# P_EH_L_IH_G_R_IH_N
#
# O'CONNOR
# OW_K_AA_N_ER
# OW_K_AH_N_ER
#
# CLASSIFY
# K_L_AE_S_AH_F_AY
# K_L_AE_S_AH_F_AY
#
# WININGER
# W_AY_N_IH_NG_ER
# W_IH_N_IH_NG_ER
#
# GULLAH
# G_AH_L_AH
# G_AH_L_AH
#
# BYRER
# B_AY_R_ER
# B_AY_ER
#
# MORAINAL
# M_ER_EY_N_AH_L
# M_ER_EY_N_AH_L
#
# ANSHAN
# AE_N_SH_AH_N
# AE_N_SH_AH_N
#
# COMPUCHEM
# K_AA_M_P_Y_UW_K_EH_M
# K_AH_M_Y_UW_M_AH_M
#
# THIEM
# TH_IY_M
# TH_IY_M
#
# SPECTRA'S
# S_P_EH_K_T_R_AH_Z
# S_P_EH_K_T_R_AH_Z
#
# WRENCHING
# R_EH_N_CH_IH_NG
# R_EH_N_CH_IH_NG
#
# SNORTER
# S_N_AO_R_T_ER
# S_N_AO_R_T_ER
#
# AHMANN
# AA_M_AH_N
# AA_M_AH_N
#
# VALLARIO
# V_AA_L_AA_R_IY_OW
# V_AA_L_AA_R_IY_OW
#
# INHUMANE
# IH_N_HH_Y_UW_M_EY_N
# IH_N_HH_Y_UW_M_EY_N
#
# JAUDON
# Y_AW_D_AO_N
# JH_AO_D_AH_N
#
# NATALLE'S
# N_AH_T_AA_L_EY_Z
# N_AA_T_AA_L_AH_Z
#
# PEINADO
# P_EY_IY_N_AA_D_OW
# P_IY_N_AA_D_OW
#
# VANDENBURG
# V_AE_N_D_AH_N_B_ER_G
# V_AE_N_D_AH_N_B_ER_G
#
# BOEHNING
# B_OW_N_IH_NG
# B_OW_N_IH_NG
#
# QUINTUPLE
# K_W_IH_N_T_UW_P_AH_L
# K_W_IH_N_T_AH_P_AH_L
#
# SCOTCHED
# S_K_AA_CH_T
# S_K_AA_CH_T
#
# PITFALLS
# P_IH_T_F_AO_L_Z
# P_IH_T_F_AA_L_Z
#
# MELLICK
# M_EH_L_IH_K
# M_EH_L_IH_K
#
# HOBBIT
# HH_AO_B_IH_T
# HH_AA_B_IH_T
#
# PATHANS
# P_AE_TH_AH_N_Z
# P_AE_TH_AH_N_Z
#
# RESELLER
# R_IY_S_EH_L_ER
# R_IY_S_EH_L_ER
#
# WATERMARK
# W_AO_T_ER_M_AA_R_K
# W_AO_T_ER_M_AA_R_K
#
# TINLEY
# T_IH_N_L_IY
# T_IH_N_L_IY
#
# HEYWOOD
# HH_EY_W_UH_D
# HH_AY_W_UH_D
#
# THEORIES
# TH_IH_R_IY_Z
# TH_IY_ER_IY_Z
#
# TRIMPE
# T_R_IH_M_P
# T_R_IH_M_P
#
# LAZZARI
# L_AA_T_S_AA_R_IY
# L_AA_Z_AA_R_IY
#
# COMMUNICATES
# K_AH_M_Y_UW_N_IH_K_EY_T_S
# K_AH_M_Y_UW_N_Y_AH_EY_EY_EY_S
#
# AIRHART
# EH_R_HH_AA_R_T
# EH_R_HH_AA_R_T
#
# SABRE
# S_EY_B_ER
# S_AA_B_ER
#
# OTERO
# OW_T_EH_R_OW
# OW_T_EH_R_OW
#
# INSTITUTIONAL
# IH_N_S_T_IH_T_UW_SH_AH_N_AH_L
# IH_N_S_T_IH_SH_AH_N_AH_L
#
# GRADCHEV
# G_R_AE_D_CH_EH_F
# G_R_AE_D_CH_EH_V
#
# JUKES
# JH_UW_K_S
# JH_UW_K_S
#
# RUNNING
# R_AH_N_IH_NG
# R_AH_N_IH_NG
#
# GELERTNER
# G_AH_L_ER_T_N_ER
# JH_EH_L_ER_T_N_ER
#
# NEWTON
# N_UW_T_AH_N
# N_UW_T_AH_N
#
# POPPLETON
# P_AA_P_AH_L_T_AA_N
# P_AA_P_L_L_T_AH_N
#
# GASPAR
# G_AE_S_P_ER
# G_AE_S_P_ER
#
# BUSSED
# B_AH_S_T
# B_AH_S_D
#
# HAIRCUT
# HH_EH_R_K_AH_T
# HH_EH_R_K_AH_T
#
# KINDLED
# K_IH_N_D_AH_L_D
# K_IH_N_D_AH_L_D
#
# GROVEL
# G_R_AA_V_AH_L
# G_R_OW_V_AH_L
#
# AFFERENT
# AE_F_ER_AH_N_T
# AH_F_ER_AH_N_AH
#
# STANARD
# S_T_AE_N_ER_D
# S_T_AA_N_ER_D
#
# MANLY
# M_AE_N_L_IY
# M_AE_N_L_IY
#
# JHERYL
# JH_EH_R_AH_L
# JH_EH_R_AH_L
#
# NASHUA
# N_AE_SH_UW_AH
# N_AE_SH_UW
#
# HOCTOR
# HH_AA_K_T_ER
# HH_AA_K_T_ER
#
# BREDE
# B_R_IY_D
# B_R_IY_D
#
# RINGENBERG
# R_IH_NG_AH_N_B_ER_G
# R_IH_NG_AH_AH_B_ER
#
# DRENNON
# D_R_EH_N_AH_N
# D_R_EH_N_AH_N
#
# AKIYAMA
# AA_K_IY_Y_AA_M_AH
# AH_K_IY_Y_AH_M
#
# MINUTIAE
# M_IH_N_UW_SH_IY_AH
# M_IH_N_Y_UW_SH_AH
#
# CUSHMAN
# K_UH_SH_M_AH_N
# K_AH_SH_M_AH_N
#
# HORSES
# HH_AO_R_S_AH_Z
# HH_AO_R_S_IH_Z
#
# RODRIQUEZ
# R_AA_D_R_IY_K_EH_Z
# R_OW_D_R_IY_K_EH_Z
#
# PERDEW
# P_ER_D_UW
# P_ER_D_UW
#
# SPRENKLE
# S_P_R_EH_NG_K_AH_L
# S_P_R_EH_NG_K_AH_L
#
# PIONEER'S
# P_AY_AH_N_IH_R_Z
# P_AY_AH_N_ER_Z
#
# REICK
# R_IY_K
# R_AY_K
#
# LEFEVRE
# L_AH_F_EY_V_ER
# L_EH_F_AH_V_ER
#
# POLSTER
# P_OW_L_S_T_ER
# P_OW_L_S_T_ER
#
# FINLETS
# F_IH_N_L_AH_T_S
# F_IH_N_L_AH_T_S
#
# DEBIASE
# D_IH_B_IY_AA_S_IY
# D_IH_B_IY_AH_S
#
# OVEREXCITES
# OW_V_ER_EH_K_S_AY_T_S
# OW_V_ER_K_IH_S_IH_T_S
#
# MALONEY
# M_AH_L_OW_N_IY
# M_AH_L_OW_N_IY
#
# DISCONNECTS
# D_IH_S_K_AH_N_EH_K_T_S
# D_IH_S_K_AH_N_AA_K_T_S
#
# FORRESTAL
# F_AO_R_AH_S_T_AH_L
# F_AO_R_S_T_AH_L
#
# MAGYAR
# M_AE_G_Y_AA_R
# M_AE_JH_Y_AA_R
#
# CRAMER'S
# K_R_EY_M_ER_Z
# K_R_AE_M_ER_Z
#
# RITTENHOUSE'S
# R_IH_T_AH_N_HH_AW_S_IH_Z
# R_IH_T_AH_N_HH_AW_S_IH_Z
#
# ZUREK
# Z_UH_R_EH_K
# Z_UH_R_IH_K
#
# HOO
# HH_UW
# HH_UW
#
# SAVILL
# S_AA_V_IY_L
# S_AA_V_IH_L
#
# MCBAY
# M_AH_K_B_EY
# M_AH_K_M_EY
#
# DETHLEFSEN
# D_EH_TH_L_IH_F_S_AH_N
# D_EH_TH_F_EH_S_AH_N
#
# LAURIN
# L_AO_R_IH_N
# L_AO_R_IH_N
#
# SHIRK
# SH_ER_K
# SH_ER_K
#
# BOKOR
# B_OW_K_ER
# B_AH_K_ER
#
# SCREENER
# S_K_R_IY_N_ER
# S_K_R_IY_N_ER
#
# CABRINI
# K_AH_B_R_IY_N_IY
# K_AA_B_R_IY_N_IY
#
# DIMMING
# D_IH_M_IH_NG
# D_IH_M_IH_NG
#
# BRAHAM
# B_R_AE_HH_AH_M
# B_R_AE_M_AH_M
#
# PRATAP
# P_R_AA_T_AH_P
# P_R_AA_T_AH_P
#
# VEY
# V_EY
# V_EY
#
# BLACK
# B_L_AE_K
# B_L_AE_K
#
# PULLBACK
# P_UH_L_B_AE_K
# P_UH_L_B_AE_K
#
# TEGTMEIER
# T_EH_T_M_AY_ER
# T_EH_T_T_M_ER
#
# STRICKLEN
# S_T_R_IH_K_AH_L_AH_N
# S_T_R_IH_K_AH_L_AH_N
#
# ESSEX'S
# EH_S_IH_K_S_IH_Z
# EH_S_EH_K_S_IH_Z
#
# HELMS'S
# HH_EH_L_M_Z_IH_Z
# HH_EH_L_M_Z
#
# ARKANSAS'S
# AA_R_K_AH_N_S_AA_Z
# AA_R_K_AA_N_S_AH_Z
#
# COSTANTINO
# K_OW_S_T_AA_N_T_IY_N_OW
# K_AA_S_T_AA_N_T_AA_N_OW
#
# MARIANNE
# M_AA_R_IY_AE_N
# M_AA_R_IY_IY_N_IY
#
# HENNEBERRY
# HH_EH_N_B_EH_R_IY
# HH_EH_N_B_B_ER_IY
#
# BAILEY
# B_EY_L_IY
# B_EY_L_IY
#
# KALAN
# K_EY_L_AH_N
# K_EY_L_AH_N
#
# EVICT
# IH_V_IH_K_T
# EH_V_IH_K_T
#
# MAWSON
# M_AO_S_AH_N
# M_AO_Z_AH_N
#
# TELESCO
# T_EH_L_EH_S_K_OW
# T_EH_L_EH_S_K_OW
#
# YASSIR
# Y_AE_S_IH_R
# Y_AE_S_ER
#
# CUMMINS
# K_AH_M_IH_N_Z
# K_AH_M_IH_N_Z
#
# PIPPEN
# P_IH_P_AH_N
# P_IH_P_AH_N
#
# INTANGIBLES
# IH_N_T_AE_N_JH_AH_B_AH_L_Z
# IH_N_T_AE_N_AH_N_AH_L_AH_L_Z
#
# HONOURABLE
# AA_N_ER_AH_B_AH_L
# HH_AA_N_R_OW_B_AH_L_AH_L
#
# HEIT
# HH_AY_T
# HH_AY_T
#
# KOURY
# K_AW_R_IY
# K_AO_R_IY
#
# MERABANK
# M_EH_R_AH_B_AE_NG_K
# M_EH_R_B_B_AE_NG_K
#
# THICKEN
# TH_IH_K_AH_N
# TH_IH_K_AH_N
#
# TAO
# T_AW
# T_OW
#
# HELIONETIC
# HH_IY_L_IY_OW_N_EH_T_IH_K
# HH_EH_L_IY_EH_N_EH_T_T_K
#
# LHOMMEDIEU
# L_OW_M_EH_D_Y_UW
# L_OW_M_IY_D_IY
#
# MCANDREW
# M_AH_K_AE_N_D_R_UW
# M_AH_K_AH_N_D_R_UW
#
# HUMANOID
# HH_Y_UW_M_AH_N_OY_D
# HH_UW_M_UW_N_OY_N
#
# DEPRAVATION
# D_EH_P_R_AH_V_EY_SH_AH_N
# D_EH_P_R_AH_V_EY_EY_SH_AH_N
#
# MARKUPS
# M_AA_R_K_AH_P_S
# M_AA_R_K_AH_P_S
#
# TOWBOAT
# T_OW_B_OW_T
# T_OW_B_OW_T
#
# HOVLAND
# HH_AA_V_L_AH_N_D
# HH_AA_V_L_AH_N_D
#
# SHIMEL
# SH_IH_M_AH_L
# SH_IH_M_AH_L
#
# TOYS'
# T_OY_Z
# T_OY_Z
#
# GAAR
# G_AA_R
# G_AA_R
#
# DWARFING
# D_W_AO_R_F_IH_NG
# D_W_AO_R_F_IH_NG
#
# LASHBROOK
# L_AE_SH_B_R_UH_K
# L_AH_S_B_R_UH_K
#
# NAPSTER
# N_AE_P_S_T_ER
# N_AE_P_S_T_ER
#
# COSBY'S
# K_AO_Z_B_IY_Z
# K_AA_S_B_IY_Z
#
# BRAZILIAN
# B_R_AH_Z_IH_L_Y_AH_N
# B_R_AE_Z_AH_L_IY_AH_N
#
# JOGS
# JH_AA_G_Z
# JH_AA_G_Z
#
# MCCLOY
# M_AH_K_L_OY
# M_AH_K_L_OY
#
# BRULEY
# B_R_UW_L_IY
# B_R_UW_L_IY
#
# GEHLE
# JH_EH_HH_AH_L
# JH_EH_L
#
# BLUNTS
# B_L_AH_N_T_S
# B_L_AH_N_T_S
#
# INTRUDES
# IH_N_T_R_UW_D_Z
# IH_N_T_R_UW_D_Z
#
# ENCYCLOPEDIA
# IH_N_S_AY_K_L_AH_P_IY_D_IY_AH
# EH_N_S_IY_K_EH_L_EH_D_IY_AH_AH_AH
#
# NEILD
# N_IY_L_D
# N_AY_L_D
#
# MICROCOMPUTERS
# M_AY_K_R_OW_K_AH_M_P_Y_UW_T_ER_Z
# M_AY_K_R_OW_K_K_M_M_M_AH_T_T_ER_Z
#
# GOUGER
# G_AW_JH_ER
# G_AW_ER
#
# DANCERS
# D_AE_N_S_ER_Z
# D_AE_N_S_ER_Z
#
# MOLLERING
# M_AA_L_ER_IH_NG
# M_AA_L_ER_IH_NG
#
# REPROCESSED
# R_IY_P_R_AO_S_EH_S_T
# R_EH_P_R_AH_S_EH_S_T
#
# KUPRES
# K_UW_P_R_AH_S
# K_UW_P_ER_Z
#
# FUTURISM
# F_Y_UW_CH_ER_IH_Z_AH_M
# F_Y_UW_T_ER_IH_Z_AH_M
#
# RAGER
# R_EY_G_ER
# R_EY_JH_ER
#
# ZARATE
# Z_AA_R_EY_T
# Z_AA_R_EY_T
#
# PRENN
# P_R_EH_N
# P_R_EH_N
#
# WAGGED
# W_AE_G_D
# W_AE_G_D
#
# SCHUYLER
# S_K_AY_L_ER
# SH_W_AY_L_ER
#
# JAMAIL
# JH_AH_M_EY_L
# JH_AE_M_AH_L
#
# YAZOV
# Y_AE_Z_AA_V
# Y_EY_Z_AA_V
#
# FANNED
# F_AE_N_D
# F_AE_N_D
#
# LANGSETH
# L_AE_NG_S_EH_TH
# L_AE_NG_G_S_AH_TH
#
# SEGALAS
# S_EH_G_AH_L_AH_S
# S_EH_G_AA_L_AH_Z
#
# ESME
# EH_Z_M
# EH_S_M
#
# HENNESS
# HH_EH_N_IH_S
# HH_EH_N_N_S
#
# BOOMED
# B_UW_M_D
# B_UW_M_D
#
# HENNESS
# HH_EH_N_IH_S
# HH_EH_N_N_S
#
# HUGGING
# HH_AH_G_IH_NG
# HH_AH_G_IH_NG
#
# MAZOR
# M_AA_Z_AO_R
# M_EY_Z_ER
#
# SMOKEY
# S_M_OW_K_IY
# S_M_OW_K_IY
#
# PROVIDED
# P_R_AH_V_AY_D_AH_D
# P_R_AA_V_AY_D_D
#
# SPLAWN
# S_P_L_AO_N
# S_P_L_N
#
# BRZEZINSKI
# B_R_IH_Z_IH_N_S_K_IY
# B_R_IH_Z_IH_IH_S_K_IY
#
# WOMACK
# W_OW_M_AE_K
# W_OW_M_AA_K
#
# MELNICK
# M_EH_L_N_IH_K
# M_EH_L_N_IH_K
#
# BIEDRZYCKI
# B_IH_JH_IH_T_S_K_IY
# B_IY_D_R_S_IH_IY
#
# PREOCCUPY
# P_R_IY_AA_K_Y_AH_P_AY
# P_R_IY_K_K_AH_P_P
#
# VALENSUELA'S
# V_AE_L_AH_N_Z_W_EY_L_AH_Z
# V_EY_L_EH_N_Y_UW_S_AH_L_AH_Z
#
# FBI
# EH_F_B_IY_AY
# F_IY
#
# JIGS
# JH_IH_G_Z
# JH_IH_G_Z
#
# ADALAH
# AA_D_AA_L_AH
# AA_D_AH_L_AH
#
# DALBERT
# D_AE_L_B_ER_T
# D_AE_L_B_ER_T
#
# GINSU
# G_IH_N_S_UW
# JH_IH_N_S_UW
#
# MO
# M_OW
# M_OW
#
# DEKOM
# D_EH_K_AH_M
# D_EH_K_AH_M
#
# MESOLITHIC
# M_EH_Z_AH_L_IH_TH_IH_K
# M_EH_S_AH_L_IH_TH_IH_K
#
# TOSCO
# T_AO_S_K_OW
# T_OW_S_K_OW
#
# GUSTAVO
# G_AH_S_T_AA_V_OW
# G_UW_S_T_AA_V_OW
#
# CATONE
# K_AH_T_OW_N
# K_AA_T_OW_N_IY
#
# APPROXIMATE
# AH_P_R_AA_K_S_AH_M_AH_T
# AH_P_R_AA_K_S_IH_M_EY_T
#
# WIDGETS
# W_IH_JH_IH_T_S
# W_IH_JH_AH_AH_T_S
#
# GARGUILO
# G_AA_R_G_W_IY_L_OW
# G_AA_R_G_IY_L_OW_L
#
# VEDDER
# V_EH_D_ER
# V_EH_D_ER
#
# PURPOSEFULLY
# P_ER_P_AH_S_F_AH_L_IY
# P_ER_P_AH_F_AH_S_AH_L
#
# PENJA
# P_EH_N_JH_AH
# P_EH_N_JH_AH
#
# DYMOND
# D_AY_M_AH_N_D
# D_IH_M_AH_N_D
#
# KAREN'S
# K_EH_R_AH_N_Z
# K_AA_R_AH_N_Z
#
# FARROWING
# F_AE_R_OW_IH_NG
# F_EH_R_OW_IH_NG
#
# ANDRAS
# AA_N_D_R_AH_S
# AA_N_D_R_AH_Z
#
# BRONCHIAL
# B_R_AA_N_CH_IY_AH_L
# B_R_AA_N_CH_IY_L_L_L
#
# AM
# AE_M
# AE_M
#
# LAKES
# L_EY_K_S
# L_EY_K_S
#
# BOOTHROYD
# B_UW_TH_R_OY_D
# B_UH_TH_R_OY_D
#
# PAISLEY
# P_EY_Z_L_IY
# P_EY_S_L_IY
#
# BUTKUS
# B_AH_T_K_IH_S
# B_AH_K_K_AH_S
#
# HALLET
# HH_AE_L_IH_T
# HH_AE_L_AH_T
#
# PREMISES
# P_R_EH_M_AH_S_AH_Z
# P_R_IH_M_AY_S_IH_Z
#
# AMETHYST
# AE_M_IH_TH_IH_S_T
# AH_M_IH_TH_IY_S_T
#
# COOPRIDER
# K_UW_P_R_AY_D_ER
# K_UW_P_R_AY_D_ER
#
# HOLLOW
# HH_AA_L_OW
# HH_OW_L_OW
#
# ILLUSIONIST'S
# IH_L_UW_ZH_AH_N_AH_S_T_S
# IH_L_UW_S_AH_SH_AH_N_IH_S_T_S
#
# MARTE
# M_AA_R_T
# M_AA_R_T
#
# IMPEDE
# IH_M_P_IY_D
# IH_M_P_IY_D
#
# ROJEK
# R_OW_Y_EH_K
# R_OW_K_IH_K
#
# WHY'D
# W_AY_D
# W_AY_D
#
# YAFFE
# Y_AE_F
# Y_AE_F
#
# GENCORP
# JH_EH_N_K_AO_R_P
# JH_EH_N_K_AO_R
#
# ACTIVATE
# AE_K_T_AH_V_EY_T
# AE_K_T_IH_V_EY_T
#
# UNDER
# AH_N_D_ER
# AH_N_D_ER
#
# SIEVE
# S_IH_V
# S_IY_V
#
# LITAKER
# L_IH_T_EY_K_ER
# L_IH_T_AH_K_ER
#
# OVERVIEW
# OW_V_ER_V_Y_UW
# OW_V_ER_V_Y_UW
#
# CONDRACKY'S
# K_AA_N_D_R_AE_K_IY_Z
# K_AA_N_D_R_AE_K_S_IY_Z
#
# LOE
# L_OW
# L_OW
#
# SURMOUNT
# S_ER_M_AW_N_T
# S_ER_M_AW_N_T
#
# KERINS
# K_EH_R_IH_N_Z
# K_ER_IY_N_Z
#
# BALLENGEE
# B_AH_L_EH_NG_G_IY
# B_AE_L_IH_NG_G_IY
#
# BEERBOWER
# B_IH_R_B_OW_ER
# B_IY_R_B_OW_ER
#
# PROHIBITORY
# P_R_OW_HH_IH_B_AH_T_AO_R_IY
# P_R_OW_HH_IY_B_AH_T_ER_IY
#
# UNDERPAID
# AH_N_D_ER_P_EY_D
# AH_N_D_ER_P_EY_D
#
# BARNACLES
# B_AA_R_N_AH_K_AH_L_Z
# B_AA_R_N_AA_K_AH_L_Z
#
# ODUM
# OW_D_AH_M
# AA_D_AH_M
#
# OUTSTRIPS
# AW_T_S_T_R_IH_P_S
# AW_T_T_T_R_IH_S
#
# INAUGURATES
# IH_N_AO_G_Y_AH_R_EY_T_S
# IH_N_AO_G_ER_EY_T_S
#
# TOBEY
# T_OW_B_IY
# T_OW_B_IY
#
# ZEKE
# Z_IY_K
# Z_IY_K
#
# MARCADE
# M_AA_R_K_EY_D
# M_AA_R_K_EY_D
#
# MUTATING
# M_Y_UW_T_EY_T_IH_NG
# M_Y_UW_T_EY_T_NG
#
# INTERDEPENDENCE
# IH_N_T_ER_D_AH_P_EH_N_D_AH_N_S
# IH_N_T_ER_N_AH_N_D_AH_N_S
#
# CRYPTOSPORIDIUM
# K_R_IH_P_T_OW_S_P_AO_R_IH_D_IY_AH_M
# K_R_AY_P_T_AH_S_P_AO_R_D_D_AH_AH
#
# CLORINDA
# K_L_AO_R_IY_N_D_AH
# K_L_ER_IH_N_D_AH_AH
#
# ONSLOW
# AA_N_S_L_OW
# AA_N_S_L_OW
#
# NAGATA
# N_AA_G_AA_T_AH
# N_AH_G_AA_T_AH
#
# WATERSHED
# W_AO_T_ER_SH_EH_D
# W_EY_T_ER_SH_EH
#
# CHIAPAS
# CH_IY_AA_P_AH_S
# CH_AY_P_P_S
#
# SYNCOM
# S_IH_NG_K_AA_M
# S_IH_NG_K_AH_M
#
# YOSHIHASHI
# Y_OW_SH_IH_HH_AA_SH_IY
# Y_OW_SH_IH_SH_IY
#
# TURENNE
# T_Y_UW_R_IH_N
# T_ER_IY_N_IY
#
# ROSENBLATT
# R_OW_Z_AH_N_B_L_AE_T
# R_OW_Z_AH_N_B_AH_AH_T_T
#
# YOUNKIN
# Y_AH_NG_K_IH_N
# Y_UH_NG_K_IH_N
#
# NANOMETER
# N_AE_N_OW_M_IY_T_ER
# N_AE_N_AH_M_EH_T_ER
#
# RIETH
# R_AY_IH_TH
# R_AY_TH
#
# MALSON
# M_AE_L_S_AH_N
# M_AE_L_S_AH_N
#
# SLIVERS
# S_L_IH_V_ER_Z
# S_L_AY_V_ER_Z
#
# HALLY
# HH_AE_L_IY
# HH_AE_L_IY
#
# MARTIN
# M_AA_R_T_AH_N
# M_AA_R_T_IH_N
#
# BUCKSKINS
# B_AH_K_S_K_IH_N_Z
# B_AH_K_S_IH_IH_Z
#
# SERGEI
# S_ER_G_EY
# S_IH_R_G_IY
#
# BRUNCHES
# B_R_AH_N_CH_IH_Z
# B_R_AH_N_CH_IH_Z
#
# IAVARONE
# IY_AA_V_ER_OW_N_IY
# AY_V_AA_R_AA_N_N
#
# INTENSIFY
# IH_N_T_EH_N_S_IH_F_AY
# IH_N_T_IH_N_S_AH_F_AY
#
# BOSNIAN'S
# B_AA_Z_N_IY_AH_N_Z
# B_AA_Z_N_IY_AH_N_Z
#
# FLASHER
# F_L_AE_SH_ER
# F_L_AE_SH_ER
#
# EMBRYONIC
# EH_M_B_R_IY_AA_N_IH_K
# EH_M_B_R_UW_AA_N_IH_K
#
# FIRESTONE
# F_AY_R_S_T_OW_N
# F_AY_R_S_T_OW_N
#
# CLAROSTAT
# K_L_EH_R_AH_S_T_AE_T
# K_L_EH_R_OW_S_AE_T
#
# DESKTOPS
# D_EH_S_K_T_AA_P_S
# D_EH_S_K_AA_P_S
#
# SCOUNDRELS
# S_K_AW_N_D_R_AH_L_Z
# S_K_AO_N_D_ER_AH_L_Z
#
# BUTTAFUOCO
# B_UW_T_AH_F_W_OW_K_OW
# B_UW_T_AH_F_OW_K_UW
#
# NELINA
# N_EH_L_IY_N_AH
# N_EH_L_IY_N_AH
#
# FINELLI
# F_IH_N_EH_L_IY
# F_IH_N_EH_L_IY
#
# CULTON
# K_AH_L_T_AH_N
# K_AH_L_T_AH_N
#
# PELLEGRINI
# P_EH_L_EH_G_R_IY_N_IY
# P_EH_L_EH_G_R_AA_N_IY_IY
#
# HILGEMAN
# HH_IH_L_G_M_AH_N
# HH_IH_L_G_M_AH_N
#
# MOPE
# M_OW_P
# M_OW_P
#
# TERMINABLE
# T_ER_M_AH_N_AH_B_AH_L
# T_ER_M_AH_N_AH_B_AH_L
#
# SUTCH
# S_AH_CH
# S_AH_CH
#
# DREWRY
# D_R_UW_R_IY
# D_R_UW_R_IY
#
# MATZINGER
# M_EY_T_S_IH_NG_ER
# M_AE_T_Z_AY_NG_ER
#
# THUY
# T_UW
# TH_AY
#
# DEPREZ
# D_EY_P_R_EH_Z
# D_EH_P_R_AH_Z
#
# NOTICEABLE
# N_OW_T_AH_S_AH_B_AH_L
# N_AA_T_IH_SH_AH_B_AH_L
#
# ORIGAMI
# AO_R_IY_G_AA_M_IY
# AO_R_IH_G_AA_M_IY
#
# ENGLBRED
# EH_G_AH_L_B_R_EH_D
# EH_NG_G_L_R_B_ER_D
#
# ANTEATER
# AE_N_T_IY_T_ER
# AE_N_T_IY_EY_ER
#
# HELMS'
# HH_EH_L_M_Z
# HH_EH_L_M_Z
#
# SPADARO
# S_P_AA_D_AA_R_OW
# S_P_AA_D_AA_R_OW
#
# POLYGLOT
# P_AA_L_IH_G_L_AA_T
# P_OW_L_IH_P_L_AH_T
#
# ESCORTING
# EH_S_K_AO_R_T_IH_NG
# EH_S_K_AO_R_T_IH_NG
#
# FELDPAUSCH
# F_EH_L_D_P_AW_SH
# F_EH_L_D_F_AO_K
#
# BANOS
# B_AA_N_OW_Z
# B_AA_N_OW_Z
#
# LANNAN
# L_AE_N_AH_N
# L_AE_N_AH_N
#
# VALUE
# V_AE_L_Y_UW
# V_AE_L_IY
#
# PRUER
# P_R_UW_ER
# P_R_UW_ER
#
# SUSA
# S_UW_S_AH
# S_UW_S_AH
#
# GINNIE
# JH_IH_N_IY
# JH_IH_N_IY
#
# AMNESIA
# AE_M_N_IY_ZH_AH
# AE_M_N_IY_ZH_IY
#
# BATHE
# B_EY_DH
# B_AE_DH
#
# UNLIVABLE
# AH_N_L_IH_V_AH_B_AH_L
# AH_N_L_AH_V_AH_B_AH_L
#
# COSTILLA
# K_OW_S_T_IH_L_AH
# K_OW_S_T_IH_L_AH
#
# EDMOND
# EH_D_M_AH_N_D
# EH_M_M_AH_N_D
#
# NARASIMHA
# N_AA_R_AH_S_IH_M_HH_AA
# N_AA_R_AA_M_IY_Z_AH
#
# UNDERSCORING
# AH_N_D_ER_S_K_AO_R_IH_NG
# AH_N_D_ER_S_K_AO_R_IH_NG
#
# LUBAR
# L_UW_B_AA_R
# L_UW_B_ER
#
# DELLER
# D_EH_L_ER
# D_EH_L_ER
#
# MULTIUSER
# M_AH_L_T_IY_Y_UW_Z_ER
# M_AH_L_T_AY_Z_ER
#
# WOOLWINE
# W_UH_L_W_AY_N
# W_UH_L_L_AY_N
#
# GALLING
# G_AO_L_IH_NG
# G_AE_L_IH_NG
#
# QUESTROM
# K_W_EH_S_T_R_AH_M
# K_W_EH_S_T_R_UW_M
#
# STOLARSKI
# S_T_AH_L_AA_R_S_K_IY
# S_T_AH_L_AA_R_S_K_IY
#
# SUBSIDE
# S_AH_B_S_AY_D
# S_AH_B_S_AY_D
#
# PANTERA'S
# P_AA_N_T_EH_R_AH_Z
# P_AE_N_T_ER_AA_AH_Z
#
# ADAPTABLE
# AH_D_AE_P_T_AH_B_AH_L
# AE_D_AH_T_AH_B_AH_L_AH_L
#
# LINDNER
# L_IH_N_D_N_ER
# L_IH_N_N_ER
#
# SINCE
# S_IH_N_S
# S_IH_N_S
#
# DESCENDING
# D_IH_S_EH_N_D_IH_NG
# D_EH_S_S_EH_N_D_NG
#
# ARETSKY
# EH_R_EH_T_S_K_IY
# EH_R_EH_S_K_IY
#
# OVERUSED
# OW_V_ER_Y_UW_Z_D
# OW_V_ER_OW_S_AH
#
# JOHNSON'S
# JH_AA_N_S_AH_N_Z
# JH_AA_N_Z_AH_N_Z
#
# EXPERIMENTS
# IH_K_S_P_EH_R_AH_M_AH_N_T_S
# IH_K_S_P_IH_R_IH_M_AH_N_T_S
#
# JANES
# JH_EY_N_Z
# JH_EY_N_Z
#
# MOWREY
# M_AO_R_IY
# M_OW_R_IY
#
# MYKLEBUST
# M_IH_K_AH_L_B_AH_S_T
# M_IH_K_AH_B_B_AH_S_T
#
# ATICO
# AE_T_IH_K_OW
# AE_T_IY_K_OW
#
# RODERICK'S
# R_AA_D_R_IH_K_S
# R_AH_D_ER_IH_K_S
#
# COSMOPULOS
# K_AO_Z_M_AH_P_Y_UW_L_OW_S
# K_OW_S_M_OW_P_Y_UW_L_L_S
#
# CARIDI
# K_AA_R_IY_D_IY
# K_AA_R_AA_D_IY
#
# HYSTERIA
# HH_IH_S_T_EH_R_IY_AH
# HH_IH_S_T_IH_R_IY_AH
#
# DERCOLE
# D_IH_R_K_OW_L_IY
# D_ER_K_OW_L_IY
#
# ZINNO
# Z_IH_N_OW
# Z_IH_N_OW
#
# AEROTECH
# EH_R_OW_T_EH_K
# EH_R_AW_T_EH_K
#
# STREITMATTER
# S_T_R_AY_T_M_AH_T_ER
# S_T_R_AY_T_M_EY_T_ER
#
# LAO
# L_AW
# L_EY_OW
#
# EISENACH
# AY_Z_AH_N_AA_K
# AY_Z_IH_N_AA_K
#
# CREHAN
# K_R_EH_HH_AH_N
# K_R_EY_HH_AH_N
#
# DISASTERS
# D_IH_Z_AE_S_T_ER_Z
# D_IH_S_AH_T_ER_Z
#
# HOOVLER
# HH_UW_V_L_ER
# HH_UH_V_L_L_ER
#
# PURA
# P_UH_R_AH
# P_Y_UW_R_AH
#
# BRINEY
# B_R_IH_N_IY
# B_R_AY_N_IY
#
# METAPHORICAL
# M_EH_T_AH_F_AO_R_IH_K_AH_L
# M_EH_T_AH_F_AH_K_ER_AH_K_AH_L
#
# HINTING
# HH_IH_N_T_IH_NG
# HH_IH_N_T_IH_NG
#
# OFFERED
# AO_F_ER_D
# AH_F_ER_ER
#
# ZHAMBU
# Z_AA_M_B_UW
# Z_AE_M_B_UW
#
# TUNNELING
# T_AH_N_AH_L_IH_NG
# T_AH_N_AH_L_IH_NG
#
# PAPO
# P_AE_P_OW
# P_AA_P_OW
#
# KILMARTIN
# K_IH_L_M_AA_R_T_IH_N
# K_IH_L_M_ER_T_EY_N
#
# SYNAN
# S_AY_N_AH_N
# S_AY_N_AH_N
#
# LEASE'S
# L_IY_S_IH_Z
# L_IY_S_IY_Z
#
# ECKFORD
# EH_K_F_ER_D
# EH_K_F_ER_D
#
# DISMANTLE
# D_IH_S_M_AE_N_T_AH_L
# D_IH_Z_M_AA_N_T_AH_L
#
# CHRIPTOSPORIDIUM
# K_R_IH_P_T_OW_S_P_AO_R_IH_D_IY_AH_M
# K_R_IH_P_T_AH_S_D_AO_R_D_AH_AH_M
#
# BAUD
# B_AO_D
# B_AO_D
#
# GRIBBLES
# G_R_IH_B_AH_L_Z
# G_R_IH_B_AH_L_Z
#
# SIMPLIFIES
# S_IH_M_P_L_AH_F_AY_Z
# S_IH_M_P_L_P_F_AY_Z
#
# HANDLING
# HH_AE_N_D_L_IH_NG
# HH_AE_N_D_L_IH_NG
#
# MENCER
# M_EH_N_S_ER
# M_EH_N_S_ER
#
# LOGICON
# L_AA_JH_IH_K_AA_N
# L_AA_JH_IH_K_AA_N
#
# CULTIVATED
# K_AH_L_T_AH_V_EY_T_IH_D
# K_AH_L_T_IH_V_EY_T_AH
#
# COMTREX
# K_AA_M_T_R_EH_K_S
# K_AA_M_T_R_EH_K_S
#
# HAIRY
# HH_EH_R_IY
# HH_EH_R_IY
#
# FORMER
# F_AO_R_M_ER
# F_AO_R_M_ER
#
# BOARD
# B_AO_R_D
# B_AO_R_D
#
# KOSAN
# K_OW_Z_AH_N
# K_AA_Z_AH_N
#
# FELL
# F_EH_L
# F_EH_L
#
# BORN
# B_AO_R_N
# B_AO_R_N
#
# INAUGURATES
# IH_N_AO_G_Y_AH_R_EY_T_S
# IH_N_AO_G_ER_EY_S_T_S
#
# BIRTHPLACE
# B_ER_TH_P_L_EY_S
# B_ER_TH_F_L_S
#
# WAMPOLE
# W_AA_M_P_OW_L
# W_AE_M_P_OW_L
#
# WESSLER
# W_EH_S_L_ER
# W_EH_S_L_ER
#
# SPARKING
# S_P_AA_R_K_IH_NG
# S_P_AA_R_K_IH_NG
#
# CREDITING
# K_R_EH_D_AH_T_IH_NG
# K_R_EH_D_IH_T_IH_NG
#
# RAMSBURG
# R_AE_M_S_B_ER_G
# R_AE_M_Z_B_AH_G_ER_G
#
# DEFLECTION
# D_IH_F_L_EH_K_SH_AH_N
# D_EH_F_L_EH_K_SH_AH_N
#
# REMODELING
# R_IH_M_AA_D_AH_L_IH_NG
# R_EH_M_OW_L_EH_L_IH_NG
#
# TANTALUS
# T_AE_N_T_AH_L_AH_S
# T_AE_N_T_AH_L_AH_S
#
# MCCROCKLIN
# M_AH_K_R_AA_K_L_AH_N
# M_AH_K_R_AA_L_IH_L
#
# INTERPRETING
# IH_N_T_ER_P_R_EH_T_IH_NG
# IH_N_T_ER_P_R_R_R_IH_T_T_NG
#
# BEEKER
# B_IY_K_ER
# B_IY_K_ER
#
# ALLOMORPH
# AE_L_AH_M_AO_R_F
# AO_L_AH_M_AO_R_F
#
# KASSAN
# K_AE_S_AH_N
# K_AE_S_AH_N
#
# TUSCAN
# T_AH_S_K_AH_N
# T_AH_S_AH_AH_N
#
# SPONSEL
# S_P_AA_N_S_AH_L
# S_P_AA_N_S_AH_L
#
# BROWNELL
# B_R_AW_N_EH_L
# B_R_OW_N_AH_L
#
# REIHER
# R_AY_HH_ER
# R_AY_ER
#
# AXA
# AE_K_S_AH
# AE_K_S_AH
#
# BLUMENSHINE
# B_L_AH_M_IH_N_SH_AY_N
# B_L_UW_M_IH_N_SH_AH_N
#
# DONATION
# D_OW_N_EY_SH_AH_N
# D_AA_N_EY_SH_AH_N
#
# NONGOVERNMENT
# N_AA_N_G_AH_V_ER_N_M_AH_N_T
# N_AA_NG_G_ER_M_AH_N_T
#
# TABLESPOON
# T_EY_B_AH_L_S_P_UW_N
# T_EY_B_AH_L_S_P_UW_N
#
# WEHE
# W_IY_HH
# W_IY
#
# BUCCANEERS
# B_AH_K_AH_N_IY_R_Z
# B_AH_K_AH_N_ER_ER_Z
#
# HANDKERCHIEF
# HH_AE_NG_K_ER_CH_IH_F
# HH_AE_N_D_ER_CH_F
#
# SHECKLER
# SH_EH_K_L_ER
# SH_EH_K_L_ER
#
# SLOVENLINESS
# S_L_AH_V_AH_N_L_IY_N_AH_S
# S_L_AH_V_L_L_AY_N_AH_S
#
# DONIGER
# D_AA_N_IH_G_ER
# D_AA_N_IH_G_ER
#
# VAPE
# V_EY_P
# V_EY_P
#
# PRIORS
# P_R_AY_ER_Z
# P_R_AY_ER_Z
#
# COMANCHES
# K_AH_M_AE_N_CH_IY_Z
# K_AH_M_AA_N_CH_IY_Z
#
# FURTHERMORE
# F_ER_DH_ER_M_AO_R
# F_ER_DH_ER_HH_AO_R
#
# KALLIO
# K_AE_L_IY_OW
# K_AA_L_IY_OW
#
# MATTEA
# M_AE_SH_AH
# M_AE_T_AH
#
# MINES
# M_AY_N_Z
# M_AY_N_Z
#
# TARTNESS
# T_AA_R_T_N_AH_S
# T_AA_R_T_N_AH_S
#
# CADMAN
# K_AE_D_M_AH_N
# K_AE_D_M_AH_N
#
# HOFFLER
# HH_AO_F_AH_L_ER
# HH_AO_F_L_ER
#
# EX
# EH_K_S
# EH_K_S
#
# CAMEO
# K_AE_M_IY_OW
# K_AH_M_IY_OW
#
# TELLES
# T_EH_L_Z
# T_EH_L_Z
#
# DEVELOPERS'
# D_IH_V_EH_L_AH_P_ER_Z
# D_IY_V_AH_L_AH_P_ER_Z
#
# HOLZER
# HH_OW_L_Z_ER
# HH_OW_L_Z_ER
#
# DIANE
# D_AY_AE_N
# D_AY_EY_N
#
# DICTATORSHIP
# D_IH_K_T_EY_T_ER_SH_IH_P
# D_IH_K_T_EY_K_T_R_SH_AH
#
# LINEAGES
# L_IH_N_IY_IH_JH_IH_Z
# L_IH_N_IH_JH_AH_Z
#
# ALLEGES
# AH_L_EH_JH_IH_Z
# AE_L_IH_JH_IY_Z
#
# OBJECTIONABLE
# AH_B_JH_EH_K_SH_AH_N_AH_B_AH_L
# OW_B_JH_EH_K_Y_AH_N_EY_AH_AH_L
#
# LAREDO
# L_ER_EY_D_OW
# L_AA_R_EH_D_OW
#
# SOUDER
# S_AW_D_ER
# S_AW_D_ER
#
# WORRY
# W_ER_IY
# W_ER_IY
#
# ELSTER
# EH_L_S_T_ER
# EH_L_S_T_ER
#
# THERRIEN
# TH_EH_R_IY_N
# TH_EH_R_IY_N_N
#
# MARNIE
# M_AA_R_N_IY
# M_AA_R_N_IY
#
# MAZOLA
# M_AH_Z_OW_L_AH
# M_OW_Z_OW_L_AH
#
# EUROFIMA
# Y_UW_R_AH_F_IY_M_AH
# Y_UW_R_OW_F_M_AH_AH
#
# CONSTERNATION
# K_AA_N_S_T_ER_N_EY_SH_AH_N
# K_AA_N_S_T_ER_EY_EY_SH_AH_N
#
# POPWELL
# P_AA_P_W_EH_L
# P_AA_P_W_EH_L
#
# DUE
# D_UW
# D_UW
#
# ROUBAL
# R_UW_B_AE_L
# R_UW_B_AH_L
#
# BLAIR
# B_L_EH_R
# B_L_EY_R
#
# PERSPIRING
# P_ER_S_P_AY_R_IH_NG
# P_ER_S_P_AY_R_NG
#
# MACYS
# M_EY_S_IY_Z
# M_AE_K_IH_Z
#
# COYM
# K_OY_M
# K_OY_M
#
# CARESSE
# K_AA_R_EH_S
# K_ER_EH_S
#
# CHILCOTT
# CH_IH_L_K_AO_T
# CH_IH_K_K_AA_T
#
# ENHOLM
# EH_N_HH_OW_L_M
# EH_N_HH_OW_M
#
# JU
# JH_UW
# JH_UW
#
# RIMBEY
# R_IH_M_B_IY
# R_IH_M_B_IY
#
# RAHN
# R_AE_N
# R_AA_N
#
# VOLGA
# V_AA_L_G_AH
# V_OW_L_G_AH
#
# SCHIRO
# S_K_IH_R_OW
# SH_IY_R_OW
#
# PUNJAB
# P_AH_N_JH_AA_B
# P_AH_N_JH_AA_B
#
# POMRENZE
# P_AA_M_R_AH_N_Z
# P_AA_M_R_AH_N_Z
#
# BROADSIDED
# B_R_AO_D_S_AY_D_IH_D
# B_R_AO_D_S_AY_D_D
#
# ELFREDA
# EH_L_F_R_EH_D_AH
# EH_L_F_R_EY_D_AH
#
# REGISTERING
# R_EH_JH_IH_S_T_ER_IH_NG
# R_IH_JH_AH_S_T_IH_R_IH_NG
#
# HEMMINGSON
# HH_EH_M_IH_NG_S_AH_N
# HH_EH_M_IH_NG_S_AH_N
#
# DENDRITIC
# D_EH_N_D_R_IH_T_IH_K
# D_EH_N_D_R_IH_T_IH_K
#
# CALLIOPE
# K_AH_L_AY_AH_P_IY
# K_AA_L_IY_P_OW_P
#
# LUNDY
# L_AH_N_D_IY
# L_AH_N_D_IY
#
# COPYCAT
# K_AA_P_IY_K_AE_T
# K_AA_P_IH_K_AE_T
#
# AMOROSO
# AA_M_AO_R_OW_S_OW
# AH_M_ER_OW_S_OW
#
# KAPLOWITZ
# K_AA_P_L_AH_W_IH_T_S
# K_AE_P_L_AH_W_IH_T_S
#
# Верно: 4151 слов из 10000

# %%
test = pd.read_csv('/content/gdrive/My Drive/test.csv')
test_w = test['Word'].values

# %%
len(test_w)
# Out:
# 41597

# %%
for i in range(len(test_w)):
    test_w[i] = ' '.join(test_w[i])

# %%
test_w
# Out:
# array(['P I T C H E D', 'D I S S O L V E R S', 'S C R A W N Y', ...,
#        'S C O G I N', 'H E S S I O N', 'T A R N O W S K I'], dtype=object)

# %%
def evaluate_test(encoder, decoder):
    res = []
    for el in test_w:
        print(el)
        output_sym, attentions = evaluate(encoder, decoder, el)
        output_word = '_'.join(output_sym)
        res.append(output_word)
        print(output_word)
        print('')
    return res

# %%
res_w = evaluate_test(encoder1, decoder1)
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# B_EH_R_EH_T_OW
#
# P A I R I N G
# P_EH_R_IH_NG
#
# L E P P A R D
# L_EH_P_ER_D
#
# A L S U P
# AH_L_S_UW_P
#
# G R I M A C E S
# G_R_IH_M_AH_S_IH_Z
#
# C H R Y S A N T H E M U M
# K_R_IH_S_AH_N_TH_UW_M_M
#
# P A N T I E S
# P_AE_N_T_IY_Z
#
# R O U L E T T E
# R_UW_L_EH_T
#
# B A N K N O T E S
# B_AE_N_K_OW_N_T_S
#
# M C G A V I N
# M_AH_G_EY_V_AH_N
#
# M O S K A T E L ' S
# M_AA_S_K_AH_T_AH_L_Z
#
# G R U N T E D
# G_R_AH_N_T_IH_D
#
# A L C A T E L
# AE_L_K_EY_T_AH_L
#
# F L U N K E D
# F_L_AH_NG_K_T
#
# C O J I M A R ' S
# K_OW_JH_IY_M_ER_Z
#
# P R E S E A S O N
# P_R_IH_Z_IH_S_AH_N
#
# G O N G S
# G_AA_NG_Z
#
# E L E C T S
# IH_L_EH_K_T_S
#
# D I F F I C U L T I E S
# D_IH_F_IH_K_Y_UW_L_IY_IY_Z
#
# P L A U S I B I L I T Y
# P_L_AO_S_IH_B_IH_L_IH_T_IY
#
# P L U N K I T T
# P_L_AH_N_K_IH_T
#
# R O C K E R
# R_AA_K_ER
#
# P R A B
# P_R_AE_B
#
# J U L I A N A
# JH_UW_L_IY_IY_N_AH
#
# T O M B
# T_AA_M
#
# G O L D F I N C H
# G_OW_L_D_F_IH_N_F
#
# D U R A B L E
# D_UH_R_AH_B_AH_L
#
# S A T H E R
# S_AE_DH_ER
#
# R O D I C K
# R_AA_D_IH_K
#
# F R E T T E R
# F_R_EH_T_ER
#
# A R I S T E D E ' S
# AA_R_IH_S_T_IY_D_Z
#
# D E E T E R
# D_IY_T_ER
#
# B A R B E C U E
# B_AA_R_B_Y_UW_K
#
# H E R N A N D E Z
# HH_ER_N_AH_N_D_EH_Z
#
# F E L I C I A
# F_AH_L_IY_SH_AH
#
# S I N I S E
# S_IH_N_IH_Z
#
# F R I T O S
# F_R_IH_T_OW_Z
#
# S T O T T L E M Y E R
# S_T_AA_T_L_L_M_IH_ER
#
# Z U G
# Z_UW_G
#
# R E F L E X
# R_IH_F_L_EH_K_S
#
# H U C K
# HH_AH_K
#
# N U T T E R S
# N_AH_T_ER_Z
#
# C A U L K I N S
# K_AO_L_K_IH_N_Z
#
# E L B E R
# EH_L_B_ER
#
# B I B B
# B_IH_B
#
# T E I G E N
# T_AY_G_AH_N
#
# R E G A T T A S
# R_IH_G_AE_T_AH_Z
#
# F R E E I N G
# F_R_IY_IH_NG
#
# M E H L H O F F
# M_EH_L_HH_AO_F
#
# L A R Y N G O S C O P Y
# R_AA_R_IH_NG_G_OW_P_OW_OW_P_IY
#
# R U S Z K O W S K I
# R_AH_Z_K_AO_F_S_K_IY
#
# S Q U I T I E R I
# S_K_W_IH_T_IY_R_IY
#
# L I C K T E I G
# L_IH_K_T_AY_IH
#
# T W E A K I N G
# T_W_IY_K_IH_NG
#
# P O H A N G
# P_OW_HH_AE_NG
#
# C O L G A T E ' S
# K_AA_L_G_EY_T_S
#
# P I G M I E D
# P_IH_G_M_IY_D
#
# M I D S T
# M_IH_D_S_T
#
# D E S P A I N
# D_IH_S_P_EY_N
#
# A G O N I S T S
# AH_G_AH_N_IH_S_T_S
#
# F O R G I N G S
# F_AO_R_G_IH_NG_Z
#
# K I M M I T T
# K_IH_M_IH_T
#
# L E I T C H
# L_AY_CH
#
# G U I N Y A R D
# G_AY_N_W_ER_R_D
#
# N O B L E
# N_OW_B_AH_L
#
# M A R I N E L L I
# M_AA_R_IH_N_EH_L_IY
#
# A M O S
# AA_M_OW_Z
#
# S U R R E A L I S M S
# S_UW_R_IY_AH_L_IH_M_Z
#
# O R D E A L
# AO_R_D_IY_AH
#
# B R O A C H E S
# B_R_OW_CH_AH_Z
#
# W E A T H E R H O L T Z
# W_EH_T_ER_HH_AO_L_T_S
#
# V E N T O L A
# V_EH_N_T_OW_L_AH
#
# L I N S E
# L_IH_N_Z
#
# P A L O N E
# P_AA_L_OW_N
#
# C A R P E N C I C ' S
# K_AA_R_P_IH_N_S_IH_K_S
#
# N E W B E R R Y
# N_UW_B_EH_R_IY
#
# O D D S M A K E R
# AA_D_Z_M_EY_K_ER
#
# G R I M L E Y
# G_R_IH_M_L_IY
#
# H E R S C U
# HH_ER_R_K_Y_UW
#
# S C U D S
# S_K_AH_D_Z
#
# D I S T I L L E R S '
# D_IH_S_T_AY_ER_Z
#
# S T E L L E R
# S_T_EH_L_ER
#
# C A R N I C E R O
# K_AA_R_N_IH_S_ER_OW
#
# R O U S I N G
# R_AW_Z_IH_NG
#
# D I Z Z I N E S S
# D_IH_Z_IH_AY_N_IH_S
#
# D E L U S I O N S
# D_IH_L_UW_ZH_AH_N_Z
#
# R A Y B O R N
# R_EY_B_AO_R_N
#
# S E N T
# S_EH_N_T
#
# M O N T A G E
# M_AA_N_T_AH_JH
#
# L I M B E R
# L_IH_M_B_ER
#
# S H E P H E R D E D
# SH_IH_F_ER_D_D
#
# W A R O N K E R
# W_AO_R_AH_N_K_ER
#
# S I D E R S '
# S_AY_D_ER_Z
#
# D E C A R A V A
# D_IH_K_AA_R_AA_V_AH
#
# S E L F - O R G A N I S A T I O N
# S_EH_L_F_Y_ER_G_R_IH_EY_SH_AH_N
#
# C A S T I L L E
# K_AA_S_T_AY_L
#
# B E R T R A D E
# B_ER_T_R_EY_D
#
# L U M B E R M A N
# L_AH_M_B_ER_M_AH_N
#
# C O N V E R T E R S
# K_AA_N_V_ER_T_ER_Z
#
# C L A R K S B U R G
# K_L_AA_R_S_B_AO_R_G
#
# H O M E S T E A D E R S
# HH_OW_M_EH_S_T_ER_D_ER_Z
#
# T U L L I U S
# T_UW_L_IY_AH_S
#
# C A R B O N A R A
# K_AA_R_B_OW_N_ER_AH
#
# S T A N L E Y
# S_T_AE_N_L_IY
#
# A M G E N ' S
# AE_M_JH_AH_N_Z
#
# P A S S B O O K
# P_AE_S_B_UH_K
#
# N A T T I E
# N_AE_T_IY
#
# H A N D C L A S P
# HH_AE_N_D_K_L_P_P_S
#
# G A U N T N E S S
# G_AO_N_T_AH_AH_S
#
# L O N S K I
# L_AA_N_S_K_IY
#
# M E Y
# M_EY
#
# A K E N S
# AH_K_AH_N_Z
#
# S T A C I E
# S_T_EY_SH_IY
#
# C A U C U S E S
# K_AO_K_Y_UW_Z_IH_Z
#
# C O N F I S C A T E
# K_AH_N_F_IH_S_K_EY_T
#
# N A B O B
# N_AA_B_OW
#
# F A N T A S I Z E S
# F_AE_N_T_AH_Z_AY_Z_IH_Z
#
# L A R E N A
# L_EH_R_EH_N_AH
#
# P A L K O V I C
# F_AE_L_K_AH_V_IH_K
#
# H A S S L E
# HH_AE_S_AH_L
#
# D I S T E N D
# D_IH_S_T_AH_N_D
#
# G A T L I N G
# G_AE_T_L_IH_NG
#
# P R I T Z K E R S
# P_R_IH_T_S_K_ER_Z
#
# F O R B E S
# F_AO_R_B_Z
#
# M A I N E R
# M_EY_N_ER
#
# B A U K N I G H T
# B_AO_K_N_AY_T
#
# D O R M A N
# D_AO_R_M_AH_N
#
# V E R H O F F
# V_ER_HH_AO_F
#
# S U N U N U
# S_UW_N_UW_N_UW
#
# S A E Z
# S_EY_Z
#
# D E U P R E E
# D_UW_P_R_IY
#
# E X T E N D A B L E
# IH_K_S_T_EH_N_D_AH_B_AH_L
#
# P O E H L
# P_OW_L
#
# M E L A N B Y
# M_EH_L_AH_N_B_IY
#
# R E F O R E S T
# R_IH_F_AO_R_IH_S_T
#
# R E V E A L S
# R_IH_V_IY_L_Z
#
# P R I Z M
# P_R_IH_Z_M_M
#
# D I S A P P O I N T I N G
# D_IH_S_AO_P_IH_T_IH_NG
#
# G U L L ' S
# G_AH_L_Z
#
# M I Z Z E L L
# M_IH_Z_Z_AH_L
#
# R U S T L E
# R_AH_S_AH_L
#
# B U R N I S H E D
# B_ER_N_IH_SH_T
#
# E R L E
# ER_L
#
# P E R S H A R E
# P_ER_SH_AH_EH
#
# H E R S K O V I T Z
# HH_ER_S_K_V_IH_T_IH_T
#
# C A B L E C
# K_AH_B_L_AH_K
#
# A V I O N S
# EY_V_Y_AH_N_Z
#
# T I K I
# T_IY_K_IY
#
# I R R E S I S T I B L Y
# IH_R_IH_S_IH_T_IH_L_L_IY
#
# M A D A Y
# M_EY_D_EY
#
# M A Z Z I O T T I
# M_AA_Z_IY_UW_OW_T_IY
#
# S A L L S
# S_AO_L_Z
#
# A D A K
# AH_D_AH_K
#
# P L U M M E T I N G
# P_L_AH_M_AH_T_IH_NG
#
# R U M S O N
# R_AH_M_S_AH_N
#
# T W O N S H E I N
# T_W_AA_N_SH_AY_N
#
# F A D I M A N
# F_AY_D_IH_M_AH_N
#
# D E R E G U L A T E D
# D_IH_R_IH_JH_AH_L_EY_T_EY_D
#
# D U N F E E
# D_AH_N_F_IY
#
# I N C I P I E N T
# IH_N_S_IH_P_AH_N_T
#
# R O W ' S
# R_OW_Z
#
# C O N N E C T E D
# K_AH_N_EH_K_T_AH_D
#
# B O U R G E O I S I E
# B_AO_R_JH_UW_JH_IY
#
# R E P R I S A L S
# R_IH_P_R_IH_AH_AH_L_Z
#
# S I L L I E R
# S_IH_L_IY_ER
#
# O P P O R T U N I S T
# AA_P_ER_R_AH_T_OW_N_IH_S_T
#
# B U R S T S
# B_ER_S_T_S
#
# A L B E R D I N G
# AE_L_B_ER_B_IH_NG
#
# D I S L O C A T E D
# D_IH_Z_L_AH_K_EY_T_IH_D
#
# E R L Y
# IH_L_IY_IY
#
# E L I Z A B E T H
# IH_L_IH_Z_B_AE_TH
#
# P A S C A L
# P_AE_S_K_AH_L
#
# M C C A F F E R T Y
# M_AH_K_AE_F_ER_IY_T_IY
#
# K N U D T S O N
# K_N_AH_D_S_AH_N
#
# N Y M P H
# N_IH_M_F
#
# M A C H E
# M_EY_SH
#
# J U N J I
# JH_UW_N_JH_IY
#
# Z A C H R Y
# Z_AE_K_R_IY
#
# F I L E
# F_AY_L
#
# R E P E T I T I O N
# R_IH_P_IH_T_IY_SH_AH_N
#
# D A N N
# D_AE_N
#
# S K Y W R I T E R S
# S_K_AY_T_R_IY_T_ER_Z
#
# M C K I E
# M_AH_K_IY
#
# O G N I B E N E
# AA_G_N_IY_B_IY_N
#
# F A K E R
# F_EY_K_ER
#
# V E G E T A T E
# V_EH_JH_AH_T
#
# M I L I C E N T
# M_IH_L_IH_S_AH_N_T
#
# B R I N N E R
# B_R_IH_N_ER_ER
#
# J E A N I N E
# JH_IY_N_IY_N
#
# F U R B I S H E S
# F_ER_B_IH_SH_AH_Z
#
# G R E G U S
# G_R_IY_G_AH_S
#
# W O L B E R T
# W_OW_L_B_ER_T
#
# E X C A V A T I O N S
# IH_K_S_K_AE_V_EY_SH_AH_N_Z
#
# T R E E S H
# T_R_IY_SH
#
# T A C I T A
# T_AA_CH_IY_T_AH
#
# C A N V A S
# K_AE_N_V_AH_Z
#
# D E S O T O
# D_IH_S_OW_T_OW
#
# L E N E T A
# L_EH_N_EH_T_AH
#
# D U R A T I O N S
# D_ER_EY_SH_AH_N_Z
#
# C O R O N E T S
# K_ER_OW_N_AH_T_S
#
# A R M S T R O N G ' S
# AA_R_M_S_T_R_IH_G_Z
#
# H O L S C L A W
# HH_AA_S_L_L_AO
#
# S U F F I X
# S_AH_F_IH_K_S
#
# U N H A P P I L Y
# AH_N_HH_AE_P_L_IY_IY
#
# S C H O L L M E Y E R
# SH_AA_L_M_AY_ER
#
# M I N E O L A
# M_IH_N_IY_OW_L_AH
#
# I N V O L V E S
# IH_N_V_OW_L_V_Z
#
# S T I C H T E R
# S_T_IH_K_T_ER
#
# B E T
# B_EH_T
#
# O M A N I
# OW_M_AA_N_IY
#
# J U D G E S '
# JH_AH_JH_IH_Z
#
# D E L U X E
# D_IH_L_AH_K_S
#
# W E I D E R M A N
# W_AY_D_ER_M_AH_N
#
# U N D E R G A R M E N T
# AA_N_D_ER_G_ER_R_EY_M_AH_N_T
#
# I N A N E
# IH_N_EY_N
#
# C I T I C O R P ' S
# S_IH_T_IH_K_AO_R_P_S
#
# S E L K I R K
# S_EH_L_K_ER_K
#
# S T U P A Y
# S_T_UW_P_EY
#
# B O U N D A R I E S
# B_AW_N_D_ER_R_IY_Z
#
# D O U B T F I R E
# D_AW_T_F_B_EH_R
#
# B I N D E L
# B_IH_N_D_AH_L
#
# B L A N K E N B U R G
# B_L_AE_NG_K_AH_N_B_ER_G
#
# B U R N E L L
# B_ER_N_AH_L
#
# J O U S T I N G
# JH_AW_S_T_IH_NG
#
# K M E T Z
# K_EH_M_S_T
#
# Z U K I N
# Z_UW_K_IH_N
#
# I M P E C C A B L Y
# IH_M_P_EH_K_K_IH_B_L_IY
#
# S Q U E E Z E S
# S_K_W_EH_Z_IH_Z
#
# W A W R Z Y N I A K
# W_AO_R_Z_IH_N_IY_AE_AE
#
# A U L L
# AO_L
#
# J O E N S
# JH_OW_N_Z
#
# R O A S T I N G
# R_OW_S_T_IH_NG
#
# L I F E - G I V I N G
# L_AY_F_AY_V_IH_NG
#
# K N E L L
# N_EH_L
#
# A D V A N C E M E N T S
# AH_D_V_AE_N_S_M_AH_N_T_S
#
# B E N A Z I R
# B_IH_N_AA_Z_ER
#
# M E T A M O R P H O S I S
# M_EH_T_AO_R_M_P_F_OW_S
#
# W O H L E R
# W_OW_L_ER
#
# F O I A
# F_OY_AH
#
# A S T R O P H Y S I C S
# AE_S_T_R_AH_F_IH_K_S
#
# D O R F M A N
# D_AO_R_F_M_AH_N
#
# R E Q U I S I T E
# R_IH_K_W_IH_Z_AY_T
#
# T R I - S T A T E
# T_R_IY_S_T_EY_T
#
# G O M B O S
# G_AA_M_B_OW_Z
#
# L A T O N I A
# L_AA_T_OW_N_IY_AH
#
# E C O N O M O S
# IH_K_AH_N_OW_M_OW_Z
#
# H E R S H K O W I T Z
# HH_ER_S_K_W_IH_T_S
#
# T I N C T U R E
# T_IH_NG_K_CH_UH_R
#
# M A G N E T I T E
# M_AE_G_G_AH_T_AY_T
#
# F R A N C O I S
# F_R_AE_N_K_OY_Z
#
# F L A N A G I N
# F_L_AE_N_IH_G_IH_N
#
# R U L E Y
# R_UW_L_IY
#
# R O N C A
# R_AA_NG_K_AH
#
# P R E T T Y
# P_R_EH_T_IY
#
# D Y L A N S
# D_AY_L_AH_N_Z
#
# D A P H N I S
# D_AE_F_N_IY_Z
#
# S W I N D L E S
# S_W_IH_N_D_AH_L_Z
#
# C R E C H E
# K_R_IY_CH
#
# G O R G O N I A N
# G_AO_R_G_OW_N_IY_AH_N
#
# M A R B L E
# M_AA_R_B_AH_L
#
# T R A P
# T_R_AE_P
#
# D E F O L I A N T S
# D_IH_F_OW_L_AH_AH_T_S
#
# B I G E L O W
# B_IH_G_IH_L_OW
#
# H A N S O N
# HH_AE_N_S_AH_N
#
# C R O A T
# K_R_OW_T
#
# A S T R O D O M E
# AA_S_T_R_OW_D_OW_M
#
# M A N G A
# M_AE_NG_G_AH
#
# A N G E L
# AE_NG_G_AH_L
#
# E D I T H
# EH_D_IH_TH
#
# G A R E T H
# G_EH_R_IH_TH
#
# V A C A T I O N S
# V_EY_K_EY_SH_AH_N_Z
#
# K I N A R K
# K_IH_N_ER_K
#
# M C A R D L E
# M_AH_K_AA_R_D_AH_L
#
# G A L L I V A N
# G_AE_L_V_IH_N
#
# F U N C K
# F_AH_NG_K
#
# S N I F F E R
# S_N_IH_F_ER
#
# B L A N K E N H O R N
# B_L_AE_NG_K_AO_R_N_ER_N
#
# U N B I A S E D
# AH_N_B_IY_S_T
#
# O B E R S T A R
# OW_B_ER_S_T_AA_R
#
# B R A N D I S
# B_R_AE_N_D_IH_Z
#
# O C T O G E N A R I A N
# AA_K_T_OW_JH_EH_R_IY_AH_N
#
# G L E N N O N
# G_L_EH_N_AH_N
#
# C R Y S L E R
# K_R_IH_S_L_ER
#
# K I C K
# K_IH_K
#
# D E T E R M I N E D
# D_IH_T_ER_M_AY_N_D_D
#
# W E N F A N
# W_EH_N_F_AH_N
#
# M I L L I L I T R E
# M_IH_L_IH_L_IH_T
#
# H O N O R E
# AA_N_ER_R
#
# O D E N T H A L
# AA_D_AH_N_TH_AA_L
#
# D E V I A N C Y
# D_IH_V_IH_AH_N_S_IY
#
# P S E U D O N Y M S
# S_AY_D_AH_N_IH_Z_M_Z
#
# I R E Y
# IH_R_IY
#
# S I U D A
# S_UW_D_AH
#
# B A T C H
# B_AE_CH
#
# C E N V I L L
# S_EH_N_V_IH_L
#
# A D D R E S S E D
# AH_D_R_EH_S_T
#
# P I N Y
# P_IH_N_IY
#
# F A Y E T T E
# F_EY_EY_T
#
# A C C O M P L I S H I N G
# AH_K_AH_M_P_L_L_SH_IH_NG
#
# G R A P P L E S
# G_R_AE_P_AH_L_Z
#
# C O L E G R O V E
# K_OW_L_EH_G_R_OW_V
#
# B A C K E S
# B_AE_K_S
#
# A S S O C I A T I O N
# AH_S_AH_SH_AH_EY_SH_AH_N
#
# A S H M A N
# AE_SH_M_AH_N
#
# E N C R O A C H
# IH_N_R_OW_K
#
# G I R A U D
# G_IH_R_OW
#
# D E N E N B E R G
# D_IH_N_AH_N_B_ER_G
#
# L A I N
# L_EY_N
#
# R E G A L A D O
# R_IH_G_AH_L_AA_D_OW
#
# E C U A D O R ' S
# IH_K_Y_UW_D_ER_Z
#
# L E N I G
# L_EH_N_IH_G
#
# K I L A
# K_IY_L_AH
#
# M U T I L A T I N G
# M_Y_UW_T_AH_L_EY_T_IH_NG
#
# I V O R I A N
# IH_V_AO_R_IY_AH_AH
#
# W O E H R
# W_AO_R
#
# R U D D I C K
# R_AH_D_IH_K
#
# W I L L I N G E R
# W_IH_L_IH_NG_ER
#
# M E L I T T A
# M_EH_L_EH_T_AH
#
# P H A N T A S M
# F_AE_N_T_AH_Z_M_M_AH_Z
#
# P O R T E O U S
# P_AO_R_T_IY_OW_S
#
# M A F I A ' S
# M_AA_F_AY_AH_Z
#
# R E A L - W O R L D
# R_IY_L_W_ER_L_D
#
# P A R A S I T E S
# P_EH_R_AH_S_AY_T_S
#
# B A G H L I
# B_AE_G_L_IY
#
# K I T T E N S
# K_IH_T_AH_N_Z
#
# I M M O B I L I Z E D
# IH_M_B_OW_L_AY_Z_Z
#
# G R I E V I N G
# G_R_IY_V_IH_NG
#
# U N B U N D L E
# AH_N_B_AH_N_D_AH_B_L_L
#
# T U O H Y
# T_UW_UW
#
# S H A M A L I A
# SH_AA_M_AA_L_IY_AH
#
# F A C T U A L
# F_AE_CH_UW_UW_L
#
# S C H E I B E L
# SH_AY_B_AH_L
#
# L U X E M B O U R G
# L_AH_Z_K_Y_UW_B_AO_R_M
#
# T R A N S C R I B E R
# T_R_AE_N_S_K_AY_B_ER_ER
#
# R E G U L A T I V E
# R_IY_G_AH_L_EY_T_IH_V
#
# B L E M I S H E S
# B_L_EH_M_IH_SH_IH_Z
#
# O L S T E N
# OW_L_S_T_AH_N
#
# F I N A N C E
# F_IH_N_AH_N_S
#
# O K A M O T O
# OW_K_AE_M_OW_T_OW
#
# D I S R U P T S
# D_IH_S_R_AH_P_T
#
# C O N S E N S U S
# K_AA_N_S_EH_N_UW_S
#
# P R O O F S
# P_R_UW_F_S
#
# P C S
# P_IH_S_IY_IY_Z
#
# S A M I R
# S_AA_M_IH_R
#
# B A M B E R G E R
# B_AE_M_B_ER_G_ER
#
# H A I L E Y
# HH_EY_L_IY
#
# C R A N K S
# K_R_AE_NG_K_S
#
# T R E B L E D
# T_R_EY_B_AH_L_D
#
# B L A C K L I S T E D
# B_L_AE_K_L_IH_Z_T_IH_D
#
# P A R N E S S
# P_AA_R_N_AH_S
#
# D I S T R I B U T O R ' S
# D_IH_S_T_IH_B_Y_AH_T_ER_Z
#
# A P A C S
# AH_P_AE_K_S
#
# H I L L S O N
# HH_IH_L_S_AH_N
#
# V I N Y L
# V_IH_N_IH_L_L
#
# A V I T A L
# AH_V_IH_T_AH_L
#
# R E N O I R S
# R_IH_N_ER_R_Z
#
# N E A R Y
# N_EH_R_IY
#
# D A Y L I G H T S
# D_EY_L_AY_T_S
#
# X I A M E N
# Z_AY_M_AH_N
#
# J O N K E R
# JH_AA_NG_K_ER
#
# C U T C H A L L
# CH_AH_CH_AH_L
#
# S N O W S T O R M S
# S_N_OW_T_S_M_AO_R_Z
#
# D E S P I C A B L E
# D_IH_S_P_AY_K_AH_B_AH_L
#
# R O R R E R
# R_OW_R_ER
#
# H I P P O C R A T E S
# HH_IH_P_AH_K_R_EY_T_S
#
# L E T H I A
# L_EH_TH_IY_AH
#
# S P O O K
# S_P_UW_K
#
# I O W A ' S
# AY_OW_OW_Z
#
# H I N D R A N C E
# HH_IH_N_D_R_AH_N_S
#
# S L A N E
# S_L_EY_N
#
# G R A N D P A S
# G_R_AE_NG_D_P_AH_Z
#
# K A L M A N O V I T Z
# K_AE_L_M_AE_N_IH_V_IH_T_IH_T_S
#
# C R A N N I E S
# K_R_AE_N_IY_Z
#
# W A B A S H
# W_AA_B_AH_SH
#
# D E F E A T S
# D_IH_F_IY_T_S
#
# C A P T A I N ' S
# K_AE_P_T_AH_N_Z
#
# F R I G H T E N I N G
# F_R_AY_T_AH_N_IH_NG
#
# M A Q U I L A D O R A
# M_AA_K_W_AY_L_D_D_R_AH
#
# C H I B A
# CH_IY_B_AH
#
# R E M I N I S C E S
# R_IH_M_AH_N_IH_S_IH_Z
#
# W I T H E R
# W_IH_DH_ER
#
# K A T A Y A N
# K_EY_T_AY_AH_N
#
# C H I L D C R A F T
# CH_IY_L_D_K_R_AE_F_T
#
# J E F F U S
# JH_EH_F_AH_S
#
# Q U I N T S
# K_W_IH_N_T_S
#
# V A N N O R M A N
# V_AA_N_ER_AO_R_M_AH_N
#
# P E Y R E L E V A D E
# P_AY_ER_L_EH_D_EY_V
#
# I N S T A N T
# IH_N_S_T_AH_N_T
#
# G E N I E
# G_EH_N_IY
#
# C O M P L E T I O N
# K_AH_M_P_L_IH_SH_AH_N
#
# H E R N E R
# HH_ER_N_ER
#
# Z U R I C H ' S
# Z_Y_UW_R_IH_K_Z
#
# R E U T E R
# R_UW_T_ER
#
# K N E E R
# N_IH_R
#
# J A R Y L
# ZH_ER_R_IH_L
#
# B R E T H
# B_R_EH_TH
#
# C R O S S L I N
# K_R_AA_S_L_IH_N
#
# F A R R E N S
# F_EH_R_AH_N_Z
#
# M O R R O
# M_AO_R_OW
#
# S C H E I N E R
# SH_AY_N_ER
#
# C E R I D I A N
# S_IH_R_IH_D_IY_AH_N
#
# D I L B E R T
# D_IH_L_B_ER_T
#
# V E N T E R S
# V_EH_N_T_ER_Z
#
# R O G A L A
# R_OW_G_AA_L_AH
#
# F E N D I N G
# F_EH_N_D_IH_NG
#
# R E C O G N I Z A N C E
# R_IH_G_AH_N_S_G_EY_S
#
# P E L L A N D
# P_EH_L_AH_N_D
#
# T R I P L E
# T_R_IH_P_AH_L
#
# E N V O S
# EH_N_V_OW_Z
#
# A C C O M M O D A T I N G
# AA_K_OW_M_M_EY_D_EY_T_IH_NG
#
# O U T F L O W
# AW_T_F_L_OW
#
# B U N G E
# B_AH_N_JH
#
# A R T W O R K
# AA_R_T_R_ER_K
#
# G Y M N A S I U M S
# G_IH_M_N_EY_Z_IY_Z_M_M_AH_Z
#
# A D A H
# AE_D_AH_F
#
# H O M E - G R O W N
# HH_OW_M_R_M_AW_R_N
#
# P R A W N
# P_R_AO_N
#
# W H I M
# W_IH_M
#
# S A L M A N
# S_AA_L_M_AH_N
#
# Q U E L L E T T E
# K_W_EH_L_EH_T
#
# B I L Z E R I A N ' S
# B_IH_L_Z_IH_R_IY_AH_N_Z
#
# T O Y E
# T_OY
#
# Q U I E T I S T
# K_W_EH_T_IH_S_T
#
# B E A R E R
# B_IH_R_ER
#
# M A R K E D
# M_AA_R_K_T
#
# T E A G A R D E N
# T_EH_G_AA_R_D_ER_R_AH_N
#
# A E R O M E X I C O
# IH_R_OW_M_EH_K_OW_OW_OW_OW_OW
#
# U N P A Y A B L E
# AH_N_P_EY_AH_AH_B_L_L
#
# H O A R D E D
# HH_AO_R_D_IH_D
#
# K U N S T L E R
# K_AH_N_S_T_ER_ER
#
# G R O U P E R
# G_R_UW_P_ER
#
# A M I R A V
# AA_M_ER_R_AE_V
#
# D E N K E R
# D_EH_NG_K_ER
#
# O U T L A S T S
# AW_T_L_AE_S_T_S
#
# U N I O N D A L E
# AA_N_IY_N_OW_N_D_AH_L
#
# B A C K B O A R D
# B_AE_K_B_AO_R_D
#
# L I F L A N D
# L_IH_F_L_AH_N_D
#
# S A N T E R R E
# S_AE_N_T_ER_R
#
# C H A N N E L L
# SH_AE_N_EH_L
#
# F I T C H E T T
# F_IH_CH_EH_T
#
# K A L L
# K_AE_L
#
# B A R I N G ' S
# B_EH_R_IH_NG_Z
#
# P I E C U C H
# P_IY_CH_UH_K
#
# L E V E R O N E
# L_EH_V_ER_OW_N
#
# F U J I S A W A
# F_Y_UW_JH_IH_Z_AA_AH
#
# L O A N S '
# L_OW_N_Z
#
# R A T I O N A L L Y
# R_EY_SH_AH_N_AH_L_IY
#
# L E I K E N
# L_AY_K_AH_N
#
# L A M I A
# L_AA_M_IY_AH
#
# D E R C H I N
# D_ER_CH_IH_N
#
# I N C O N G R U I T Y
# IH_NG_K_AO_R_M_AH_JH_AH_T
#
# S A L T S M A N
# S_AA_L_T_M_AH_N
#
# K W O K
# K_W_AA_K
#
# P A R D O E
# P_AA_R_D_OW
#
# G R I T T E R
# G_R_IH_T_ER
#
# F I R E B O M B
# F_IH_R_AH_B_AO_M
#
# P O W L E S S
# P_AW_L_Z
#
# M I N I M U M S
# M_IH_N_IH_M_AH_M_Z
#
# C E L S
# S_EH_L_Z
#
# K R E E G E R
# K_R_IY_G_ER
#
# N E W B O L D
# N_UW_B_AO_L_D
#
# H O W S O N
# HH_AW_Z_AA_N
#
# H E M L E R
# HH_EH_M_L_ER
#
# B U T T R U M
# B_AH_T_R_AH_M
#
# R E A L I Z I N G
# R_IY_IH_L_AY_Z_IH_NG
#
# C A L A D I U M S
# K_AE_L_AH_D_IY_AH_M_Z
#
# C L E V I E
# K_L_IY_V_IY
#
# C A V A N
# K_AA_V_AH_N
#
# P A L M I S A N O
# P_AA_L_M_IH_S_AA_N_OW
#
# M O N E T A R I S T
# M_AA_N_IH_T_ER_IH_S_T
#
# H A R S H F I E L D
# HH_AA_R_SH_F_IY_L_D
#
# J U S T E R
# JH_AH_S_T_ER
#
# F E L T S M A N
# F_EH_L_S_T_M_AH_N
#
# E X A C E R B A T I N G
# IH_G_Z_AE_R_B_EY_SH_AH_NG
#
# S K I P P E R S
# S_K_IH_P_ER_Z
#
# V I D E O P H I L E
# V_AY_D_D_OW_F_AY_L_L
#
# S H O R T H A N D
# SH_AO_R_TH_AH_N_D
#
# S A L E E B Y
# S_AE_L_AH_B_IY
#
# H U L S M A N
# HH_AH_L_M_AH_N
#
# M E A L Y
# M_IY_L_IY
#
# P A S O
# P_AA_S_OW
#
# I M A G I N G
# IH_M_EY_JH_IH_NG
#
# B R E S H E A R S
# B_R_IH_SH_IH_R_Z
#
# M A S T I F F
# M_AE_S_T_IH_F
#
# D E G R A Y
# D_EH_G_R_EY
#
# P A D U L A
# P_AA_D_UW_L_AH
#
# M A N N E S M A N N
# M_AA_N_EH_Z_M_AH_N
#
# M O T E L S
# M_OW_T_EH_L_Z
#
# C A S E Z E
# K_AH_Z_EH_Z
#
# M A L I
# M_AA_L_IY
#
# E X T R A P O L A T I N G
# IH_K_S_T_R_OW_P_L_L_EY_T_IH_NG
#
# F A X
# F_AE_K_S
#
# T I S H E R
# T_IH_SH_ER
#
# I N C L O S U R E
# IH_N_K_L_OW_ZH_ER
#
# B E D O L L A
# B_EH_D_OW_L_AH
#
# C O L L E C T I V I Z E D
# K_AA_L_T_IY_K_V_AY_Z_D
#
# Y O E S
# Y_OW_Z
#
# W E I R D O
# W_EH_R_D_OW
#
# U N W O R T H Y
# AH_N_W_ER_DH_IY
#
# D U N L E Y
# D_AH_N_L_IY
#
# T I M B E R S
# T_IH_M_B_ER_Z
#
# M A S C O L O
# M_AH_S_K_OW_L_OW
#
# B U R N E T T E
# B_ER_N_EH_T
#
# G L I T Z
# G_L_IH_T_S
#
# M A T Z N E R
# M_AE_T_Z_N_ER_ER
#
# F O E S
# F_OW_Z
#
# E L V I N A
# IH_L_V_IY_N_AH
#
# S M A L L T A L K
# S_M_AO_L_T_AH_K
#
# B E L C H E R
# B_EH_L_CH_ER
#
# A P S O
# AE_P_S_OW
#
# B L A L A C K
# B_L_AE_R_AH_K
#
# N I S S E N B A U M
# N_IH_S_IH_N_B_AO_M
#
# C U S T O D Y
# K_AH_S_T_OW_D_IY
#
# V O L L E R
# V_AA_L_ER
#
# P R E T E N D S
# P_R_EH_T_AH_N_D_Z
#
# S C H O O N E R
# SH_UW_N_ER
#
# T R E L L I S
# T_R_EH_L_IH_S
#
# E Y E S O R E
# IY_S_AO_R
#
# G R I P E S
# G_R_IH_P_S
#
# E A R T H M O V I N G
# IH_R_TH_M_OW_R_OW_V_IH_NG
#
# S A R R I S
# S_EH_R_IH_S
#
# B R A N A G A N
# B_R_AE_N_AH_G_AH_N
#
# K A M P E N
# K_AE_M_P_AH_N
#
# H O N E Y D E W
# HH_AA_N_IH_D_UW_UW
#
# R E N N Y
# R_EH_N_IY
#
# M Y R M I D O N
# M_IH_R_IH_D_AH_N
#
# U N W E L C O M E D
# AH_N_K_EH_L_K_M_D
#
# M A R I C L E
# M_AA_R_IH_K_AH_L
#
# H O R R O R S
# HH_AO_R_ER_Z
#
# E F F L U E N T
# EH_F_L_UW_AH_N_T
#
# A B A D A K A
# AH_B_AA_D_AA_K_AH
#
# A R S E N E A U L T
# AA_R_S_AH_N_T_OW_L_T
#
# P R A C T I C E S
# P_R_AE_K_T_IH_S_IH_Z
#
# U N C O U T H
# AH_N_K_UW_TH
#
# E N V E L O P E
# IH_N_V_IY_L_OW_P
#
# B U Z Z E L L I
# B_AH_T_EH_L_IY
#
# A L P H A B E T I Z E D
# AE_L_F_AH_B_AH_Z_AY_Z_D
#
# P A R D E
# P_AA_R_D
#
# E X E R T E D
# IH_K_S_ER_T_AH_D
#
# H U R T I N G
# HH_ER_T_IH_NG
#
# S E C O N D A R I E S
# S_IY_K_AH_N_D_EH_R_Z
#
# M E A N W H I L E
# M_IY_N_W_UW_L
#
# D I S P E L L
# D_IH_S_P_EH_L
#
# S C U L P T O R
# S_K_AH_L_P_T_ER
#
# L I N E A G E
# L_IH_N_IH_JH
#
# P R O S C R I B E
# P_R_AA_S_K_R_IY_B_IY
#
# B O L D I N G
# B_OW_L_D_IH_NG
#
# K U N E S H
# K_AH_N_EH_SH
#
# S C H E D U L E R
# SH_IY_D_UW_L_ER
#
# R E I N F O R C E S
# R_IH_N_F_AO_R_S_IH_Z
#
# I N T E R M O D A L
# IH_N_T_ER_M_OW_D_AH_L
#
# C L E A N U P S
# K_L_IY_N_AH_AH_P_S
#
# O E S T E R L I N G
# OW_S_T_L_IH_IH_NG
#
# M E D S T O N E
# M_EH_D_S_T_OW_N
#
# F L A M B O Y A N T
# F_L_AE_M_B_OY_AH_N_T
#
# P A L O M A R
# P_AA_L_AA_M_ER
#
# S E R P E N T I N E
# S_ER_P_AH_N_T_IY_N
#
# B U G G Y
# B_AH_G_IY
#
# F I N N E R T Y
# F_IH_N_ER_T_IY
#
# D E R R Y B E R R Y
# D_IH_R_IH_B_EH_R_IY
#
# A D J O U R N
# AH_JH_ER_N
#
# K N O X ' S
# N_AA_K_S_IH_Z
#
# O S H E L
# AA_SH_AH_L
#
# K E E L I N G
# K_IY_L_IH_NG
#
# R E C E R T I F Y I N G
# R_IH_S_ER_T_IH_F_AY_IH_NG
#
# S U L L E N S
# S_AH_L_AH_N_Z
#
# A B O R T I V E
# AH_B_AO_R_T_IH_V
#
# F E U D A L I S T I C
# F_AY_D_AH_L_IH_S_T_IH_K
#
# D A V E Y
# D_EY_V_IY
#
# S C H O O L B U S
# SH_UW_L_B_AH_S
#
# L A U S C H
# L_AO_SH
#
# B L E E D
# B_L_EH_D
#
# P A V L I C
# P_AE_V_L_IH_K
#
# P A R A G U A Y
# P_ER_R_EY_G_W_EY
#
# K O C I
# K_OW_IY
#
# G R O U P
# G_R_UW_P
#
# C H A N D E L I E R
# CH_AE_N_D_IH_L_IY_ER
#
# M A N S F I E L D
# M_AE_N_S_F_IY_L_D
#
# W O R L D C O M
# W_ER_L_D_K_AA_M
#
# G L O R I O U S L Y
# G_R_AO_R_IH_AH_L_L_IY
#
# K H M E R
# K_ER_M_ER
#
# D U L A N Y
# D_UW_L_AH_N_IY
#
# C O N S U L T A N T S '
# K_AH_N_S_AH_L_T_AH_N_T_S
#
# J A C Q U I N
# JH_AE_K_W_IH_N
#
# I N S T A N C E S
# IH_N_S_T_AH_N_S_IH_Z
#
# S E P P I
# S_EH_P_IY
#
# C O W E D A
# K_OW_D_D_AH
#
# H O R V A T H ' S
# HH_AO_R_V_AH_TH
#
# W I K E L
# W_AY_K_AH_L
#
# K A R L S S O N
# K_AA_R_L_S_AH_N
#
# R E E N A C T S
# R_IY_N_AE_AE_T_S
#
# S N U F F I N G
# S_N_UW_F_IH_NG
#
# C I T I Z E N S
# S_IH_T_AY_Z_AH_N_Z
#
# R A B I
# R_AA_B_IY
#
# O ' M E A R A
# OW_M_EH_R_AH
#
# M I L O S E V I C
# M_IH_L_AH_S_IH_V_IH_K
#
# B R Y A N S
# B_R_AY_AH_N_Z
#
# E V A D N E
# IH_V_AE_D_N_IY
#
# B R O C K M E Y E R
# B_R_AA_K_M_AY_ER
#
# S O C K E T
# S_AA_K_EH_T
#
# C O W H E R
# K_AW_ER
#
# B O E H N E
# B_OW_N
#
# Z A G A R
# Z_EY_G_ER
#
# F E R N A N D A
# F_ER_N_D_AA_N_D_AH
#
# H A R R I S E S
# HH_EH_R_IH_S_IH_Z
#
# D A W K I N S
# D_AO_K_IH_N_Z
#
# J U L I N E
# Y_UW_L_AH_N_IY
#
# G A A L
# G_AA_L
#
# V E R D E R B E R
# V_ER_D_ER_B_ER
#
# R O L L I S O N
# R_AA_L_IH_S_AH_N
#
# I N E L A S T I C
# IH_N_AH_L_L_S_T_IH_K
#
# A D M O N I S H E D
# AH_D_M_AH_N_IH_SH_T
#
# I C O N S
# AY_K_AH_N_Z
#
# H E A L T H ' S
# HH_EH_L_TH_S
#
# B A N G L E
# B_AE_NG_G_AH_L
#
# M A R T I N S ' S
# M_AA_R_T_IH_N_Z
#
# P A U P E R
# P_AW_P_ER
#
# H A R A S S I N G
# HH_EH_R_AH_Z_IH_NG
#
# P A R K I N S
# P_AA_R_K_AH_N_Z
#
# K A N D T
# K_AE_N_D_T
#
# D U L I N
# D_UW_L_IH_N
#
# B L A C K E T T
# B_L_AE_K_IH_T
#
# G R O M A N
# G_R_OW_M_AH_N
#
# P A U L L I N
# P_AO_L_IH_N
#
# F I N E X
# F_IH_N_EH_K_S
#
# I N S T R U M E N T A L I S T S
# IH_N_S_T_R_AH_M_M_M_AH_AH_M_AH_AH_AH_T_L_AE_T_S
#
# N E W B O R N S
# N_UW_B_ER_N_Z
#
# C H A M N E S S
# M_AE_N_N_AH_S
#
# W H O O P I E
# W_UW_P_IY
#
# S A K A M O T O
# S_AA_K_AH_M_OW_T_OW
#
# I N D U C E
# IH_N_D_UW_S
#
# M E R T E N S
# M_ER_T_AH_N_Z
#
# F I R M A N S
# F_ER_M_AH_N_Z
#
# I N N A T E L Y
# IH_N_AH_T_L_L_IY
#
# C A R N A U D
# K_AA_R_N_AA_D
#
# B E N I G N O
# B_EH_N_IY_G_OW
#
# R E D U C T I O N S
# R_IH_D_AH_K_SH_AH_N_Z
#
# B E U T H I N
# B_OY_TH_IH_N
#
# H O L L E N D E R
# HH_AA_L_D_IH_N_D_ER
#
# A L L O W A B L E
# AA_L_AH_B_AH_L
#
# N O R T O N
# N_AO_R_T_AH_N
#
# C A R O L ' S
# K_EH_R_AH_L_Z
#
# T I S S U E
# T_IH_S_UW
#
# A T T R A C T I O N
# AH_T_R_AE_K_SH_AH_N
#
# P O L Y P H O N Y
# P_AA_L_IH_F_OW_N_IY
#
# I N I T I O
# IH_N_IY_T_IY_OW
#
# H A R V E S T A B L E
# HH_AA_R_V_AH_S_T_AH_B_AH_L
#
# F E F F E R
# F_EH_F_ER
#
# C O U N T E R W E I G H T S
# K_AW_N_T_ER_W_IH_T_S
#
# S C H O L Z
# SH_OW_L_Z
#
# D O E S N ' T
# D_OW_S_N_T
#
# D R A G
# D_R_AE_G
#
# L U A N D A ' S
# L_UW_AE_N_D_AH_Z
#
# F R I E N D L Y ' S
# F_R_IY_N_D_L_IY_Z_L_IY_Z
#
# D E W A L T
# D_UW_AH_L_T
#
# S P E L L E R S
# S_P_EH_L_ER_Z
#
# C A M B E L L
# K_AE_M_B_AH_L
#
# C H E S T E D
# CH_EH_S_T_AH_D
#
# V A N V A L K E N B U R G
# V_AA_N_V_AH_L_K_AH_B_B_ER_G
#
# H E A N E Y
# HH_IY_N_IY
#
# C L E A V E L A N D
# K_L_IY_V_L_L_AH_N_D
#
# F O R D Y C E
# F_AO_R_D_IH_S
#
# M U T A T E D
# M_Y_UW_T_EY_T_IH_D
#
# M A T T I A S
# M_AE_T_IY_AH_Z
#
# B R A N I L L O
# B_R_AH_N_IH_L_OW
#
# B I L K E D
# B_IH_L_K_D
#
# N I C K N A M E D
# N_IH_K_N_AE_M_D
#
# C O U N T R Y W I D E
# K_AH_N_T_R_UW_D_AY_D_D
#
# G A S T R I T I S
# G_AE_S_T_R_IY_T_IY_Z
#
# P A T H O L O G I S T S
# P_AH_TH_AH_L_IH_JH_IH_S_T_S
#
# M E Y O
# M_IY_OW
#
# T U R Q U O I S E
# T_ER_K_OW_OW_Z
#
# W O R L D E R S
# W_AO_R_D_ER_Z
#
# F I G M E N T S
# F_AY_G_M_AH_N_T_S
#
# F E N I C H E L L
# F_EH_N_IH_K_AH_L
#
# L A B E L ' S
# L_EY_B_EH_L_Z
#
# G I E R
# G_IY_R
#
# H A C K E T T
# HH_AE_K_IH_T
#
# D E D I C A T E
# D_EH_D_IH_K_EY_T
#
# A N D E R S E N ' S
# AE_N_D_ER_S_ER_AH_N_Z
#
# C A R D E N
# K_AA_R_D_AH_N
#
# E I R I C H
# AY_ER_IH_CH
#
# R E L A T I O N A L
# R_IH_L_EY_SH_AH_N_AH_L
#
# G O O D B A R
# G_UH_D_B_AA_R
#
# L A M E S A
# L_AA_M_IY_S_AH
#
# B U B B
# B_AH_B
#
# K I E D R O W S K I
# K_IY_D_R_IH_F_S_K_IY
#
# C R A S N E R
# K_R_AE_S_N_ER
#
# C H A J E T
# HH_EY_JH_EH_T
#
# T I L G H M A N
# T_IH_L_M_JH_AH_N
#
# D I S Q U A L I F I C A T I O N
# D_IH_S_K_W_AH_F_IH_K_Y_AH_L_EY_SH_AH_N
#
# O ' B R E C H T
# OW_B_R_EH_CH
#
# W I S I N S K I
# W_IH_S_IH_N_S_K_IY
#
# A M E N A B L E
# AH_M_AH_N_AH_B_AH_L
#
# R A D I O S
# R_EY_D_IY_OW_Z
#
# H A R A D A
# HH_AA_R_EY_D_AH
#
# F E R M I N
# F_ER_M_IH_N
#
# A D D W E S T
# AH_D_W_EH_S_T
#
# S A V A G E S
# S_EY_V_IH_JH
#
# C A J O L E D
# K_AH_HH_OW_L_D
#
# V E N T U R E D
# V_EH_N_CH_ER_D
#
# W R E N
# R_EH_N
#
# R O T U N N O
# R_OW_T_UW_N_OW
#
# P R I M E R I C A ' S
# P_R_IH_M_EH_R_IH_K_AH_Z
#
# P L O D D I N G
# P_L_AA_D_IH_NG
#
# D E A L
# D_IY_L
#
# A C C E D I N G
# AH_S_IH_D_IH_NG
#
# D E C R I M I N A L I Z A T I O N
# D_IH_K_R_IH_M_AH_L_AH_Z_EY_SH_AH_N
#
# C H A R A C T E R I Z E
# K_AA_R_AH_K_T_ER_AY_Z
#
# V A C A T I O N E D
# V_EY_CH_EY_SH_AH_N_D
#
# N O G U E I R A
# N_OW_G_W_IY_R_IY
#
# B E L E A G U E R
# B_IH_L_IY_G_AO_R
#
# H A M B L I N
# HH_AE_M_B_L_IH_N
#
# S T I N E M A N
# S_T_AY_N_M_AH_N
#
# D I S C O U N T E D
# D_IH_S_K_AW_N_T_IH_D
#
# S U L P H A T E S
# S_AH_L_F_AY_T_S
#
# A E R O B I C S
# IH_R_AH_B_IH_K_S
#
# C O O V I C K
# K_UW_V_IH_K
#
# G R A D E
# G_R_EY_D
#
# G O R B A C H E V ' S
# G_AO_R_B_AH_CH_EH_Z
#
# A N G L I C A N S
# AE_NG_G_IH_K_K_AH_N_Z
#
# R A M B L E R S
# R_AE_M_B_L_ER_Z
#
# G U M P E R T
# G_AH_M_P_T_ER_T
#
# B Y U
# B_Y_UW
#
# B E L A D U R ' S
# B_IH_L_AE_D_ER_Z
#
# G R E T H E R
# G_R_EH_DH_ER
#
# B I A G G I N I
# B_IY_AA_G_IH_N_IY
#
# E A R T H L I N G
# IH_R_TH_L_IH_NG
#
# R I O R D A N
# R_AY_AO_R_D_AH_N
#
# G A N Z E L
# G_AE_N_Z_AH_L
#
# T O O T H
# T_UW_TH
#
# W E I D N E R
# W_AY_D_N_ER
#
# L I L L Y ' S
# L_IH_L_IY_Z
#
# A N N A B L E
# AH_N_AH_B_AH_L
#
# I N D U S T R I A L S
# IH_N_D_AH_T_R_IY_AH_L_Z
#
# Q U E R I E S
# K_EH_IY_IY_Z
#
# J A C I N T H A
# JH_AA_S_IY_N_TH_AH
#
# K A S E Y
# K_EY_S_IY
#
# S L O S H I N G
# SH_L_OW_SH_IH_NG
#
# A N N U N Z I A T A
# AA_N_UW_Z_IY_N_OW
#
# R U C K E L S H A U S
# R_AH_K_AH_L_UW_UW
#
# C L E A N N E S S
# K_L_IY_N_N_AH_S
#
# S H E E N S
# SH_IY_N_Z
#
# I N C O N S T A N C Y
# IH_N_K_AO_N_T_S_IH_IY
#
# B O U W K A M P
# B_AW_K_M_AE_P
#
# B A S I L I C A
# B_AH_S_IH_L_AA_K_AH
#
# I N D A B A
# IH_N_D_AA_B_AH
#
# B R E I D E N B A C H
# B_R_AY_D_IH_N_B_AA_K
#
# W O O D L A N D
# W_UH_D_L_AH_N_D
#
# B I T T E R S
# B_IH_T_ER_Z
#
# W E S T H E I M E R
# W_EH_S_T_HH_AY_M_ER
#
# I N S T I T U T I O N S
# IH_N_S_T_IH_SH_AH_N_Z
#
# M O E N
# M_OW_N
#
# U R B A N O
# ER_B_AA_N_OW
#
# I N T U I T I O N
# IH_N_T_UW_OW_SH_AH_N
#
# C H E E R I O S
# CH_EH_R_IY_OW_Z
#
# B U D D I E R
# B_AH_D_IY_ER
#
# F L Y P A P E R
# F_L_AY_P_EY_P_ER
#
# L O U R
# L_AO_R
#
# I N M A C
# IH_M_N_AE_K
#
# M A N U F A C T U R E
# M_AE_N_Y_AH_F_AE_K_CH_ER
#
# R E C A L C I T R A N C E
# R_IH_K_AH_L_T_IH_N_T_R_EY_N
#
# L O C K L I N
# L_AA_K_L_IH_N
#
# S H R E D S
# SH_R_EH_D_Z
#
# P A G L I A R O
# P_AA_G_L_IY_R_IY
#
# U N P R O T E C T E D
# AH_N_P_R_AH_K_EH_K_T_AH_D
#
# U N D E R P R I C I N G
# AH_N_D_ER_P_R_IH_S_IH_NG
#
# S T I T C H E S
# S_T_IH_CH_IH_Z
#
# S H I N K O
# SH_IH_NG_K_OW
#
# B O M B E R ' S
# B_AA_M_B_ER_Z
#
# D I S A R M E D
# D_IH_S_ER_M_D
#
# D E N O M I N A T E D
# D_IH_N_AH_M_AH_N_EY_T_IH_D
#
# T R Z A S K A
# T_R_AH_S_K_AH_K
#
# M O R E S O
# M_AO_R_EH_S_OW
#
# M O N O T Y P E
# M_AA_N_OW_T_AY_P
#
# P O S T D A T E D
# P_AA_S_T_AE_AE_T_IH_D
#
# M A L K I N
# M_AE_L_K_IH_N
#
# Y O W
# Y_OW
#
# A M U L E T S
# AH_M_Y_UW_L_AH_T_S
#
# V E R B
# V_ER_B
#
# E D I F Y
# IH_D_IH_F_AY
#
# L E B E A U
# L_EH_B_OW
#
# A R P I N O
# AA_R_P_IY_N_OW
#
# W O J C I K
# W_UW_CH_IH_K
#
# V E R N E S
# V_ER_N_Z
#
# A S Y N C H R O N O U S
# AH_S_IH_N_R_IH_CH_AH_N_S
#
# B E R M
# B_ER_M
#
# P A R C H
# P_AA_R_CH
#
# S L A T E S
# S_L_EY_T_S
#
# G R Z Y W I N S K I
# G_IH_Z_IH_IH_IH_S_K_IY_IY
#
# K I M C H I
# K_IH_M_CH_IY
#
# C R O M B I E
# K_R_AA_M_B_IY
#
# S C H U T T L E R
# SH_AH_T_AH_L_ER
#
# H A R R I S B U R G H
# HH_EH_R_IH_B_B_R_B
#
# K A M P E L M A N
# K_AA_M_P_AH_L_M_AH_N
#
# H O E L T E R
# HH_OW_L_T_ER
#
# S I E L S K I
# S_IY_L_L_S_K_IY
#
# A R I E L L A
# AA_R_IY_L_L_AH
#
# C R I M I N A L I S T
# K_R_IH_M_AH_N_AH_L_IH_S_T
#
# S I N N E T T
# S_IH_N_IH_T
#
# T I N Y
# T_IH_N_IY
#
# M A K I
# M_AA_K_IY
#
# C A B A L L E R O
# K_AA_B_AA_L_ER_OW
#
# S T A H L
# S_T_AA_L
#
# P U B L I C - S P I R I T
# P_AH_B_L_IH_K_P_R_IH_K_IH_T
#
# T R I C K S T E R S
# T_R_IH_K_T_IH_Z
#
# S A R A B I A
# S_AA_R_EY_SH_AH
#
# W A T T E N B U R G
# W_AO_T_W_N_B_ER_G
#
# F E R R I E R A
# F_EH_R_IY_R_AH
#
# S O N N E T
# S_AA_N_IH_T
#
# H I L D
# HH_IH_L_D
#
# W A I V E R
# W_EY_V_ER
#
# C A N I D A
# K_AA_N_IY_D_AH
#
# T E L U S T R A T O R
# T_EH_L_AH_S_T_AA_T_ER
#
# S K O W R O N E K
# S_K_AO_R_AH_N_EH_K
#
# F I G U E R A S
# F_AY_G_W_ER_AH_Z
#
# O U T S T A N D I N G
# AW_T_S_AE_N_D_IH_NG
#
# R E S N I C K ' S
# R_IH_S_N_IH_K_S
#
# P U N I S H
# P_AH_N_IH_SH
#
# Z E I D E R S
# Z_AY_Z_ER_Z
#
# P H O T O P H O R E S I S
# F_OW_T_ER_OW_F_ER_R_IY_SH
#
# G I U R E S C U
# G_IH_R_IH_S_K_UW
#
# W L O D A R S K I
# L_AH_D_AA_R_S_K_IY
#
# P A R E N T H O O D
# P_EH_R_IH_N_T_HH_UH_D
#
# O P E R A N T
# AA_P_ER_AE_N_T
#
# K R A G E R
# K_R_EY_JH_ER
#
# R E C U S I N G
# R_IH_K_Y_UW_Z_IH_NG
#
# O G R E
# OW_G_R
#
# B A R I C H
# B_EH_R_IH_K
#
# U L C E R
# AH_L_S_ER
#
# B R U F F
# B_R_AH_F
#
# L E N N A R D
# L_EH_N_D_ER_D
#
# S H O C K W A V E
# SH_AA_K_K_AH_V_EY_V
#
# S H I N W A
# SH_IH_N_W_AH
#
# S I L K E N
# S_IH_L_K_AH_N
#
# H E R B S T E R
# HH_ER_B_S_T_ER
#
# C U R E T O N
# K_Y_EH_R_AH_T
#
# G O T W A L T
# G_OW_T_W_AO_L_T
#
# P H E N O T Y P E S
# F_EH_N_AH_T_IY_P_Z
#
# M E N T A L
# M_EH_N_T_AH_L
#
# R E C O N Q U E R E D
# R_IY_K_AO_N_K_ER_D
#
# B R E S E E
# B_R_IH_Z_IY
#
# G A M U T
# G_AE_M_AH_T
#
# P A N I A G U A
# P_AE_N_IY_OW_G_AH
#
# C A R P O R T S
# K_AA_R_P_ER_R_T
#
# O R N A M E N T
# AO_R_N_AH_M_EH_N_T
#
# N O N - T U R B O S
# N_AA_N_T_ER_B_OW_Z
#
# A N T I T O X I N S
# AE_N_T_IH_K_AH_K_T_IH_N_Z
#
# A L L I N S O N
# AE_L_IH_N_S_AH_N
#
# Z A G U R Y
# Z_AE_G_ER_IY
#
# S H O P P I N G
# SH_AA_P_IH_NG
#
# K U I P E R S
# K_Y_UW_P_ER_Z
#
# B R A I D S
# B_R_EY_D_Z
#
# A U D R I S
# AO_D_R_IH_Z
#
# K L A U S N E R
# K_L_AO_S_N_ER
#
# H I D E R
# HH_AY_D_ER
#
# K O T E L E S
# K_OW_T_EH_L_Z
#
# O L E S K Y
# AH_L_EH_S_K_IY
#
# A P P R O P R I A T I N G
# AA_P_R_AH_P_R_EY_T_IH_NG
#
# I M I T A T O R S
# IH_M_IH_T_EY_T_ER_Z
#
# G R I D L E Y
# G_R_IH_D_L_IY
#
# S T A H L E Y
# S_T_AE_L_IY
#
# C H U B B U C K
# CH_AH_B_AH_K
#
# R E C A P T U R E
# R_IH_K_AE_P_CH_ER_AH
#
# P R I G M O R E
# P_R_IH_M_M_AO_R
#
# B I N G E D
# B_IH_NG_D
#
# R E V I S I T
# R_IH_V_IH_ZH_AH_T
#
# N O T I O N S
# N_OW_SH_AH_N_Z
#
# T O N
# T_AA_N
#
# U N S U P E R V I S E D
# AH_N_S_AH_V_R_IH_V_AY_Z_D
#
# L E T ' S
# L_EH_T_S
#
# C E R T I F I C A T I O N
# S_ER_T_IH_F_IH_K_EY_SH_AH_N
#
# I N F E S T
# IH_N_F_EH_S_T
#
# L A S P I N A
# L_AE_S_P_IY_N_AH
#
# A R A K A K I
# AA_R_AE_K_IY_K
#
# Y A W N S
# Y_AO_N_Z
#
# B A L D O C K
# B_AE_L_D_AA_K
#
# G H O S T
# G_AO_S_T
#
# S U K H U M I
# S_AH_K_UW_M_IY
#
# R O O N E Y ' S
# R_UW_N_IY_Z
#
# F A R B
# F_AA_R_B
#
# D O N I S
# D_AA_N_IH_S
#
# C A N N E R
# K_AE_N_ER
#
# W O O D C A R V E R
# W_UW_D_K_AE_V_ER
#
# P E N D E R
# P_EH_N_D_ER
#
# C O L L I C K
# K_AA_L_IH_K
#
# B A R T O L O M E O
# B_AA_R_T_AH_L_OW_M_OW
#
# H E R E W I T H
# HH_ER_R_UW_TH
#
# S T A G
# S_T_AE_G
#
# H E R N O N
# HH_ER_N_AH_N
#
# I A N N E L L O
# W_AA_N_EH_L_OW
#
# S H A R L E E N
# SH_AA_R_L_IY_N
#
# F L E S H E D
# F_L_EH_SH_T
#
# S T R O Z I E R
# S_T_R_OW_IY_AY_ER
#
# Y E S H I V A
# Y_EH_SH_IH_V_AH
#
# E L O P E
# IY_L_OW_P
#
# T I M O T H Y
# T_IH_M_OW_DH_IY
#
# L E Y
# L_IY
#
# B A Y U L
# B_EY_AH_L
#
# G E R M I S T O N
# G_ER_M_IH_S_T_AH_N
#
# E C O L E
# IH_K_AA_L_IY
#
# M O N T P E L I E R ' S
# M_AA_N_T_P_L_L_Y_ER_Z
#
# L O U G H L I N
# L_UW_G_L_N
#
# F L E E C Y
# F_L_IY_S_IY
#
# C O S M O N A U T S '
# K_OW_Z_M_AO_N_T_Z
#
# S A I N T L Y
# S_EY_N_T_L_IY
#
# A B A C U S
# AE_B_AE_K_AH_S
#
# U N D E R W O O D S
# AH_N_D_ER_W_UH_D_Z
#
# P L A N E S '
# P_L_EY_N_Z
#
# A L L O T E D
# AE_L_OW_T_IH_D
#
# S O L I T A R I N E S S
# S_OW_L_IH_T_IH_R_IY_N_AH_S
#
# T O R I E N T E
# T_AO_R_IY_N_T
#
# T E R R O R I S T
# T_EH_R_AH_R_IH_S_T
#
# D I S T A S T E F U L
# D_IH_S_T_AH_F_AH_L
#
# N E A L L
# N_IY_L
#
# O B T A I N A B L E
# AA_T_T_AH_N_AH_B_AH_L
#
# H I M A L A Y A
# HH_IH_M_AA_L_IY_AH
#
# S L O B B E R
# S_L_AA_B_ER
#
# T A U N T S
# T_AO_N_T_S
#
# L A T T E
# L_AE_T
#
# S T U D I O U S
# S_T_UW_D_UW_AH_S
#
# I N F E R S
# IH_N_F_ER_Z
#
# N O N C O M M E R C I A L
# N_AA_N_K_AO_R_M_EY_M_M_AH_AH_AH
#
# V E R B E K E
# V_ER_B_AH_K
#
# M A Z U R K A S
# M_AH_Z_UW_R_AH_AH_Z
#
# F A W L E Y
# F_AO_L_IY
#
# D E B T H O L D E R
# D_EH_TH_T_HH_OW_L_D_ER
#
# S C H O E N R O C K
# SH_OW_N_R_IH_K
#
# V I N T A G E S
# V_IH_N_T_IH_JH_IH_Z
#
# I N V E R T
# IH_N_V_ER_T
#
# S A T A N I C
# S_AH_T_AE_N_IH_K
#
# B E R T I N O T T I
# B_ER_T_IH_N_OW_T_IY
#
# N O R D S T R O M S
# N_AO_R_D_D_AH_S_T_M_AH_Z
#
# S C L E R O S I S
# S_K_ER_L_OW_S_IH_S
#
# M A I L L A R D
# M_EY_L_ER_D
#
# S P I E D
# S_P_IY_D
#
# S N A P E
# S_N_EY_P
#
# P R O S T
# P_R_AA_S_T
#
# B O D E N S T E I N
# B_AH_D_AH_S_T_AY_N
#
# M O S T E K
# M_AH_S_T_EH_K
#
# A P L O M B
# AE_P_L_AH_M
#
# L O C K M I L L E R
# L_AA_K_M_IH_L_ER
#
# M A R Y L I N
# M_ER_R_IH_L_N
#
# V E R B A L
# V_ER_B_AH_L
#
# H E N K
# HH_EH_NG_K
#
# L O O K U P
# L_UW_K_AH_P
#
# H A R P S T
# HH_AA_R_P_S_T
#
# K N A U S S
# N_AW_S
#
# P I X A R
# P_IH_K_S_ER
#
# T R A N S A T L A N T I C
# T_R_AH_N_Z_IH_L_T_IH_K
#
# C H I P P E R
# SH_IH_P_ER
#
# S O U D E R S
# S_UW_D_ER_Z
#
# C O C K L E S
# K_AA_K_AH_L_Z
#
# T O E N J E S
# T_OW_N_JH_AH_Z
#
# G E N E V A
# G_EH_N_IY_V_AH
#
# K E A N E
# K_IY_N
#
# T A P L I N
# T_AE_P_L_IH_N
#
# S C R A M
# K_R_AE_M
#
# A J A
# EY_JH_AH
#
# F I T Z P A T R I C K
# F_IH_T_Z_P_R_IH_K
#
# A R T
# AA_R_T
#
# C A R D U C C I
# K_AA_R_D_UW_CH_IY
#
# D I D N ' T
# D_IH_D_N_T
#
# Z A P
# Z_AE_P
#
# A R N A L D A
# AA_R_N_AA_L_D_AH
#
# W A S
# W_AA_Z
#
# T R A N S C R I P T I O N S
# T_R_AE_N_S_K_IH_N_P_SH_AH_N_Z
#
# M A G I E
# M_EY_JH_IY
#
# B L A C K L E Y
# B_L_AE_K_L_IY
#
# S O R B U S
# S_AO_R_B_AH_Z
#
# B E A R A
# B_EH_R_AH
#
# K U C H I N S K I
# K_UW_Y_IH_N_S_K_IY
#
# S P O R T E D
# S_P_AO_R_T_IH_D
#
# R E I N I G
# R_IY_N_IH_G
#
# R H A P S O D I Z E
# R_AA_P_S_OW_D_AY_Z
#
# F E S T O O N
# F_EH_S_T_AH_N
#
# N A K A G A W A
# N_AA_K_AA_G_W_AH
#
# H E I F E R
# HH_AY_F_ER
#
# T A L L M A D G E
# T_AE_L_M_AE_JH
#
# C L A X O N
# K_L_AE_S_AH_N
#
# S I M I L A R I T Y
# S_IH_M_IH_L_IH_R_IH_T_IY
#
# N O V O T N E Y
# N_OW_V_AH_N_T_IY
#
# E G G E N B E R G E R
# IH_G_AH_N_B_ER_G_ER
#
# T R O U N C I N G
# T_R_AW_N_S_IH_NG
#
# C H I M A Y O
# CH_IH_M_OW_OW
#
# M A R C I L I O
# M_AA_R_CH_IH_L_IY_OW
#
# A P T
# AE_P_T
#
# G A I S E R
# G_EY_Z_ER
#
# S T I C K L E S
# S_T_IH_K_AH_L_Z
#
# F U J I T S U
# F_Y_UW_JH_IH_T_UW
#
# V A T I C A N ' S
# V_AE_T_IH_K_AH_N_Z
#
# S A T E L L I T E
# S_AH_T_AH_L_AY_T
#
# R E I D
# R_IY_D
#
# G L O N A S S
# G_L_OW_N_AH_S
#
# A D V O
# AE_D_V_OW
#
# Z I Z Z O
# Z_IH_T_OW_OW
#
# W I N G E R T
# W_IH_NG_G_ER_T
#
# O F F S E T T I N G
# AO_F_S_AH_T_IH_NG
#
# M C Q U A Y
# M_AH_K_W_EY
#
# D A R K
# D_AA_R_K
#
# T R O Y A N O S
# T_R_OW_Y_AA_N_OW_Z
#
# P R E D I S P O S I N G
# P_R_IH_D_IH_P_S_OW_Z_IH_NG
#
# P A S S P O R T S
# P_AE_S_P_AO_R_T
#
# L I N Z E Y
# L_IH_N_Z_IY
#
# L I N S A Y
# L_IH_N_S_EY
#
# S U R F A C T A N T
# S_ER_F_AE_K_T_AH_N_T
#
# G A L I O T O
# G_AH_L_IY_OW_T_OW
#
# U N I V E R S I T Y
# Y_UW_IH_IH_V_ER_S_IH_T_IY
#
# W A V E D
# W_EY_V_D
#
# P R O V A B L E
# P_R_OW_V_AH_B_AH_L
#
# L I F E R
# L_IH_F_ER_ER
#
# M A N A K
# M_AH_N_AH_K
#
# T U R B O C H A R G E D
# T_ER_CH_AA_B_R_AE_G_D
#
# I N T E R C E D I N G
# IH_N_T_ER_S_IH_D_IH_NG
#
# P R U ' S
# P_R_UW_Z
#
# P E A L
# P_IY_L
#
# H U T N I C K
# HH_AH_T_N_IH_K
#
# M I T H C E L L
# M_IH_TH_S_AH_L
#
# C H I M E R A
# CH_IH_M_ER_AH
#
# L E G G E D
# L_EH_G_D
#
# N O B O D Y
# N_OW_B_OW_D_IY
#
# B R E H M
# B_R_EH_M
#
# C H U A N G
# SH_AH_NG
#
# S U B A N D R I O
# S_UW_B_AA_N_D_R_IY_OW
#
# M E I N Z E R
# M_IH_N_Z_ER_ER
#
# H A A C K E
# HH_AA_K
#
# H E D L E Y
# HH_EH_D_L_IY
#
# K I T Z H A B E R
# K_IH_T_Z_B_AA_Z_ER
#
# D ' O R S A Y
# D_AO_R_S_EY
#
# B R E E D S
# B_R_IY_D_Z
#
# C H E O N G
# SH_IY_NG
#
# O V E R H E A R S
# OW_V_ER_HH_IH_Z_ER_Z
#
# D E N N I N G E R
# D_IH_N_IH_NG_ER
#
# S O L A
# S_OW_L_AH
#
# A S H E N F E L T E R
# AE_SH_AH_N_F_EH_L_T_ER
#
# P E N D E R G A S T
# P_EH_N_D_ER_AE_AE_S_T
#
# D E C K E R ' S
# D_EH_K_ER_Z
#
# E F F I C A C I O U S
# IH_F_IH_SH_IH_SH_AH_Z
#
# H O R M U Z
# HH_AO_R_M_AH_Z
#
# L I N A G E
# L_IH_N_IH_JH
#
# B U S B E E
# B_AH_S_B_IY
#
# D A R
# D_AA_R
#
# P R O L I F E R A T I N G
# P_R_OW_L_IH_F_ER_EY_T_IH_NG
#
# S C H I E S S E R
# SH_IY_S_ER
#
# K E R B
# K_ER_B
#
# M A R G I N S
# M_AA_R_JH_IH_N_Z
#
# V E V I L A
# V_EH_V_IH_L_AH
#
# A N C E S T O R S
# AE_N_S_EH_S_T_ER_Z
#
# R E D R A F T
# R_IY_D_R_AE_F_T
#
# T H A L L I U M
# TH_AE_L_IY_AH_M
#
# T O N K
# T_AA_NG_K
#
# S T R A D A
# S_T_R_AA_D_AH
#
# B A T H K E
# B_AE_TH_K
#
# B U L G A R I A N S
# B_AH_L_G_ER_IY_IY_AH_Z
#
# G U I N D O N
# G_W_IH_N_D_AH_N
#
# C R U C I F Y
# K_R_UW_S_UW_F_AY
#
# J A C K I ' S
# JH_AE_K_IY_Z
#
# C O M M I E
# K_AA_M_IY
#
# S H I T H O L E
# SH_IH_CH_OW_L
#
# N A T I O N A L I Z I N G
# N_EY_SH_AH_N_AH_L_AY_Z_IH_NG
#
# E L I S H A
# EH_L_IY_SH_AH
#
# D E S P E R A T E
# D_IH_S_P_ER_EY_T
#
# H A N N I
# HH_AE_N_IY
#
# B I S P I N G
# B_IH_S_P_IH_NG
#
# I N T E N T I O N E D
# IH_N_T_EH_N_SH_AH_N_D
#
# D E P O P U L A T I O N
# D_IH_P_AH_P_Y_AH_L_EY_SH_AH_N
#
# P R O U T
# P_R_AW_T
#
# R E S T I N G
# R_EH_S_T_IH_NG
#
# N A T A L I A
# N_AA_T_AA_L_IY_AH
#
# S K I R V I N
# S_K_ER_R_V_IH_N
#
# L E I B O V I T Z
# L_IY_B_AH_V_IH_T_S
#
# W E I S E N T H A L
# W_AY_S_AH_N_T_AH_L
#
# K E A H E Y
# K_IY_HH_IY
#
# F A Y E Z
# F_EY_EH_Z
#
# M A K H O U L
# M_EY_K_UW_L
#
# M I K L E S
# M_IH_K_AH_L_Z
#
# H O L L E N K A M P
# HH_AA_L_AH_N_AE_AE_M_P
#
# B O T T L E R S
# B_AA_T_AH_ER_Z
#
# A D J U D I C A T I O N
# AH_JH_D_D_IH_K_EY_SH_AH_N
#
# H E R T Z
# HH_ER_T_S
#
# B A R R A S
# B_EH_R_AH_Z
#
# D E T E R R I N G
# D_IH_T_ER_IH_NG
#
# S C A R A N O
# S_K_EH_R_AA_N_OW
#
# D A B A H
# D_AE_B_AH
#
# B L A C K L I S T I N G
# B_L_AE_K_L_AH_S_T_IH_NG
#
# S P R I G G S
# S_P_R_IH_G_Z
#
# B E A C H A M
# B_IY_CH_AH_M
#
# B L I N C O E
# B_L_IH_NG_K_OW
#
# P E C K E N P A U G H
# P_EH_K_AH_N_P_AO
#
# S P L A S H
# S_P_L_AE_SH
#
# H A Z E
# HH_EY_Z
#
# M I Y A G A W A
# M_AY_Y_AA_M_AA_G_AH
#
# P A C K M A N
# P_AE_K_M_AH_N
#
# C O M M E R F O R D
# K_AO_M_ER_F_ER_D
#
# W E I N D E L
# W_AY_N_D_AH_L
#
# C L A U D I A
# K_L_OW_D_IY_AH
#
# V A L E R I A N
# V_AE_L_ER_IY_IY_AH
#
# Q U I L T E R S
# K_W_IH_L_T_ER_Z
#
# R U D O L P H
# R_IH_D_AH_L_F
#
# G I E S E C K E
# G_IY_Z_EH_K
#
# F L A T L A N D
# F_L_AE_T_AH_AH_N_D
#
# A R G O ' S
# AA_R_G_OW_Z
#
# I N V E S T I G A T O R Y
# IH_N_V_EH_S_T_AH_G_R_AH_T_IY
#
# L I N E B A C K E R S
# L_IH_N_AH_B_ER_K_ER_Z
#
# R E C L I N I N G
# R_IH_K_L_AY_N_IH_NG
#
# B U N D E S R A T
# B_AH_N_D_EH_S_R_AE_T
#
# L A N K A N S
# L_AE_NG_K_AH_N_Z
#
# C A L L E G A R I
# K_AA_L_IH_G_AA_R_IY
#
# G O L F M A N
# G_OW_L_F_M_AH_N
#
# S T A R B U C K
# S_T_AA_R_B_AH_K
#
# S O L I D - S T A T E
# S_AA_L_IH_S_T_AH_T
#
# T A F E L
# T_EY_F_AH_L
#
# G I O V A N N O N I
# G_OW_OW_N_OW_V_IY_N_IY
#
# L A C H E N B R U C H
# L_AH_S_AH_N_B_R_UH_CH
#
# L A S H U A
# L_AA_SH_UW_AH
#
# V O L K M A N
# V_AA_L_K_M_AH_N
#
# M I R A G E
# M_IH_R_IH_ZH
#
# B O W D E N
# B_OW_D_AH_N
#
# B R O C K W A Y ' S
# B_R_AA_K_W_EY_Z
#
# I N C I S O R S
# IH_N_CH_IH_S_ER_Z
#
# F I R E S I G N
# F_AY_ER_S_AY_N
#
# G A Z E L L E
# G_AH_Z_EH_L
#
# S W A N D A
# W_AA_AA_D_AH
#
# H U L E T
# HH_UW_L_AH_T
#
# F L E I S S N E R
# F_L_IY_S_N_ER
#
# B E L I G E R E N C E
# B_IH_L_IH_G_R_IH_N_JH_AH
#
# R O M A N T I C S
# R_OW_M_AE_T_T_IH_K_S
#
# M A N N E S
# M_AE_N_Z
#
# T H R O N E B E R R Y
# TH_R_AA_N_IH_B_EH_R_IY
#
# C O R K I N S
# K_AO_R_K_IH_N_Z
#
# F O R E C A S T S
# F_AO_R_K_AE_T_S
#
# A U T H O R I Z E
# AO_TH_ER_AY_Z
#
# W I T U C K I
# W_IH_T_UW_K_IY
#
# D O P E
# D_OW_P
#
# R O S E N D A L E
# R_OW_Z_N_D_EY_L
#
# L A N D O
# L_AE_N_D_OW
#
# B U L A
# B_UW_L_AH
#
# F E R N H O L Z
# F_EH_R_HH_AA_L_Z
#
# C A R A V A
# K_AA_R_AA_V_AH
#
# M E N D E N H A L L
# M_EH_N_D_IH_N_D_AH_N
#
# H O L T Z M A N
# HH_AA_L_T_S_M_AH_N
#
# G U Y T O N
# G_AY_T_AH_N
#
# F A V O R A B L Y
# F_EY_V_ER_AH_B_L_IY
#
# N A N G
# N_AE_NG
#
# C H L O R O F L U O R O C A R B O N S
# K_L_AH_R_OW_F_AH_B_R_OW_N_Z
#
# C O L L I E R S
# K_AA_L_IY_ER_Z
#
# E N T O M B E D
# EH_N_T_AH_M_B_D
#
# A R T Y ' S
# AA_R_T_IY_Z
#
# A Q U I L A
# AA_K_W_IY_L_AH
#
# O U T C A L T
# AW_T_K_AH_T
#
# S H R E I B E R
# SH_R_AY_B_ER
#
# G L A D D I N G
# G_L_AE_D_IH_NG
#
# B O N A V E N T U R E
# B_AA_N_AH_V_Y_EH_V_EH_N_T_ER
#
# R H O
# R_OW
#
# H A N D H O L D I N G
# HH_AE_N_D_HH_OW_L_D_IH_NG
#
# S L A T S
# S_L_AE_T_S
#
# G I R T O N
# G_ER_T_AH_N
#
# G E T - T O G E T H E R
# G_EH_T_G_OW_TH_ER_IH_T_ER
#
# E Q U A T O R S
# IH_K_W_ER_EY_T_ER_Z
#
# C H R O M A T O G R A P H Y
# K_R_OW_M_AE_T_AE_G_R_AH_F_IY
#
# C E A S E L E S S
# S_IY_Z_L_AH_S
#
# A D R I A
# AE_D_R_IY_AH
#
# F E E S E R
# F_IY_Z_ER
#
# N E E C O
# N_IY_K_OW
#
# H A Z E L
# HH_EY_Z_AH_L
#
# D E C O U P L I N G
# D_IY_K_AH_P_L_L_NG
#
# C O P P E D G E
# K_AA_P_IH_JH
#
# M C C R E A D Y
# M_AH_K_R_IY_D_IY
#
# T R E M E N S
# T_R_EH_M_AH_N_Z
#
# H A R V E L L
# HH_AA_R_V_AH_L
#
# J E L T O N
# JH_EH_L_T_AH_N
#
# P E L A E Z
# P_EH_L_AA_Z
#
# K L A M O N
# K_L_AE_M_AH_N
#
# V E S T I B U L E
# V_EH_S_T_IY_B_AH_L
#
# P E R M E A B I L I T Y
# P_ER_M_M_IH_B_IH_L_IH_T_IY
#
# R E P U T E D
# R_IH_P_Y_UW_T_AH_D
#
# L I C E N T I O U S
# L_AY_S_T_AH_N_IH_SH_AH_Z
#
# P I S S
# P_IH_S
#
# O C A M P O
# OW_K_AE_P_OW
#
# R E D E N B A U G H
# R_IH_D_IH_N_B_AO
#
# S C A F F O L D S
# S_K_AE_F_OW_L_D_Z
#
# T E A M S '
# T_IY_M_Z
#
# A S H B R O O K
# AE_Z_B_R_UH_K
#
# T E M P L E R S
# T_EH_M_P_L_ER_Z
#
# V O Y A G E D
# V_AY_AH_JH_D
#
# Z I E B A
# Z_IY_B_AH
#
# W R I G H T S O N
# R_AY_T_S_AH_N
#
# H A N D
# HH_AE_N_D
#
# Z A M Z O W
# Z_AE_M_Z_OW
#
# F R E N K E L
# F_R_EH_NG_K_AH_L
#
# M I L Z
# M_IH_L_Z
#
# E L E C T R I C
# IH_L_EH_K_T_R_IH_K
#
# P U B L I C ' S
# P_AH_B_L_IH_K_S
#
# D E B I L I T A T E
# D_IH_B_IH_L_IH_T_EY_T
#
# A R T C A R V E D
# AA_R_T_K_AA_V_ER_D
#
# A S H T O N ' S
# AE_SH_T_AH_N_Z
#
# A L I A S
# AH_L_IY_AH_Z
#
# T E R R I T O R I A L
# T_EH_R_IH_T_AO_R_IY_AH
#
# E W E R S
# W_ER_ER_Z
#
# C L A I M E D
# K_L_EY_M_D
#
# T R E U H A N D A N S T A L T
# T_R_AH_AH_AH_D_N_AE_L_T
#
# B U L K H E A D S
# B_UH_L_HH_EH_Z_D_Z
#
# G O V E R N A N C E
# G_AH_V_ER_N_V_AH_N_S
#
# P E R R O N E
# P_ER_R_OW_N
#
# P H Y S I C S
# F_IH_Z_IH_K_S
#
# S T E R I L E
# S_T_EH_R_AH_L
#
# M A M A S
# M_AA_AA_AH_Z
#
# P I L Z
# P_IH_L_Z
#
# C A R S T E N S
# K_AA_R_S_T_N_Z
#
# E F F I C A C Y
# IH_F_IH_K_IH_S_IY
#
# T O - D O S
# T_OW_D_OW_Z
#
# B U M P A S
# B_AH_M_P_AH_Z
#
# S M A R T E N E D
# S_M_AA_R_T_AH_N_D
#
# S O P H R O N I A
# S_OW_P_R_OW_N_IY_AH
#
# K E Y E S '
# K_EY_Z
#
# W A N E R
# W_EY_N_ER
#
# E S T A B R O O K S
# IH_S_T_AH_B_R_UH_K_S
#
# A L S A T I A N
# AA_L_S_EY_SH_AH_N
#
# B I L Y E U
# B_IH_L_IY_Y_UW
#
# P A I N E W E B B E R ' S
# P_EY_N_W_B_ER_Z
#
# H O O C K
# HH_UH_K
#
# W E S T E R N I Z A T I O N
# W_EH_S_T_ER_N_EY_SH_AH_N
#
# T H E O R E T I C A L L Y
# TH_IH_AH_R_IH_T_T_IH_K_IY_IY
#
# L A I D L A W
# L_EY_D_L_AO
#
# B O Y F R I E N D
# B_AO_F_R_IY_N_D
#
# C O S T C O
# K_OW_S_T_K_OW
#
# R A C H
# R_AE_CH
#
# E X E M P T
# IH_G_Z_M_P_P_T
#
# F L E E C E D
# F_L_IY_S_T
#
# T R I V I A L I Z E S
# T_R_IH_V_IH_L_AY_Z_L_Z
#
# D A F O E
# D_EY_F_OW
#
# P H I L B I N
# F_IH_L_B_IH_N
#
# O C U L I S T
# AH_K_Y_UW_L_IH_S_T
#
# B U S A M
# B_UH_Z_AH_M
#
# C R O L L
# K_R_AO_L
#
# B O T H A M ' S
# B_AA_TH_AH_M_Z
#
# O L I V E R O S
# OW_L_IY_V_ER_OW_Z
#
# M A R S A L
# M_AA_R_S_AH_L
#
# P R O D I G Y ' S
# P_R_AA_D_IY_Z
#
# S T R A T E G I S T
# S_T_R_AE_T_IH_JH_IH_S_T
#
# A B S C O N D
# AE_B_S_K_AH_N_D
#
# S C H O L A S T I C
# SH_OW_L_AE_T_IH_IH_K
#
# R E V O C A T I O N
# R_IH_V_AH_K_EY_SH_AH_N
#
# A I R B A G
# EH_R_B_AE_G
#
# D E L V I N G
# D_EH_L_V_IH_NG
#
# A C C E P T
# AH_K_AH_P_T
#
# F R I L L S
# F_R_IH_L_Z
#
# I N E X P L I C A B L E
# IH_N_IH_K_S_K_P_AH_AH_B_AH_L
#
# P R O S P E R I
# P_R_AA_S_P_EH_R_IY
#
# H U B O R
# HH_Y_UW_B_ER
#
# A I R L I F T E D
# EH_R_L_IH_F_T_IH_D
#
# C A R E
# K_EH_R
#
# R O C H
# R_AA_CH
#
# S W I P E D
# S_W_IH_P_T
#
# B I S E K
# B_IH_S_EH_K
#
# P A R M E L E E
# P_AA_R_M_IH_L_IY
#
# M E N D O L A
# M_EH_N_D_OW_L_AH
#
# C R E D L E
# K_R_EH_D_AH_L
#
# I N C O N S I S T E N C I E S
# IH_N_K_AH_N_S_T_AH_N_IH_Z
#
# S T A R C K M A N N
# S_T_AA_R_K_M_AH_N
#
# T R U E B L O O D
# T_R_UW_B_L_AH_D
#
# S T R A T E G I C A L L Y
# S_T_R_EY_T_AH_JH_IH_K_L_IY
#
# S Q U I B B ' S
# S_K_W_IH_B_Z
#
# A V O C A D O S
# AA_V_AH_K_OW_D_OW_Z
#
# K O Z E M C H A K
# K_AH_Z_EH_M_AE_K
#
# S W O B O D A
# S_W_OW_B_OW_D_AH
#
# F R A N C I A
# F_R_AA_N_SH_AH
#
# G A R R I D O
# G_EH_R_IY_D_OW
#
# L I C H T E N S T E I N
# L_IH_NG_T_K_S_T_IY_N
#
# A R M C H A I R S
# AA_R_M_CH_ER_Z
#
# U N D E M O C R A T I C
# AH_N_D_AH_M_EH_K_R_AE_T_IH_K
#
# A A L I Y A H
# AA_L_IY_AH
#
# S C H R A U F N A G E L
# SH_R_AO_F_AH_N_JH_AH_L
#
# N U R T U R E D
# N_ER_CH_ER_D
#
# M I S B E H A V I N G
# M_IH_S_B_IH_HH_EY_G_IH_NG
#
# V O E L L E R
# V_OW_L_ER
#
# L E F C O U R T
# L_EH_K_F_UH_R_T
#
# U N D E R S T A T E
# AH_N_D_ER_S_T_EY_T
#
# M A R L I N
# M_AA_R_L_IH_N
#
# K A R P E N
# K_AA_R_P_AH_N
#
# C L I N I C A L ' S
# K_L_IH_N_IH_K_AH_L_Z
#
# R E D H E A D E D
# R_IY_D_HH_IY_D
#
# E L B O W S
# EH_L_B_OW_Z
#
# B A T H R O B E
# B_EY_TH_R_OW_B
#
# K A P L A I N
# K_EY_P_L_EY_N
#
# C O M E D O W N
# K_OW_M_D_D_AW_N
#
# A U D I E N C E ' S
# AH_D_AH_N_S_IH_Z
#
# R E M O D E L
# R_IH_M_AH_D_AH_L
#
# P O L I T O
# P_OW_L_IY_T_OW
#
# S H A R A
# SH_EH_R_AH
#
# I N F L A T O R
# IH_N_F_L_AH_T_ER
#
# M O L S O N
# M_OW_L_S_AH_N
#
# R E D M O N
# R_EH_D_M_AH_N
#
# T R E P A G N I E R
# T_R_EH_P_AH_G_N_IY_R
#
# H U E B E R
# HH_Y_UW_B_ER
#
# A N T E R I O R M O S T
# AA_N_T_ER_IY_M_AO_R_T_OW
#
# I N C A T A ' S
# IH_NG_K_AA_T_AH_Z
#
# T R O U S E R
# T_R_AW_Z_ER
#
# M O N D S
# M_AA_N_D_Z
#
# P R I M E S T A R
# P_R_IH_M_EH_S_T_ER
#
# T R U N K S
# T_R_AH_NG_K_S
#
# R E N T Z
# R_EH_N_T_S
#
# H E G L U N D
# HH_EH_G_L_AH_N_D
#
# K A Y A K
# K_EY_AA_K
#
# P A V O N
# P_AA_V_AH_N
#
# D E X F E N F L U R A M I N E
# D_IH_K_S_F_EH_N_M_L_L_M_AO_R_M_AH_N
#
# D O O L I N
# D_UW_L_IH_N
#
# C O B A I N E
# K_OW_B_EY_N
#
# G I A N N A T T A S I O
# G_Y_AH_N_AH_T_OW_SH_OW_OW
#
# R E C A N T
# R_IY_K_AH_N_T
#
# C R U M P L E D
# K_R_AH_M_P_AH_L_D
#
# N I K O L I C H
# N_IH_K_AH_L_IH_L
#
# A B L E S T
# AH_B_L_EH_S_T
#
# B I L G E R
# B_IH_L_G_ER
#
# P H Y S I O L O G Y
# F_IH_IH_IH_OW_L_JH_IY
#
# S U C R A L O S E
# S_AH_K_R_AH_L_OW_Z
#
# I N C E
# IH_N_S
#
# S A V O R Y
# S_EY_V_ER_IY
#
# H I L L B I L L Y
# HH_IH_L_B_IH_L_IY
#
# F O S S E
# F_AA_S
#
# R E T R A C T
# R_EH_T_R_AE_K_T
#
# C A R O L L O
# K_AA_R_OW_L_OW
#
# O U T H O U S E
# AW_TH_Y_UW_Z
#
# T H E O ' S
# TH_IY_OW_Z
#
# P A R T E D
# P_AA_R_T_IH_D
#
# U R E A
# Y_UH_R_IY
#
# Z A P P U L L A
# Z_AA_P_Y_UW_L_AH
#
# N E U N E R
# N_UW_N_ER
#
# G U M I N A
# G_UW_M_IY_N_AH
#
# P R I E M
# P_R_IY_M
#
# F A R R A R
# F_EH_R_ER
#
# O G R E S S
# OW_G_R_IH_S
#
# G R E M B A N
# G_R_EH_M_B_AH_N
#
# L A T H
# L_AE_TH
#
# S E C R E T E D
# S_IH_K_R_IH_T_AH_D
#
# D O R M
# D_AO_R_M
#
# C A S P E R S
# K_AE_S_P_ER_Z
#
# E X P A T R I A T I O N
# IH_K_S_P_P_R_IY_EY_SH_AH_N
#
# M E D A L L I O N S
# M_IH_D_AH_L_Y_AH_N_Z
#
# A T T A C K E R S
# AH_T_AE_K_ER_Z
#
# S A B R E T E C H
# S_AH_B_R_IH_K_EH
#
# G I L L A N D
# G_IH_L_AH_N_D
#
# B I C K E T T
# B_IH_K_IH_T
#
# S A L E S W O M A N
# S_AA_L_EH_S_W_W_M_AH_N
#
# K I S S I N G E R ' S
# K_IH_S_IH_NG_ER_ER_Z
#
# A G L E R
# AE_G_L_ER
#
# R A I N B O W
# R_EY_N_B_OW
#
# M I N U T E M A N
# M_IH_N_AH_T_AH_M_AH_N
#
# C I R C U S
# S_ER_K_UW_S
#
# D W I R E
# D_W_AY_ER
#
# P L A T I N U M ' S
# P_L_AE_T_IY_N_M_AH_M_Z
#
# S W I T C H E R S
# S_W_IH_CH_ER_Z
#
# H I M M E L S B A C H
# HH_IH_M_B_AH_L_B_AE_K
#
# G U A T E M A L A ' S
# G_W_AA_T_EH_M_AH_L_Z
#
# P H E N O M
# F_EH_N_AH_M
#
# F R A G M E N T
# F_R_EY_M_JH_AH_N_T
#
# W E A K L Y
# W_IY_K_L_IY
#
# L U B R I C A T E D
# L_AH_B_R_IY_K_EY_T_IH_D
#
# T R U C K ' S
# T_R_AH_K_S
#
# M O N O P O L E
# M_AH_N_OW_P_OW_L
#
# V E L O T T A
# V_EH_L_OW_T_AH
#
# I K E A
# IH_K_IY_IY
#
# P U C H A L S K I
# P_AH_CH_AH_L_S_K_IY
#
# K U O M I N T A N G ' S
# K_UW_UW_M_AE_N_T_AE_NG_Z
#
# A G U I L L A R D
# AA_G_AY_L_ER_D
#
# C O N S U M E R
# K_AA_N_S_UW_M_ER
#
# P O R T E N T
# P_AO_R_T_AH_N_T
#
# J U R Y ' S
# Y_Y_R_IY_Z
#
# W E N G E R D
# W_EH_NG_D_ER_D
#
# N O L D E N
# N_OW_L_D_AH_N
#
# B U R G E O N I N G
# B_ER_JH_UW_N_IH_NG
#
# D V O R A C E K
# D_AO_R_AH_S_EH_K
#
# M A R U L A N D A
# M_AA_R_UW_L_N_D_D_AH
#
# G O E R
# G_AO_R
#
# C O H E S I O N
# K_OW_HH_IH_ZH_AH_N
#
# T A U E R
# T_AW_ER
#
# C L O N C H
# K_L_AA_N_CH
#
# P R O F I L E S
# P_R_AA_F_AY_L_Z
#
# S K U L K
# S_K_AH_L_K
#
# B A N K C A R D S
# B_AE_NG_K_AA_R_D_Z
#
# S E N T I M E N T S
# S_EH_N_T_IH_M_AH_N_T_S
#
# D A U G H T R Y
# D_AO_T_R_IY
#
# P R E T T I E R
# P_R_EH_T_IY_ER
#
# R E A S S E S S E D
# R_IY_Z_EH_S_T
#
# C O N A R D
# K_AA_N_ER_D
#
# M O N T E E
# M_AA_N_T_IY
#
# W E D I N
# W_EH_D_IH_N
#
# V E R S T R A E T E
# V_ER_S_T_R_EY_T
#
# S Y L V I A ' S
# S_IH_L_V_IY_AH_Z
#
# K U B I C
# K_UW_B_IH_K
#
# R O T E N B E R R Y
# R_OW_T_EH_N_B_EH_R_IY
#
# V I E T N A M ' S
# V_IY_T_N_AE_M_Z
#
# G U I N I E R
# G_AY_N_IY_ER
#
# E L E G A N C E
# IH_L_IH_G_N_S
#
# D A L B E Y
# D_AO_L_B_IY
#
# H O B O
# HH_OW_B_OW
#
# Z O O M S
# Z_UW_M_Z
#
# B R A C K I N S
# B_R_AE_K_IH_N_Z
#
# N O E L L E
# N_OW_L_L
#
# A R M W O O D
# AA_R_M_UW_D
#
# K R A E G E R
# K_R_IY_G_ER
#
# L O I A C A N O
# L_OW_AA_AA_K_AA_N_OW
#
# B A R O V S K Y
# B_EH_R_AH_V_S_K_IY
#
# C O R O N A ' S
# K_AO_R_OW_N_AH_Z
#
# J E R K E D
# JH_ER_K_D
#
# G R A U L
# G_R_AO_L
#
# F L A H I V E
# F_L_AA_HH_IH_V
#
# P E T R E E
# P_EH_T_R_IY
#
# B E L U G A
# B_IH_L_UW_G_AH
#
# D E T E R D I N G
# D_IH_T_ER_D_IH_NG
#
# B E I L K E
# B_IY_L_K
#
# E L E C T R O L U X
# IH_L_EH_R_T_K_L_K_K_K
#
# S W A R T W O U T
# S_W_AO_R_T_AW_T
#
# B R A I L E Y
# B_R_EY_L_IY
#
# O U T C O M E S
# AW_T_K_OW_M_Z
#
# I N T R A V E N O U S
# IH_N_T_R_AH_V_AH_N_N_UW_S
#
# M E C K L E Y
# M_IH_K_L_IY
#
# A L U M N A
# AA_L_UW_M_N_AH
#
# P R O V E D
# P_R_OW_V_D
#
# W O R K P L A C E
# W_AO_R_P_P_L_EY
#
# B A R R A C L O U G H
# B_AA_R_AH_K_L_L
#
# S O U L L I E R E
# S_AW_L_IY_R
#
# R O G E R ' S
# R_OW_JH_ER_Z
#
# D E H U M I D I F I E R
# D_IH_HH_Y_UW_M_IH_D_IH_F_AY_ER
#
# L A N O U E T T E
# L_AH_N_EH_T
#
# C A L H O O N
# K_AE_L_HH_UW_N
#
# R H A M E S
# R_EY_M_Z
#
# C O V E N T R Y
# K_AH_V_AH_N_T_R_IY
#
# C U O M O ' S
# K_UW_OW_M_OW_Z
#
# A L P H A B E T I Z I N G
# AE_L_F_Y_AH_B_IH_T_IH_Z_IH_NG
#
# O ' L O U G H L I N
# OW_L_OW_L_L_IH_N
#
# A R B I T R A T O R S '
# AA_R_B_IH_T_EY_T_ER_Z
#
# B U N D L E D
# B_AH_N_D_AH_L_D
#
# S U R P L U S
# S_ER_P_L_AH_S
#
# H A R E
# HH_EH_R
#
# B O G E R T
# B_AA_JH_ER_T
#
# H O B E R G
# HH_OW_B_ER_G
#
# B U S T A R D
# B_AH_S_T_AA_R_D
#
# M O Z E N A
# M_OW_Z_EH_N_AH
#
# S U L F U R I C
# S_AH_L_F_UH_R_IH_K
#
# O B E R O N
# OW_B_ER_B_AH_N
#
# C R E S C E N Z I
# K_R_EH_S_CH_EH_N_Z_IY
#
# P A S S I V E
# P_AA_S_IH_V
#
# C A L L I E R
# K_EY_L_IY_ER
#
# A M U S E M E N T S
# AH_M_Y_UW_S_M_AH_N_T_S
#
# B E N Z E N E
# B_EH_N_Z_EH_N
#
# P S Y C H E D E L I C
# S_AY_K_AH_D_IH_L_IH_K
#
# N O U V E L L E
# N_UW_V_EH_L
#
# M A V
# M_AE_V
#
# W O O T T E N
# W_UW_T_AH_N
#
# V R B A
# V_R_IY_B_AH
#
# P A R T N E Y
# P_AA_R_T_N_IY
#
# M O S T A R ' S
# M_AA_S_T_ER_Z
#
# S T E P S I S T E R S
# S_P_EH_P_S_IH_S_T_ER_Z
#
# A T L A N
# AE_T_L_AH_N
#
# D E R T H I C K
# D_ER_TH_IH_K
#
# R E A S S E R T I O N
# R_IY_S_ER_SH_AH_N
#
# T H I R T E E N ' S
# TH_ER_T_IY_N_Z
#
# C H E Q U E
# CH_IY_K
#
# S I L A J D Z I C ' S
# S_AY_L_AH_D_IH_IH_K_S
#
# B R A B E N D E R
# B_R_AE_B_EH_N_D_ER
#
# B A R T N I K
# B_AA_R_T_N_IH_K
#
# S T E I N H A U S
# S_T_AY_N_N_HH_AW_S
#
# I N V A L I D A T I N G
# IH_N_V_AE_L_IH_D_AY_T_IH_NG
#
# G E R M A N ' S
# G_ER_M_AH_N_Z
#
# C O N D I T I O N E R
# K_AA_N_D_IH_SH_AH_N_ER
#
# S N E E Z E D
# Z_N_IY_Z_T
#
# H A R T L A U B
# HH_AA_R_T_L_B_UH
#
# D E S T R O Y E D
# D_IH_S_T_R_OY_D
#
# R E H Y D R A T I O N
# R_IH_HH_IH_D_R_EY_SH_AH_N
#
# B U R G
# B_ER_G
#
# E P P E R L Y
# IH_P_ER_L_IY
#
# R O T A T E
# R_OW_T_EY_T
#
# A L A R M I N G
# AA_L_AA_R_M_IH_NG
#
# D R A I N E
# D_R_EY_N
#
# C R O G A N
# K_R_OW_G_AH_N
#
# T A T A
# T_AA_T_AH
#
# G I F T S
# G_IH_F_T_S
#
# P A N N I L L
# P_AE_N_IH_L
#
# N E D L L O Y D
# N_EH_D_L_OY_D
#
# L E C H M A N
# L_EH_CH_M_AH_N
#
# B U L L H O R N S
# B_UH_L_HH_AO_R_N_Z
#
# O M A R A
# OW_M_ER_AH
#
# G A N N E T T ' S
# G_AE_N_AH_T_S
#
# B I O S P H E R I A N
# B_AY_AH_S_P_ER_R_IY_AH_N
#
# G U D G E O N
# G_AH_JH_AH_N
#
# S M O K I N G
# S_M_OW_K_IH_NG
#
# W A T T O N
# W_AA_T_AH_N
#
# R E C O R D A B L E
# R_IY_D_AO_R_AH_B_AH_L
#
# P E N F I L
# P_EH_N_F_IH_L
#
# P O C I U S
# P_OW_SH_UW_Z
#
# L E V E R A G E
# L_EH_V_ER_IH_JH
#
# K E M P K E
# K_EH_M_P_K_IY
#
# E S T R U T H
# EH_S_T_R_UW_TH
#
# M U R R E E
# M_ER_IY_IY
#
# I N H E R I T A B L E
# IH_N_HH_IH_R_IH_T_AH_B_AH_L
#
# Z I M M E R
# Z_IH_M_Z_ER
#
# S T R U T H E R S
# S_T_ER_Z_ER_Z
#
# N E T T E D
# N_EH_T_IH_D
#
# P R O V I D E N C E
# P_R_AA_V_IH_D_V_AH_N_S
#
# V A L U E P O I N T
# V_AE_L_UW_P_OY_N_AH_T
#
# D E N A
# D_EH_N_AH
#
# T E M P O
# T_EH_M_P_OW
#
# D O A N E
# D_OW_N
#
# S T A N D O U T
# S_T_AE_N_D_AW_T
#
# M A N E
# M_EY_N
#
# E T H N I C
# EH_TH_N_IH_K
#
# M A R B U R G E R
# M_AA_R_B_Y_ER_G_ER
#
# R E H M A N N
# R_EH_M_AH_N
#
# S W O R
# S_W_ER_ER
#
# H O B O K E N
# HH_AA_B_AH_K_AH_N
#
# P U R S E R
# P_ER_Z_ER
#
# M C I V E R
# M_AH_K_IH_V_ER
#
# S U F F O C A T E D
# S_AH_F_OW_K_EY_T_IH_D
#
# W E S T R A
# W_EH_S_T_R_AH
#
# R E C I T A L
# R_IH_S_IH_T_AH_L
#
# V A R I A N C E
# V_EH_R_IH_AH_N_S
#
# B I G H O R N S
# B_AY_G_AO_R_N_Z
#
# T A L O N S
# T_AE_L_AH_N_Z
#
# A R L E T T E
# AA_R_L_EH_T
#
# W E T T I N G
# W_EH_T_IH_NG
#
# C H O D O R O W
# CH_AA_D_ER_OW
#
# T U L I P S
# T_UW_L_IH_P_S
#
# C A R D I E L
# K_AA_R_D_IY_L
#
# S C I E N T I S T S
# S_IY_AH_N_T_S_T_S
#
# P R O T E C T E D
# P_R_AA_T_EH_K_T_AH_D
#
# B O A S T E D
# B_OW_S_T_AH_D
#
# B E G E L M A N
# B_IH_G_AH_L_M_AH_N
#
# L A M B R E A U
# L_AH_M_R_OW
#
# E L E C T R O P L A T I N G
# IH_L_EH_K_T_R_AE_P_L_L_EY_T_IH_NG
#
# P L A I N
# P_L_EY_N
#
# O M A R
# OW_M_ER
#
# A N Y
# EY_N_IY
#
# C R A N K
# K_R_AE_NG_K
#
# S T O R M E R
# S_T_AO_R_M_ER
#
# C R I P P S
# K_R_IH_P_S
#
# C O U N T E R T E R R O R I S M
# K_AW_N_T_ER_R_IH_AO_R_IH_M_M
#
# F E B R U A R Y ' S
# B_EH_B_R_UW_R_IY_Z
#
# D O W N P L A Y
# D_OW_N_P_L_EY
#
# M O W A T T
# M_OW_AH_T
#
# F R O N T L I N E
# F_R_AA_N_T_L_AY_N
#
# H E R Y A N A
# HH_EH_R_IY_AH_N
#
# S O L I D I F Y I N G
# S_OW_L_IH_D_AY_F_AY_IH_NG
#
# N O B U A K I
# N_OW_B_Y_UW_K_IY
#
# B O G G L I N G
# B_AA_G_L_L_IH_NG
#
# K A N J I
# K_AA_N_JH_IY
#
# F A R N A M
# F_AA_R_N_AH_M
#
# N E G L I A
# N_EH_G_L_IY_AH
#
# M E L L
# M_EH_L
#
# N U F E R
# N_UW_F_ER
#
# S O N O M A
# S_AA_N_OW_M_AH
#
# D A U
# D_AW
#
# M C G U I N N
# M_AH_G_Y_UW_N
#
# W E S R A Y
# W_EH_S_R_EY
#
# S T E A M S
# S_T_IY_M_Z
#
# G E R O N
# G_EH_R_AH_N
#
# M E L L O N S
# M_EH_L_AH_AH_Z
#
# C A L O R I E
# K_AE_L_AO_R_IY
#
# R E I N S U R A N C E
# R_IH_IH_N_S_ER_R_AH_N_S
#
# F E H E R
# F_EH_HH_ER
#
# M E S O P O T A M I A
# M_IY_S_OW_P_OW_T_OW_M_M_AH
#
# F L A N N E L S
# F_L_AE_N_AH_L_Z
#
# B R O K E N - W I N D E D
# B_R_AA_K_W_IH_N_AY_N_D_D
#
# L E I T Z E L
# L_EY_T_Z_L_L
#
# W I S N E S K I
# W_IH_Z_K_EH_S_K_IY
#
# L O W N E Y
# L_OW_N_IY
#
# T R U E X
# T_R_UW_K_S
#
# F U R T A K
# F_ER_T_AE_K
#
# B I J A C
# B_IH_G_AE_K
#
# B O E R N E R
# B_AO_R_N_ER
#
# K A V A N A G H
# K_AA_V_AE_N_AA_HH
#
# M C R I G H T
# M_AH_K_R_AY_T
#
# S P A W N E D
# S_P_AO_N_D
#
# C H A N C E L L O R
# CH_AE_N_CH_EH_L_ER
#
# S P E A K S
# S_P_IY_K_S
#
# D O N A L D S O N
# D_AA_N_AH_L_D_AH_N_Z
#
# D E V A L
# D_EY_V_AH_L
#
# M O L T I N G
# M_OW_L_T_IH_NG
#
# W A U K E S H A
# W_AA_K_W_AA_SH_AH
#
# C R O S S B O W
# K_R_AA_S_B_OW
#
# B A S I N S K I
# B_AH_S_IH_N_S_K_IY
#
# T R A V E S T I E S
# T_R_AH_V_EH_S_T_IY_Z
#
# R E F R A C T O R S
# R_IH_F_R_AE_K_T_ER_Z
#
# G A R G A N
# G_AA_R_G_AH_N
#
# R O S E L L E N
# R_OW_Z_L_L_N
#
# D R E I G H T O N
# D_R_EY_T_AH_N
#
# G E R T Y
# G_ER_T_IY
#
# T R A C Z Y K
# T_R_AE_CH_IH_K
#
# S U B S O I L
# S_AH_B_L_UW_L
#
# L E Y S
# L_IY_S
#
# O L I G O P O L I S T I C
# AA_L_IH_G_AH_P_IH_L_IH_IH_IH_T_IH_IH
#
# A B E R R A T I O N
# EY_B_ER_EY_SH_AH_N
#
# O V I E D O
# OW_V_IY_D_OW
#
# P O W E R L E S S
# P_OW_ER_L_AH_S
#
# S I N F O N I A
# S_IH_N_F_OW_OW_N_IY
#
# S T R O N G L Y
# S_T_R_AA_NG_G_IY_IY
#
# R E N T E D
# R_EH_N_T_IH_D
#
# H O S A K A W A
# HH_AA_S_AA_AA_AA_W_AH
#
# T A B A R
# T_EY_B_AA_R
#
# R I C K E
# R_IH_K
#
# B O L T Z
# B_OW_L_T_S
#
# A I L M E N T S
# EY_L_M_AH_N_T_S
#
# W A S S I N K
# W_AA_S_IH_NG_K
#
# M E N G E
# M_EH_N_JH
#
# W E D G W O O D
# W_EH_D_G_UH_D
#
# S P I C K L E R
# S_P_IH_K_AH_L_ER
#
# B A R T O N ' S
# B_AA_R_T_AH_N_Z
#
# E L F M A N
# EH_L_F_M_AH_N
#
# M A N C E R A
# M_AA_N_S_ER_AH
#
# T O R S O
# T_AO_R_S_OW
#
# J U X T A P O S I T I O N
# JH_AH_K_S_AH_P_AH_P_AH_SH_AH_N
#
# L A M O R E A U X
# L_AH_M_AO_R_OW_OW
#
# M E T O Y E R
# M_IY_T_OY_ER
#
# D E A C O N
# D_IY_K_AH_N
#
# W A L L I E
# W_AO_L_IY
#
# P E L L E R
# P_EH_L_ER
#
# O K E E F F E
# OW_K_IY_F
#
# F R I N G E R
# F_R_IH_NG_G_ER
#
# J A S P E R
# JH_AE_S_P_ER
#
# G R I N S T E I N
# G_R_IH_N_S_T_AY_N
#
# B R A C E L E T S
# B_R_AH_S_AH_L_T_S
#
# M I N I S U P E R C O M P U T E R
# M_IH_N_IH_S_P_AH_R_M_Y_AH_M_AO_R_T_M_M_K_T_ER
#
# K U S H N E R
# K_AH_SH_N_ER
#
# G E N E N T E C H ' S
# G_EH_N_EH_N_T_EH_K_Z
#
# P U S T E J O V S K Y
# P_AH_S_T_AH_OW_OW_S_K_IY
#
# T E R A D A T A
# T_EH_R_AA_D_AH_T
#
# V A S S
# V_AE_S
#
# B E N S O N ' S
# B_EH_N_S_AH_N_Z
#
# R O S A B E L
# R_OW_Z_AH_B_EH_L
#
# B O U N D L E S S
# B_AW_N_D_AH_AH_Z
#
# F O R W A R D E D
# F_AO_R_W_ER_D_D
#
# C H E S T E R S O N
# CH_EH_S_T_ER_S_AH_N
#
# V E R R Y
# V_EH_R_IY
#
# N O T I F I C A T I O N
# N_AA_T_IH_F_OW_K_EY_SH_AH_N
#
# S T A G N A T E
# S_T_AA_G_N_EY_T
#
# R E H E A R S E D
# R_IH_HH_ER_S_Z
#
# M A T L O C K
# M_AE_T_L_AH_K
#
# V O U G H T
# V_AW_T
#
# D U T K O
# D_AH_T_K_OW
#
# S O N O D A
# S_AA_N_OW_D_AH
#
# O S A K A
# OW_S_AA_K_AH
#
# B O O K E R
# B_UH_K_ER
#
# S C H R O E R
# SH_R_OW_ER
#
# C E N S O R I N G
# S_EH_N_CH_ER_IH_NG
#
# E X P O S E
# IH_K_S_P_OW_Z
#
# C E L I S
# S_IY_L_IH_S
#
# L O N G S T R E E T
# L_AA_NG_G_R_IH_T
#
# D E R M A N
# D_ER_M_AH_N
#
# V O G E L S
# V_AA_G_AH_L_Z
#
# U R A L
# Y_UH_R_AH_L
#
# N A N C Y
# N_AE_S_IY
#
# G U I D E P O S T S
# G_AY_D_P_OW_AH_S_T_S
#
# L A M B Y
# L_AE_M_B_IY
#
# F L I N G S
# F_L_IH_NG_Z
#
# S U I T I N G
# S_UW_T_IH_NG
#
# S I L V E R S I D E S
# S_IH_L_V_ER_S_AY_Z
#
# W E C H S L E R
# W_EH_K_S_L_ER
#
# H U P F E R
# HH_AH_P_F_ER
#
# L E A T H E R M A N
# L_IY_DH_ER_M_AH_N
#
# L U P A T K I N
# L_AH_P_AH_T_K_K
#
# E L A B O R A T E L Y
# IH_L_AH_B_ER_AH_T_L_IY
#
# A R R U P E
# ER_UW_P_UW
#
# I N O C U L A T I O N
# IH_N_AA_K_Y_AH_L_EY_SH_AH_N
#
# U N T O
# AH_N_T_OW
#
# S C O G I N
# S_K_AA_G_IH_N
#
# H E S S I O N
# HH_EH_SH_AH_N
#
# T A R N O W S K I
# T_AA_R_N_AO_F_S_K_IY

# %%
result = pd.DataFrame()
result['Transcription'] = res_w
result.index = np.arange(1, len(test) + 1)
result.index.names = ['Id']

# %%
result
# Out:
#                      Transcription
# Id
# 1                        P_IH_CH_T
# 2               D_IH_S_AA_L_V_ER_Z
# 3                    S_K_R_AO_N_IY
# 4               B_AA_N_EH_F_AA_N_T
# 5                    IH_K_S_IY_D_Z
# ...                            ...
# 41593  IH_N_AA_K_Y_AH_L_EY_SH_AH_N
# 41594                    AH_N_T_OW
# 41595                S_K_AA_G_IH_N
# 41596                HH_EH_SH_AH_N
# 41597         T_AA_R_N_AO_F_S_K_IY
#
# [41597 rows x 1 columns]

# %%
result.to_csv('new.csv')
files.download("new.csv")
